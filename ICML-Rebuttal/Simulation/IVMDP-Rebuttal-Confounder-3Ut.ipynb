# %% [markdown]
# ## Description
# In this notebook, we changed the confounding strength to **medium** level through function 'generate_Rt'.

# %% [markdown]
# ## Generate simulation data

# %%
import joblib
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from numpy.ma.core import exp
from scipy.special import expit

# %%
# define some functions to generate the simulation data

def generate_S0(n0):
    S01=np.random.normal(size=n0)
    S02=np.random.normal(size=n0)
    return np.vstack((S01,S02)).T

def generate_Ut(n0):
    return np.random.binomial(size=n0, n=1, p=0.5) - 0.5

def generate_Zt(St,n0):
    p=expit(St[:,0]+St[:,1])
    return np.random.binomial(1,p,size=n0)

def generate_At(St,Zt,Ut,n0):
    p=expit(St[:,0]+St[:,1]+Zt+1*Ut)
    return np.random.binomial(1,p,size=n0)

# 5Ut -> 3Ut
def generate_Rt(St,At,Ut,n0):
    return (St[:,0]+St[:,1]+2*At+3*Ut)

def generate_Stplus1(St,At,Ut,n0):
    Stplus11 = St[:,0] + Ut + (At - 0.5)
    Stplus12 = St[:,1] - Ut - (At - 0.5)
    Stplus = np.vstack((Stplus11,Stplus12)).T
    return Stplus

# %%
# generate simulation dataset
# the number of samples
n=10**3
# the number of stages
T=120
p=2


np.random.seed(525)
S0=generate_S0(n)
MDP = np.copy(S0)
St=S0
for i in range(T):
    Ut=generate_Ut(n)
    Zt=generate_Zt(St,n)
    At=generate_At(St,Zt,Ut,n)
    Rt=generate_Rt(St,At,Ut,n)
    Stplus1=generate_Stplus1(St,At,Ut,n)
    MDP = np.hstack((MDP, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
    St=Stplus1


MDP=MDP[:,(20*(p+3)):(120*(p+3)+p)]
print(np.shape(MDP))
# Out:
# (1000, 502)

# %%
pd.DataFrame(MDP)
# Out:
#            0          1    2    3         4          5          6    7    8    \
# 0    -7.665318   5.507090  0.0  0.0 -0.658228  -7.665318   5.507090  1.0  0.0
# 1     9.381374  -7.349269  1.0  1.0  2.532105   9.381374  -7.349269  1.0  1.0
# 2     7.314472  -6.954949  0.0  0.0 -1.140477   6.314472  -5.954949  1.0  1.0
# 3    13.226179 -11.576353  1.0  1.0  5.149827  14.226179 -12.576353  0.0  1.0
# 4     0.545412  -1.115731  0.0  1.0 -0.070319   0.545412  -1.115731  1.0  0.0
# ..         ...        ...  ...  ...       ...        ...        ...  ...  ...
# 995   1.640969  -0.121767  1.0  1.0  5.019202   2.640969  -1.121767  0.0  1.0
# 996   7.410351  -7.092512  0.0  1.0  3.817839   8.410351  -8.092512  0.0  0.0
# 997  -0.795136  -0.038623  1.0  0.0 -2.333758  -1.795136   0.961377  0.0  0.0
# 998   8.153053  -7.755844  0.0  0.0 -1.102792   7.153053  -6.755844  1.0  1.0
# 999  -5.126541   3.867136  0.0  0.0 -2.759405  -6.126541   4.867136  0.0  1.0
#
#           9    ...  492  493       494        495        496  497  498  \
# 0   -3.658228  ...  0.0  0.0 -0.658228 -40.665318  38.507090  0.0  0.0
# 1    2.532105  ...  1.0  1.0  5.532105  53.381374 -51.349269  1.0  0.0
# 2    0.859523  ...  0.0  0.0 -1.140477  26.314472 -25.954949  1.0  1.0
# 3    2.149827  ...  1.0  1.0  2.149827  44.226179 -42.576353  0.0  1.0
# 4    0.929681  ...  1.0  1.0 -0.070319  -2.454588   1.884269  0.0  1.0
# ..        ...  ...  ...  ...       ...        ...        ...  ...  ...
# 995  2.019202  ...  1.0  1.0  5.019202  44.640969 -43.121767  0.0  1.0
# 996  1.817839  ...  0.0  0.0 -1.182161  30.410351 -30.092512  1.0  1.0
# 997 -2.333758  ...  0.0  1.0  2.666242 -19.795136  18.961377  0.0  1.0
# 998  0.897208  ...  1.0  1.0  0.897208  12.153053 -11.755844  1.0  1.0
# 999  2.240595  ...  0.0  0.0 -2.759405 -24.126541  22.867136  0.0  0.0
#
#           499        500        501
# 0   -3.658228 -41.665318  39.507090
# 1    0.532105  52.381374 -50.349269
# 2    3.859523  27.314472 -26.954949
# 3    5.149827  45.226179 -43.576353
# 4    2.929681  -1.454588   0.884269
# ..        ...        ...        ...
# 995  2.019202  44.640969 -43.121767
# 996  3.817839  31.410351 -31.092512
# 997  2.666242 -18.795136  17.961377
# 998  0.897208  12.153053 -11.755844
# 999  0.240595 -24.126541  22.867136
#
# [1000 rows x 502 columns]

# %%
p=2
#Pi=1
gamma=0.9
domain_At=np.array([0,1])
domain_Zt=np.array([0,1])
max_iter=1000
epsilon=5e-4
T=100

# %%
def Pi(St):
    if len(St.shape) == 0:
        raise ValueError("St should be 1d/2d array")

    if len(St.shape) == 1:
        return 1
        #p = expit(St[0]+St[1]+1.5*expit(St[0]+St[1]))
    else:
        return np.ones(np.shape(St)[0])
        #p = expit(St[:,0]+St[:,1]+1.5*expit(St[:,0]+St[:,1]))

# %% [markdown]
# ## true value

# %%
# approximate the true value of eta_pi by MC method
# the first step is to generate a dataset that follows target policy Pi.
# in this case, we specify At=np.ones(n0)*Pi where Pi can be 0 or 1.

np.random.seed(525)
n0=10**5 # the number of trajectories in MC approximation. The larger the better.
T_burn=20
p=2
T=100 # the number of stages
gamma=0.9

eta_pi_true=0
for repp in range(100):

    S0=generate_S0(n0)
    MDP_burn = np.copy(S0)
    St=S0
    for i in range(T_burn):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=generate_At(St,Zt,Ut,n0)
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP_burn = np.hstack((MDP_burn, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

  #print(np.shape(MDP_burn))


    S0=MDP_burn[:,T_burn*(p+3):(T_burn*(p+3)+2)]

    MDP0 = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=np.random.binomial(n=1, p=Pi(St), size=n0) # generate Ai following Pi
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP0 = np.hstack((MDP0, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1
  #MDP0=MDP0[:,(20*(p+3)):(120*(p+3)+p)]
  #print(np.shape(MDP0))

  # true value of $\eta_{\pi}$ can be estimated by MC method:

    for t in range(T):
        eta_pi_true=eta_pi_true+(gamma**(t))*sum(MDP0[:,(p+2)+(p+3)*t])/n0

        
eta_pi_true=eta_pi_true/100
print(eta_pi_true)
# Out:
# 19.99604133247016

# %%
np.shape(Zt)
# Out:
# (100000,)

# %%
pd.DataFrame(MDP0)
# Out:
#              0          1    2    3         4          5          6    7    \
# 0       6.014786  -5.354693  1.0  1.0  1.160093   6.014786  -5.354693  0.0
# 1      13.275657 -10.343086  1.0  1.0  3.432571  13.275657 -10.343086  1.0
# 2      11.096759 -10.223350  1.0  1.0  4.373409  12.096759 -11.223350  1.0
# 3      11.620527  -9.817214  1.0  1.0  5.303313  12.620527 -10.817214  1.0
# 4       8.270191  -7.059221  0.0  1.0  4.710971   9.270191  -8.059221  1.0
# ...          ...        ...  ...  ...       ...        ...        ...  ...
# 99995  -2.687823   1.920101  0.0  1.0 -0.267723  -2.687823   1.920101  0.0
# 99996   3.978756  -4.450690  0.0  1.0  3.028066   4.978756  -5.450690  0.0
# 99997  12.216641 -10.047447  1.0  1.0  2.669194  12.216641 -10.047447  1.0
# 99998  -1.366799  -0.603489  0.0  1.0  1.529713  -0.366799  -1.603489  0.0
# 99999   1.335805  -1.943831  0.0  1.0 -0.108026   1.335805  -1.943831  0.0
#
#        8         9    ...  492  493       494        495        496  497  498  \
# 0      1.0  1.160093  ...  1.0  1.0  4.160093  51.014786 -50.354693  1.0  1.0
# 1      1.0  6.432571  ...  1.0  1.0  6.432571  64.275657 -61.343086  1.0  1.0
# 2      1.0  1.373409  ...  0.0  1.0  4.373409  55.096759 -54.223350  0.0  1.0
# 3      1.0  5.303313  ...  1.0  1.0  5.303313  59.620527 -57.817214  1.0  1.0
# 4      1.0  4.710971  ...  0.0  1.0  4.710971  53.270191 -52.059221  1.0  1.0
# ...    ...       ...  ...  ...  ...       ...        ...        ...  ...  ...
# 99995  1.0 -0.267723  ...  1.0  1.0  2.732277  55.312177 -56.079899  1.0  1.0
# 99996  1.0  0.028066  ...  1.0  1.0  3.028066  50.978756 -51.450690  1.0  1.0
# 99997  1.0  2.669194  ...  1.0  1.0  5.669194  56.216641 -54.047447  1.0  1.0
# 99998  1.0 -1.470287  ...  0.0  1.0 -1.470287  41.633201 -43.603489  0.0  1.0
# 99999  1.0 -0.108026  ...  1.0  1.0  2.891974  55.335805 -55.943831  1.0  1.0
#
#             499        500        501
# 0      1.160093  51.014786 -50.354693
# 1      3.432571  64.275657 -61.343086
# 2      4.373409  56.096759 -55.223350
# 3      5.303313  60.620527 -58.817214
# 4      1.710971  53.270191 -52.059221
# ...         ...        ...        ...
# 99995  2.732277  56.312177 -57.079899
# 99996  3.028066  51.978756 -52.450690
# 99997  2.669194  56.216641 -54.047447
# 99998 -1.470287  41.633201 -43.603489
# 99999 -0.108026  55.335805 -55.943831
#
# [100000 rows x 502 columns]

# %% [markdown]
# ## comparison

# %% [markdown]
# #### IVRL

# %%
def IVRL_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # IV+MDP. Off policy evaluation: estimate the averaged treatment effect in infinite-horizon MDP settings
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler
    from numpy.linalg import inv, eigvals

    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T

    index_Z=np.linspace(0,T-1,T)*(p+3)+p
    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2
    index_SZ=np.concatenate((index_S,index_Z))

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_SZ=MDP[:,index_SZ.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Zvec=MDP[:,index_Z.astype(int)].T.reshape(-1,1)
    SZvec=np.hstack((Svec,Zvec))
    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s,z) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(SZvec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(SZvec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")
    def Pa(St,Zt,n,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St,Zt]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(np.concatenate((St,np.array([Zt]))).reshape(1, -1))[0]
      else:
        return A_model.predict_proba(np.hstack((St,Zt)))


    ## (2) estimate P11 := p_a(At=1|Zt=1,St)
    def P11(St,n,A_model):
      if (n==1):
        return Pa(St,1,n,A_model)[1]
      else:
        return Pa(St,np.ones(n).reshape(-1,1),n,A_model)[:,1]

    ## (3) estimate P10 := p_a(At=1|Zt=0,St)
    def P10(St,n,A_model):
      if (n==1):
        return Pa(St,0,n,A_model)[1]
      else:
        return Pa(St,np.zeros(n).reshape(-1,1),n,A_model)[:,1]

    ## (4) estimate c(Zt|St)
    def c(Zt,St,n,Pi,A_model):
      #ratio = np.clip(ratio, a_min=-100, a_max=100)
      if (n==1):
        c=Zt*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c
        return np.clip(c, a_min=-50, a_max=50)
      else:
        c=Zt.T*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt.T)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c[0]
        return np.clip(c[0], a_min=-50, a_max=50)

    ## (5) estimate pz(Zt|St)
    Z_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #Z_model = LogisticRegression()
    Z_model.fit(Svec[range(int(n*T*0.9))], Zvec[range(int(n*T*0.9))].reshape(1,-1)[0])
    print("pz model performance (accuracy): ", Z_model.score(Svec[range(int(n*T*0.9),n*T)], Zvec[range(int(n*T*0.9),n*T)], sample_weight=None),"\n")

    def Pz(Zt,St,n,Z_model):
      if ((n==1) and (p==1)):
        return Z_model.predict_proba(np.array([St]).reshape(1, -1))[0][int(Zt)]
      elif ((n==1) and (p!=1)):
        return Z_model.predict_proba(St.reshape(1, -1))[0][int(Zt)]
      else:
        return Z_model.predict_proba(St)[:,1]*Zt.T[0] + Z_model.predict_proba(St)[:,0]*(1-Zt.T[0])




    ## (6) estimate $\rho(Z_t,S_t)$
    def rho(St,Zt,n,Pi,A_model):
      return c(Zt,St,n,Pi,A_model)/Pz(Zt,St,n,Z_model)

    print("Start estimating omega_pi(St):")
    ## (7) estimate $\omega^{\pi}(s)$: should change if St continuous, and here we only specify linear function class for xi
    class RatioLinearLearner:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, time_difference=None, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=True, rho=rho, A_model=A_model, truncate=100, domain_Zt=np.array([0,1]), domain_At=np.array([0,1])):
            self.use_IV = use_IV

            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])
            if use_IV:
                self.IV = np.copy(dataset['IV']).reshape(-1, 1)
            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)

            self.Pi = Pi

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                ratio = rho(self.state,self.IV,len(self.action),self.Pi,A_model)
            #else:
                  #estimate_pa = self.PALearner.get_pa_prediction(self.state, self.action)
                  #target_pa = self.target_policy_pa(self.policy, self.state, self.action)
                  #pa_ratio = target_pa / estimate_pa
                  #ratio = pa_ratio

            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)

    state_all=Svec
    IV=Zvec.T[0]
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, IV, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action, 'IV': IV,
            'reward': reward, 
            "next_state": next_state_all}

    
    rlearner = RatioLinearLearner(dataset, Pi, ndim = ndim, use_IV= True, rho=rho, A_model=A_model)
    rlearner.fit()
    omega_all=rlearner.get_ratio_prediction(state_all)

    print("omega_pi(St) estimation finished.\n")


    print("Start estimating Q function and Value function (fitted Q evaluation):")
    ## (8) estimate Q function: we only specify Q as a linear function of (St,Zt,At). Can be generalized later.
    # Q function: a linear function of (St,Zt,At). Can be modified later.
    def Q(beta,n,St,Zt,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,Zt,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([Zt]),np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,Zt,At)),beta)################################3

    ## (9) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta, domain_Zt, domain_At, A_model):
      len_Zt=len(domain_Zt)
      len_At=len(domain_At)
      if (n==1):
        V_St=0
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q(beta,n,St,domain_Zt[i],domain_At[j])
            #V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q_model.predict(np.concatenate((St,np.array([domain_Zt[i]]),np.array([domain_At[j]]))))
      else:
        V_St=np.zeros(n)
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i]*np.ones(n).reshape(-1,1),St,n,Pi,A_model)*Pa(St,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]*Q(beta,n,St,domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1))
            #V_St=V_St+c(np.ones(n)*domain_Zt[i].reshape(-1,1),St,n,Pi,A_model)*Pa(St,np.ones(n)*domain_Zt[i].reshape(-1,1),n,A_model)[:,j]*Q_model.predict(np.hstack((St,np.ones(n)*domain_Zt[i].reshape(-1,1),np.ones(n)*domain_At[j].reshape(-1,1))))

      return V_St

    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+2
    nall=n*T
    len_Zt=len(domain_Zt)
    len_At=len(domain_At)
    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p+2)]),axis=1)

      f_tplus1_Q=np.zeros((n,nfeatures+1))
      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      for i in range(len_Zt):
        for j in range(len_At):
          xi_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)],domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1)),axis=1)
          coef_Q=c(domain_Zt[i]*np.ones(n).reshape(-1,1),Stplus1,n,Pi,A_model)*Pa(Stplus1,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]
          f_tplus1_Q=f_tplus1_Q+xi_tplus1_Q* coef_Q[:, np.newaxis]

      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q=np.linalg.solve(part1_Q,part2_Q)

    print("Estimated beta_Q is: ", beta_Q)
    print("Q function and Value function estimation finished.\n")


    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q):
      
      phi_result=0
      #phi_result_part1=0
      #phi_result_part2=0

      for t in range(T):
        if (p==1):
          Pa_At=Pa(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=MDP[i,4*t+1],At=a)

          phi_3=MDP[:,4*t+2]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          #delta_a=np.clip(delta_a, a_min=-50, a_max=50)
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,4*t],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega) !!!!!!!!!!!!!!!
          rho_StZt=rho(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        else:
          Pa_At=Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=MDP[i,(p+3)*t+p],At=a)

          phi_3=MDP[:,(p+3)*t+p+1]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          rho_StZt=rho(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        
        
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2+phi_3))

        #phi_result_part1=phi_result_part1+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2))
        #phi_result_part2=phi_result_part2+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*phi_3)

      phi_result=phi_result/n/(T)
      #phi_result_part1=phi_result_part1/n/(T)
      #phi_result_part2=phi_result_part2/n/(T)

      return phi_result


    print("Start calculating DM estimator:")
    # calculate the direct estimator
    eta_pi_DM=0
    for i in range(n):
      for z in range(2):
        for a in range(2):
          eta_pi_DM=eta_pi_DM+c(Zt=z,St=MDP[i,0:p],n=1,Pi=Pi,A_model=A_model)*Pa(Zt=z,St=MDP[i,0:p],n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,0:p],Zt=z,At=a)
    eta_pi_DM=eta_pi_DM/n
    print("DM estimator: eta_pi_DM=", eta_pi_DM)
    print("DM estimator calculation finished.\n")

    print("Start calculating augmentation terms:")
    # calculate the augmentation terms by function phi_aug
    eta_pi_aug=phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q)
    print("Augmentation term: eta_pi_aug=", eta_pi_aug)
    print("Augmentation terms calculation finished.\n")

    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_DR=eta_pi_DM+eta_pi_aug
    
    return eta_pi_DM, eta_pi_DR

# %% [markdown]
# #### Other methods: NUC

# %%
def DRL_NUC_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # Double reinforcement learning with NO unmeasured confounders. 
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv, eigvals



    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T


    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(Svec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(Svec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")


    def Pa(St,n,p,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(St.reshape(1, -1))[0]
      else:
        return A_model.predict_proba(St)

    #from scipy.interpolate import BSpline


    ## (9) estimate Q function: we only specify Q as a linear function of (St,At). Can be generalized later.
    # Q function: a linear function of (St,At). Can be modified later.
    def Q(beta,n,St,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,At)),beta)################################3

    ## (10) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta):
      # deterministic policy Pi: here we just test Pi=1. The whole function can be generalized to random policy later.
      if (n==1):
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=1)[0])
      else:
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=n).reshape(-1,1))

      return V_St


    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+1
    nall=n*T

    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,((p+3)*t+p+1)].reshape(-1,1)),axis=1)

      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      f_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),Stplus1,np.random.binomial(n=1, p=Pi(MDP[:,(p+3)*t:((p+3)*t+p)]), size=n).reshape(-1,1)),axis=1)


      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q_NUC=np.linalg.solve(part1_Q,part2_Q)

    # DM estimator:
    eta_pi_est_DM_NUC=0
    for i in range(n):
      eta_pi_est_DM_NUC=eta_pi_est_DM_NUC+V(MDP[i,0:p],1,Pi,beta_Q_NUC) # corre
    eta_pi_est_DM_NUC=eta_pi_est_DM_NUC/n

    print("DM estimator under NUC: ",eta_pi_est_DM_NUC) 


    ## (7) estimate beta_pi
    def beta_pi(St,At,p,n,Pi,A_model):
      if (n==1):
        return (Pi(St)*At+(1-Pi(St))*(1-At))/(Pa(St,1,2,A_model)[int(At)])
      else:
        return (Pi(St)*At.T[0]+(1-Pi(St))*(1-At.T[0]))/(At.T[0]*Pa(St,n,2,A_model)[:,1]+(1-At.T[0])*Pa(St,n,2,A_model)[:,0])


    ## (8) estimate $\omega^{\pi}(s)$: here we only specify linear function class for xi
    # -*- coding: utf-8 -*-

    import numpy as np
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler

    class RatioLinearLearner_NUC:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=False, truncate=100):
            self.use_IV=use_IV
            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])

            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)
            self.beta_pi=beta_pi
            self.Pi = Pi
            self.A_model = A_model

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                rho(self.state,self.IV.reshape(-1,1),len(self.action),self.Pi,A_model)
            else:
                ratio = beta_pi(self.state, self.action,p,n,self.Pi,self.A_model)

            # print(np.mean(ratio)) # close to 1 if behaviour and target are the same
            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            # design_matrix = np.zeros((psi.shape[1], psi.shape[1]))
            # for i in range(self.state.shape[0]):
            #     design_matrix += np.matmul(psi[i].reshape(-1, 1), psi_minus_psi_next[i].reshape(1, -1))
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))  
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)


    state_all=Svec
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action,
            'reward': reward, 
            "next_state": next_state_all}

    #dataset, policy, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=100,
    rlearner_NUC = RatioLinearLearner_NUC(dataset, Pi, beta_pi, ndim = ndim, use_IV= False, A_model=A_model)
    rlearner_NUC.fit()
    omega_all_NUC=rlearner_NUC.get_ratio_prediction(state_all)



    '''
    # MIS estimator:
    eta_pi_est_MIS_NUC=0

    for t in range(T):
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)*beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,((p+3)*t+p+1)].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)* MDP[:,((p+3)*t+p+2)]

    eta_pi_est_MIS_NUC=sum(eta_pi_est_MIS_NUC)/n/(T)/(1-gamma)

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    '''

    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC):
      
      phi_result=0
      eta_pi_est_MIS_NUC=0

      for t in range(T):
        if (p==1):
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,4*t].reshape(-1,1),MDP[:,4*t+2].reshape(-1,1))
          #omega_St=omega(MDP[:,4*t].reshape(-1,1),n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,4*t].reshape(-1,1),At=MDP[:,4*t+2].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        else:
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,(p+3)*t+p+1].reshape(-1,1))
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,(p+3)*t+p+1].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(phi_1-phi_2))
        eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(MDP[:,(p+3)*t+p+2]))

      phi_result=phi_result/n/(T)
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC/n/(T)

      return phi_result, eta_pi_est_MIS_NUC


    eta_pi_est_aug_NUC, eta_pi_est_MIS_NUC=phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC)  

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_est_DR_NUC=eta_pi_est_DM_NUC+eta_pi_est_aug_NUC
    print("DRL estimator under NUC: ",eta_pi_est_DR_NUC) 


    return eta_pi_est_MIS_NUC, eta_pi_est_DM_NUC, eta_pi_est_DR_NUC

# %% [markdown]
# #### Run

# %%
import joblib

REP=100
est_IVRL_DR=np.zeros((REP,10))
est_IVRL_DM=np.zeros((REP,10))
est_DM=np.zeros((REP,10))
est_MIS=np.zeros((REP,10))
est_DRL=np.zeros((REP,10))

np.random.seed(526)

n_all=np.array([100,200,300,400,500,600,700,800,900,1000])

for rep in range(30,REP):
  print("rep=",rep,":\n")
  for j in range(10):
  
    # generate MDP
    n=n_all[j]

    # the number of stages
    T=120
    p=2

    S0=generate_S0(n)
    MDP_IVRL = np.copy(S0)
    MDP_NUC = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n)
        Zt=generate_Zt(St,n)
        At=generate_At(St,Zt,Ut,n)
        Rt=generate_Rt(St,At,Ut,n)
        Stplus1=generate_Stplus1(St,At,Ut,n)
        MDP_NUC = np.hstack((MDP_NUC, Zt.reshape(-1,1),Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        MDP_IVRL = np.hstack((MDP_IVRL, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

    T=100
    p=3
    MDP_NUC=MDP_NUC[:,(20*(p+3)):(120*(p+3)+p)]
    MDP_NUC= np.hstack((MDP_NUC, Zt.reshape(-1,1)))
    est_MIS[rep,j],est_DM[rep,j],est_DRL[rep,j]=DRL_NUC_TE_est(MDP_NUC, 3, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)

    p=2
    MDP_IVRL=MDP_IVRL[:,(20*(p+3)):(120*(p+3)+p)]
    est_IVRL_DM[rep,j], est_IVRL_DR[rep,j]=IVRL_TE_est(MDP_IVRL, 2, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)
# Out:
# Streaming output truncated to the last 5000 lines.
# pa model performance (accuracy):  0.7676666666666667
#
# pz model performance (accuracy):  0.728
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73392632  9.32087022  9.29253609 -0.11910555  2.72764917]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.834993333587015
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.533010078522175
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.774
#
# DM estimator under NUC:  24.012089260910944
# MIS estimator under NUC:  29.567900926844214
# DRL estimator under NUC:  24.034273330130727
# pa model performance (accuracy):  0.774
#
# pz model performance (accuracy):  0.7335
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.8535847   9.51568014  9.49191362 -0.17719628  2.78826211]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.321253784616044
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.484235080791777
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7554
#
# DM estimator under NUC:  22.862573834793512
# MIS estimator under NUC:  28.30795074428618
# DRL estimator under NUC:  22.877862059447377
# pa model performance (accuracy):  0.7554
#
# pz model performance (accuracy):  0.7172
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.79956745  9.06941356  9.03887919 -0.13245204  2.7584023 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.147858572745054
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.4946824791920388
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7398333333333333
#
# DM estimator under NUC:  22.2812875055361
# MIS estimator under NUC:  26.72547616890701
# DRL estimator under NUC:  22.369458452118216
# pa model performance (accuracy):  0.7398333333333333
#
# pz model performance (accuracy):  0.7141666666666666
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.57690203  9.39040497  9.36834485 -0.13182317  2.74491812]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.38080243187657
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3465933585166479
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7602857142857142
#
# DM estimator under NUC:  24.113391953799503
# MIS estimator under NUC:  28.50801061893495
# DRL estimator under NUC:  24.189567909604808
# pa model performance (accuracy):  0.7602857142857142
#
# pz model performance (accuracy):  0.7105714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.95972761  9.34589243  9.33425143 -0.12649673  2.74489179]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.52393053719245
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6061918124238715
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7725
#
# DM estimator under NUC:  22.793823459209325
# MIS estimator under NUC:  28.28502050714686
# DRL estimator under NUC:  22.822171752331343
# pa model performance (accuracy):  0.7725
#
# pz model performance (accuracy):  0.737625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.63760728  9.49004065  9.48055704 -0.13990678  2.73476027]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.728802683514314
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.539778418230532
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7627777777777778
#
# DM estimator under NUC:  22.88722727472152
# MIS estimator under NUC:  28.386516328244394
# DRL estimator under NUC:  22.87855389061794
# pa model performance (accuracy):  0.7627777777777778
#
# pz model performance (accuracy):  0.7254444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73783216  9.35620018  9.33476817 -0.13519212  2.74195189]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.98372976708449
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8675386544504857
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7568
#
# DM estimator under NUC:  22.997398752326976
# MIS estimator under NUC:  28.078523212065566
# DRL estimator under NUC:  22.98699071922284
# pa model performance (accuracy):  0.7568
#
# pz model performance (accuracy):  0.7268
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.32498817  9.16537057  9.1223235  -0.1512501   2.76934147]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.74545307579753
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.783866412078475
# Augmentation terms calculation finished.
#
# rep= 67 :
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  20.4529684749611
# MIS estimator under NUC:  24.600472947561233
# DRL estimator under NUC:  20.30551443371182
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.685
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.71753406  9.58582795  9.6045031  -0.13333701  2.68371403]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.490916730449133
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.5095383888619884
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7495
#
# DM estimator under NUC:  22.764170881622917
# MIS estimator under NUC:  26.75572422929698
# DRL estimator under NUC:  22.66383138557858
# pa model performance (accuracy):  0.7495
#
# pz model performance (accuracy):  0.7125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.15646601  9.38931047  9.38348489 -0.157442    2.7538318 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.30748517267544
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.9700961514240777
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7553333333333333
#
# DM estimator under NUC:  23.442424222201772
# MIS estimator under NUC:  28.57963314997955
# DRL estimator under NUC:  23.378281934177327
# pa model performance (accuracy):  0.7553333333333333
#
# pz model performance (accuracy):  0.7193333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.91554437  8.51161275  8.40724357 -0.18768218  2.84492142]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.527835625219588
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4695576985851835
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7615
#
# DM estimator under NUC:  23.474392831787895
# MIS estimator under NUC:  29.315221563148953
# DRL estimator under NUC:  23.4996037847228
# pa model performance (accuracy):  0.7615
#
# pz model performance (accuracy):  0.72975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.79591245  9.24239445  9.21866986 -0.13299469  2.75766164]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.684854375788127
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7191678031344924
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7454
#
# DM estimator under NUC:  22.236155497864736
# MIS estimator under NUC:  26.658434178699714
# DRL estimator under NUC:  22.21359181204643
# pa model performance (accuracy):  0.7454
#
# pz model performance (accuracy):  0.7044
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.47045041  9.39993536  9.37759781 -0.12483495  2.71865423]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.31389635862399
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.41759001378455785
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7573333333333333
#
# DM estimator under NUC:  23.444173873515197
# MIS estimator under NUC:  28.533934508564013
# DRL estimator under NUC:  23.533659897323055
# pa model performance (accuracy):  0.7573333333333333
#
# pz model performance (accuracy):  0.7126666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.20021242  9.21061959  9.15392596 -0.14683635  2.79022897]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.20648587845679
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3424023052147473
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7564285714285715
#
# DM estimator under NUC:  23.2521952268612
# MIS estimator under NUC:  28.22096615874994
# DRL estimator under NUC:  23.201179463572387
# pa model performance (accuracy):  0.7564285714285715
#
# pz model performance (accuracy):  0.7264285714285714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.19007481  9.33547317  9.30415513 -0.16282046  2.78366472]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.766635922898228
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.011006008607667627
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.759625
#
# DM estimator under NUC:  23.129605917312265
# MIS estimator under NUC:  27.995999780730827
# DRL estimator under NUC:  23.12707937139779
# pa model performance (accuracy):  0.759625
#
# pz model performance (accuracy):  0.72375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73304699  9.50670809  9.50087116 -0.13566758  2.72510022]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.35607570487132
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.249333930465267
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7607777777777778
#
# DM estimator under NUC:  22.768699404626716
# MIS estimator under NUC:  27.75327001066056
# DRL estimator under NUC:  22.81855919378892
# pa model performance (accuracy):  0.7607777777777778
#
# pz model performance (accuracy):  0.7142222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.41518069  9.19683223  9.15792744 -0.15450558  2.78182137]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.527613916923354
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.46041114588039883
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7559
#
# DM estimator under NUC:  22.686361566018213
# MIS estimator under NUC:  27.508354964648202
# DRL estimator under NUC:  22.674886906449732
# pa model performance (accuracy):  0.7559
#
# pz model performance (accuracy):  0.7136
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.71705359  9.2938034   9.2784493  -0.1334605   2.75515507]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.81883640552486
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9542238086316552
# Augmentation terms calculation finished.
#
# rep= 68 :
#
# pa model performance (accuracy):  0.788
#
# DM estimator under NUC:  24.103958342321956
# MIS estimator under NUC:  29.92310326801733
# DRL estimator under NUC:  24.136443042758255
# pa model performance (accuracy):  0.788
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.30507762  9.584586    9.5365806  -0.15285021  2.74888817]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.119106602851815
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.2496260253541616
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.738
#
# DM estimator under NUC:  21.484015135981473
# MIS estimator under NUC:  25.63770820864388
# DRL estimator under NUC:  21.42710161253119
# pa model performance (accuracy):  0.738
#
# pz model performance (accuracy):  0.6965
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.60069398  9.27711065  9.18304898 -0.18446301  2.80903186]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.427279112914746
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.919617983261643
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7606666666666667
#
# DM estimator under NUC:  23.784467019968808
# MIS estimator under NUC:  28.014296200073524
# DRL estimator under NUC:  23.73982161869127
# pa model performance (accuracy):  0.7606666666666667
#
# pz model performance (accuracy):  0.708
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.90858786  8.64281817  8.54430815 -0.14211512  2.88215217]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.3277373853206
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.881452158236388
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76525
#
# DM estimator under NUC:  24.115276431648113
# MIS estimator under NUC:  28.739358983556368
# DRL estimator under NUC:  24.173382822382056
# pa model performance (accuracy):  0.76525
#
# pz model performance (accuracy):  0.71025
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.36067957  9.4571338   9.42535938 -0.14738644  2.76037976]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.97921805181269
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8952736075047418
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532
#
# DM estimator under NUC:  22.741695767471338
# MIS estimator under NUC:  27.786662604203443
# DRL estimator under NUC:  22.730395649069624
# pa model performance (accuracy):  0.7532
#
# pz model performance (accuracy):  0.7184
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.3359035   9.30676949  9.26201075 -0.14919801  2.78168977]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.57611644662011
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7298802919923889
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7623333333333333
#
# DM estimator under NUC:  22.87129933696293
# MIS estimator under NUC:  28.109938549141685
# DRL estimator under NUC:  22.83401292921636
# pa model performance (accuracy):  0.7623333333333333
#
# pz model performance (accuracy):  0.7205
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.40860805  9.47382284  9.45202807 -0.139946    2.75229705]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.766605589931537
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6136845763967811
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7562857142857143
#
# DM estimator under NUC:  22.94205410172485
# MIS estimator under NUC:  27.424699843023888
# DRL estimator under NUC:  22.953786399133506
# pa model performance (accuracy):  0.7562857142857143
#
# pz model performance (accuracy):  0.7181428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.96374128  9.13356733  9.08421265 -0.17685162  2.81545969]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.275173426397338
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6975462137042219
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.755125
#
# DM estimator under NUC:  22.737032404984465
# MIS estimator under NUC:  27.97978225108687
# DRL estimator under NUC:  22.691618661136854
# pa model performance (accuracy):  0.755125
#
# pz model performance (accuracy):  0.727625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.31648909  9.57097871  9.55273951 -0.16554473  2.74224663]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.24969454081781
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8813643759835745
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7572222222222222
#
# DM estimator under NUC:  23.23898235159906
# MIS estimator under NUC:  28.396080761642065
# DRL estimator under NUC:  23.312274862463845
# pa model performance (accuracy):  0.7572222222222222
#
# pz model performance (accuracy):  0.723
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.14595199  9.10054466  9.07284967 -0.11673938  2.75044782]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.820937967620864
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.17365615726796169
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7493
#
# DM estimator under NUC:  23.455625510386806
# MIS estimator under NUC:  27.997474572930443
# DRL estimator under NUC:  23.38792561882005
# pa model performance (accuracy):  0.7493
#
# pz model performance (accuracy):  0.7209
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.590957    9.33204548  9.30839379 -0.13823152  2.75176093]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.555651166569113
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3007799803412066
# Augmentation terms calculation finished.
#
# rep= 69 :
#
# pa model performance (accuracy):  0.718
#
# DM estimator under NUC:  24.721547803630912
# MIS estimator under NUC:  31.389521820267067
# DRL estimator under NUC:  24.98700789896084
# pa model performance (accuracy):  0.718
#
# pz model performance (accuracy):  0.691
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87491092  9.56955574  9.56906723 -0.13719334  2.72035184]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.04383346355573
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.310022755646264
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7605
#
# DM estimator under NUC:  23.370087090162805
# MIS estimator under NUC:  27.68907623321445
# DRL estimator under NUC:  23.34484963539197
# pa model performance (accuracy):  0.7605
#
# pz model performance (accuracy):  0.7295
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.27266826  9.06610129  9.03502719 -0.14670148  2.75430188]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.013353849000758
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -20.46755952016897
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.762
#
# DM estimator under NUC:  23.932863173569928
# MIS estimator under NUC:  29.491041739361567
# DRL estimator under NUC:  23.88908684313402
# pa model performance (accuracy):  0.762
#
# pz model performance (accuracy):  0.7206666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.36918413  9.50759182  9.49262674 -0.15060229  2.74279804]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.649223149807323
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.1927030642468277
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.73475
#
# DM estimator under NUC:  22.70940225818573
# MIS estimator under NUC:  27.997386259046166
# DRL estimator under NUC:  22.724905716914996
# pa model performance (accuracy):  0.73475
#
# pz model performance (accuracy):  0.704
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.38515479  9.22556088  9.19072725 -0.15182464  2.76862323]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.517778903062894
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7716952556401612
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7606
#
# DM estimator under NUC:  22.478323838415694
# MIS estimator under NUC:  27.708281518240096
# DRL estimator under NUC:  22.497120864568423
# pa model performance (accuracy):  0.7606
#
# pz model performance (accuracy):  0.726
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.19706258  9.42457726  9.39687339 -0.15171211  2.75629523]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.050449046027957
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.10851435606160738
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7561666666666667
#
# DM estimator under NUC:  23.478976352155623
# MIS estimator under NUC:  28.80087636997296
# DRL estimator under NUC:  23.55056228237239
# pa model performance (accuracy):  0.7561666666666667
#
# pz model performance (accuracy):  0.7238333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.32684458  9.38252448  9.36900191 -0.1582137   2.75180731]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.04218170036261
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6102657933942744
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7702857142857142
#
# DM estimator under NUC:  23.52968969863458
# MIS estimator under NUC:  29.45361620505711
# DRL estimator under NUC:  23.539302485953115
# pa model performance (accuracy):  0.7702857142857142
#
# pz model performance (accuracy):  0.7327142857142858
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.15606474  9.4168196   9.39234732 -0.15475193  2.76009156]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.155127142230214
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.698877061056174
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.759875
#
# DM estimator under NUC:  24.202419524534953
# MIS estimator under NUC:  28.580570838316138
# DRL estimator under NUC:  24.227119399376893
# pa model performance (accuracy):  0.759875
#
# pz model performance (accuracy):  0.71825
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.58629893  9.33444204  9.31674983 -0.14693527  2.75490818]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.303381540954483
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.0896636531655757
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7675555555555555
#
# DM estimator under NUC:  23.40604160665532
# MIS estimator under NUC:  27.984444918876093
# DRL estimator under NUC:  23.42682089242558
# pa model performance (accuracy):  0.7675555555555555
#
# pz model performance (accuracy):  0.7252222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.55302116  9.29795928  9.28123447 -0.15114743  2.75078267]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.36500389926928
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.532485477994963
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7545
#
# DM estimator under NUC:  22.6749718901857
# MIS estimator under NUC:  27.5666243434703
# DRL estimator under NUC:  22.706866125474388
# pa model performance (accuracy):  0.7545
#
# pz model performance (accuracy):  0.7213
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68075526  9.23146915  9.19589307 -0.13316497  2.77716198]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.76530491199125
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3618537462145457
# Augmentation terms calculation finished.
#
# rep= 70 :
#
# pa model performance (accuracy):  0.765
#
# DM estimator under NUC:  23.08241378118602
# MIS estimator under NUC:  30.194979483154725
# DRL estimator under NUC:  23.073994555580555
# pa model performance (accuracy):  0.765
#
# pz model performance (accuracy):  0.735
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.26501863  9.16590207  9.0438241  -0.17538228  2.8910814 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.744523245322185
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.525184887085816
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.743
#
# DM estimator under NUC:  23.41597703753057
# MIS estimator under NUC:  28.715588962830182
# DRL estimator under NUC:  23.393775049627443
# pa model performance (accuracy):  0.7445
#
# pz model performance (accuracy):  0.724
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.93093813  9.2122833   9.10216771 -0.18691326  2.88157315]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.818188261917964
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -5.555710966396877
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  23.373003678380837
# MIS estimator under NUC:  29.13679712394082
# DRL estimator under NUC:  23.447054789299834
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.91131374  9.27610984  9.17748783 -0.18932211  2.86481502]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.950414657861458
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 10.986069387096993
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75475
#
# DM estimator under NUC:  22.04893726047221
# MIS estimator under NUC:  26.95373995611162
# DRL estimator under NUC:  22.043573537630394
# pa model performance (accuracy):  0.75475
#
# pz model performance (accuracy):  0.71975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.67281962  9.20053449  9.16158043 -0.12980999  2.76629284]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.159074603769792
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8340910319480471
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7574
#
# DM estimator under NUC:  23.71876153422274
# MIS estimator under NUC:  29.320388867650095
# DRL estimator under NUC:  23.723652197103934
# pa model performance (accuracy):  0.7574
#
# pz model performance (accuracy):  0.7208
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.97695021  9.29917695  9.26856816 -0.16619309  2.78211714]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.10166277480022
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.1848845871450266
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7521666666666667
#
# DM estimator under NUC:  23.6941460837457
# MIS estimator under NUC:  28.052844704882382
# DRL estimator under NUC:  23.723630636898466
# pa model performance (accuracy):  0.7521666666666667
#
# pz model performance (accuracy):  0.7196666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.58225974  9.39956823  9.33582913 -0.18801937  2.81642457]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.651553394536293
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.8919703805065655
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7441428571428571
#
# DM estimator under NUC:  22.0605353259928
# MIS estimator under NUC:  26.6100420082317
# DRL estimator under NUC:  22.039249519514538
# pa model performance (accuracy):  0.7441428571428571
#
# pz model performance (accuracy):  0.7082857142857143
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76420574  9.27910365  9.27010737 -0.13597794  2.72305616]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.219515232757537
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8763597035244552
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.764
#
# DM estimator under NUC:  22.512415988153112
# MIS estimator under NUC:  27.56715039103419
# DRL estimator under NUC:  22.461274797316857
# pa model performance (accuracy):  0.764
#
# pz model performance (accuracy):  0.727375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.7287641   9.55434213  9.55247017 -0.13394265  2.6974188 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.79522184001339
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3520589855830602
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7488888888888889
#
# DM estimator under NUC:  22.767259816958862
# MIS estimator under NUC:  27.117278684714226
# DRL estimator under NUC:  22.73938177426456
# pa model performance (accuracy):  0.7488888888888889
#
# pz model performance (accuracy):  0.7135555555555556
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.47249592  9.24794064  9.22426859 -0.14644525  2.75335982]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.713704702422273
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9646740851340807
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7608
#
# DM estimator under NUC:  22.38132745386753
# MIS estimator under NUC:  27.892703292880338
# DRL estimator under NUC:  22.402689638023748
# pa model performance (accuracy):  0.7608
#
# pz model performance (accuracy):  0.7226
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.4238685   9.32225297  9.29034813 -0.14642533  2.75762507]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.169446928275022
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.7114204347795918
# Augmentation terms calculation finished.
#
# rep= 71 :
#
# pa model performance (accuracy):  0.804
#
# DM estimator under NUC:  23.8297703346662
# MIS estimator under NUC:  31.257687110568646
# DRL estimator under NUC:  24.058502589374793
# pa model performance (accuracy):  0.803
#
# pz model performance (accuracy):  0.758
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.60180187  9.62897496  9.59656507 -0.16155919  2.77707426]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.83205704562896
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -8.68425747459432
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  22.527280004392228
# MIS estimator under NUC:  27.477629385448182
# DRL estimator under NUC:  22.5371013110707
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.704
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.27312826  8.90201126  8.86038256 -0.13385699  2.79573253]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.299815460127085
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6469228835934782
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7666666666666667
#
# DM estimator under NUC:  22.931437023429254
# MIS estimator under NUC:  28.368423900209947
# DRL estimator under NUC:  22.84845412937857
# pa model performance (accuracy):  0.7663333333333333
#
# pz model performance (accuracy):  0.7243333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.21059301  9.36516936  9.33907857 -0.15058386  2.73532181]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.49658340747321
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.7293011008713295
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7715
#
# DM estimator under NUC:  22.308699061085182
# MIS estimator under NUC:  27.919803669026532
# DRL estimator under NUC:  22.30785761011584
# pa model performance (accuracy):  0.7715
#
# pz model performance (accuracy):  0.71625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.83862019  9.51252009  9.51065236 -0.12945056  2.72061097]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.56486482700401
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3991404427344921
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7486
#
# DM estimator under NUC:  23.582519872340438
# MIS estimator under NUC:  27.65295484066161
# DRL estimator under NUC:  23.598810531230665
# pa model performance (accuracy):  0.7486
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.10092155  9.08924125  9.06727234 -0.11634437  2.76801287]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.212538161581683
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3946578765687536
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7411666666666666
#
# DM estimator under NUC:  22.49582382761478
# MIS estimator under NUC:  27.000624307019425
# DRL estimator under NUC:  22.48162269902217
# pa model performance (accuracy):  0.7411666666666666
#
# pz model performance (accuracy):  0.7036666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.67775563  9.25538024  9.24351597 -0.1398959   2.74246271]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.55721257911412
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.019673278620027
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7512857142857143
#
# DM estimator under NUC:  22.837173070321764
# MIS estimator under NUC:  27.89915604184207
# DRL estimator under NUC:  22.88275897324362
# pa model performance (accuracy):  0.7512857142857143
#
# pz model performance (accuracy):  0.7222857142857143
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.32953813  9.1452555   9.12972164 -0.10938735  2.73280287]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.580851362527575
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.727385188964455
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.757375
#
# DM estimator under NUC:  22.690332566926696
# MIS estimator under NUC:  28.122361394722063
# DRL estimator under NUC:  22.709584307266873
# pa model performance (accuracy):  0.757375
#
# pz model performance (accuracy):  0.73425
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.53754737  9.37935452  9.3649021  -0.14925565  2.7431036 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.59805948008297
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.381896953424524
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7446666666666667
#
# DM estimator under NUC:  23.511054076031982
# MIS estimator under NUC:  27.88311121734399
# DRL estimator under NUC:  23.59972231048679
# pa model performance (accuracy):  0.7446666666666667
#
# pz model performance (accuracy):  0.7034444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.70464368  9.1409746   9.10734347 -0.13435624  2.76813954]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.699229493064113
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.11675836564375713
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7579
#
# DM estimator under NUC:  23.041330394656054
# MIS estimator under NUC:  27.97236717759857
# DRL estimator under NUC:  23.041402879473697
# pa model performance (accuracy):  0.7579
#
# pz model performance (accuracy):  0.7228
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.53066249  9.33541822  9.31225822 -0.14386491  2.75567243]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.00574832275791
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7212084799736828
# Augmentation terms calculation finished.
#
# rep= 72 :
#
# pa model performance (accuracy):  0.735
#
# DM estimator under NUC:  22.956182175166873
# MIS estimator under NUC:  28.99777664931639
# DRL estimator under NUC:  22.769526824628155
# pa model performance (accuracy):  0.735
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.53232797  7.96192905  7.84036586 -0.06921705  2.90169732]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.241556565552926
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.6026050093350745
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.774
#
# DM estimator under NUC:  23.01501003766608
# MIS estimator under NUC:  28.327947022305
# DRL estimator under NUC:  23.072022529818067
# pa model performance (accuracy):  0.774
#
# pz model performance (accuracy):  0.711
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.255562    8.91888391  8.84794521 -0.14525836  2.7846723 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.99322050285585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.94694368820097
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7603333333333333
#
# DM estimator under NUC:  22.73159563541782
# MIS estimator under NUC:  27.864398437405967
# DRL estimator under NUC:  22.762024024483082
# pa model performance (accuracy):  0.7603333333333333
#
# pz model performance (accuracy):  0.7163333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.71202497  9.07684066  8.99174431 -0.13881537  2.78479212]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.261536589091026
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.44020447739626517
# Augmentation terms calculation finished.
#
# ...
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.625909121555665
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.0901644084663964
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7575
#
# DM estimator under NUC:  23.027211762982958
# MIS estimator under NUC:  28.08518104372346
# DRL estimator under NUC:  23.068210372439694
# pa model performance (accuracy):  0.7575
#
# pz model performance (accuracy):  0.7199
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.20408821  9.27564208  9.23892115 -0.16042265  2.76663368]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.639518213949252
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.374504809906125
# Augmentation terms calculation finished.
#
# rep= 85 :
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  24.573754834446248
# MIS estimator under NUC:  30.601459876787903
# DRL estimator under NUC:  24.416055116786744
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.73
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76332006  9.04016661  8.99805646 -0.11352454  2.74776305]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.141034353348154
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.7388829298579314
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.781
#
# DM estimator under NUC:  23.341666216257213
# MIS estimator under NUC:  28.54880714011832
# DRL estimator under NUC:  23.43808013066459
# pa model performance (accuracy):  0.781
#
# pz model performance (accuracy):  0.7475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.77980313  8.52467888  8.37698331 -0.19458053  2.93239055]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.65769865635274
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.34653944919475377
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7546666666666667
#
# DM estimator under NUC:  24.06079930420521
# MIS estimator under NUC:  29.394589925264153
# DRL estimator under NUC:  24.19046863276844
# pa model performance (accuracy):  0.7546666666666667
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.34169838  9.28413606  9.25012012 -0.16237451  2.7364063 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.980961714345383
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.791126044521323
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.767
#
# DM estimator under NUC:  22.986457569102676
# MIS estimator under NUC:  28.41376655712538
# DRL estimator under NUC:  23.05595734189741
# pa model performance (accuracy):  0.767
#
# pz model performance (accuracy):  0.72525
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84324167  9.36899449  9.35878749 -0.11743058  2.76316383]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.28425766708584
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5528702765338082
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7644
#
# DM estimator under NUC:  22.82665366348232
# MIS estimator under NUC:  27.73585934371581
# DRL estimator under NUC:  22.862233014207675
# pa model performance (accuracy):  0.7644
#
# pz model performance (accuracy):  0.7206
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.37361796  9.41458798  9.33294812 -0.17711254  2.81562988]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.68258736926605
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.6510976871624745
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7596666666666667
#
# DM estimator under NUC:  23.324467376021094
# MIS estimator under NUC:  28.34439821626463
# DRL estimator under NUC:  23.332398341779122
# pa model performance (accuracy):  0.7596666666666667
#
# pz model performance (accuracy):  0.7155
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87522808  9.10247713  9.08653683 -0.13132294  2.77680675]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.588385359327066
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5942907321834501
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7514285714285714
#
# DM estimator under NUC:  22.260029675382444
# MIS estimator under NUC:  27.094741433837438
# DRL estimator under NUC:  22.27225340669586
# pa model performance (accuracy):  0.7514285714285714
#
# pz model performance (accuracy):  0.7164285714285714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.54362859  9.63493623  9.6071826  -0.18899377  2.75798366]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.0780054351461
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.65449334162068
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.760125
#
# DM estimator under NUC:  23.749673334557606
# MIS estimator under NUC:  28.792949807229306
# DRL estimator under NUC:  23.804753872624985
# pa model performance (accuracy):  0.760125
#
# pz model performance (accuracy):  0.73075
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.4457831   9.28956183  9.2528775  -0.15300084  2.77227671]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.58929775487808
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1512928005645549
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7531111111111111
#
# DM estimator under NUC:  23.358085379739226
# MIS estimator under NUC:  28.083348134548878
# DRL estimator under NUC:  23.37640187085439
# pa model performance (accuracy):  0.7531111111111111
#
# pz model performance (accuracy):  0.7244444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.24867324  9.36741971  9.33361954 -0.16544202  2.78944986]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.92821282318175
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7114708609818804
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  23.32309851220943
# MIS estimator under NUC:  27.748259801075843
# DRL estimator under NUC:  23.355838115943975
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.7177
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.15937819  9.18799785  9.13870563 -0.1555931   2.78156398]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.940074754565625
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.7000401621421015
# Augmentation terms calculation finished.
#
# rep= 86 :
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  22.48443650565632
# MIS estimator under NUC:  27.538092476260445
# DRL estimator under NUC:  22.592722137205012
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.696
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.93701561  8.95803077  8.90368913 -0.11097611  2.76908579]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.791711645024808
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.548981800819471
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7405
#
# DM estimator under NUC:  22.866254009913245
# MIS estimator under NUC:  28.076951882900115
# DRL estimator under NUC:  22.938131221622555
# pa model performance (accuracy):  0.74
#
# pz model performance (accuracy):  0.732
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.09747449  9.047306    9.03141    -0.10574564  2.74506384]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.32419322496834
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.6809432018538666
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7483333333333333
#
# DM estimator under NUC:  23.18480196922541
# MIS estimator under NUC:  28.109181414103954
# DRL estimator under NUC:  23.167970781671215
# pa model performance (accuracy):  0.7483333333333333
#
# pz model performance (accuracy):  0.7076666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.46089352  9.01560006  8.99200352 -0.10274376  2.77024153]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.061030433324884
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.2711239523550306
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7575
#
# DM estimator under NUC:  22.486071411773896
# MIS estimator under NUC:  27.66573930572687
# DRL estimator under NUC:  22.45566874968419
# pa model performance (accuracy):  0.7575
#
# pz model performance (accuracy):  0.72725
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.05179428  9.23862808  9.1261365  -0.16338814  2.84700973]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.168452982837298
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.930376553057003
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7586
#
# DM estimator under NUC:  22.17463883604141
# MIS estimator under NUC:  27.245912064997636
# DRL estimator under NUC:  22.20304938691733
# pa model performance (accuracy):  0.7586
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.77670945  9.2366423   9.20794344 -0.14051383  2.76436815]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.165388640333205
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.46958203137655985
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.756
#
# DM estimator under NUC:  22.975451639072123
# MIS estimator under NUC:  27.825153153537844
# DRL estimator under NUC:  22.9792297338002
# pa model performance (accuracy):  0.756
#
# pz model performance (accuracy):  0.7191666666666666
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.3995229   9.31032292  9.26487849 -0.13976437  2.76399915]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.979286584726957
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.2665080421325583
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7622857142857142
#
# DM estimator under NUC:  23.435106666501706
# MIS estimator under NUC:  28.617359259646072
# DRL estimator under NUC:  23.387170399423006
# pa model performance (accuracy):  0.7622857142857142
#
# pz model performance (accuracy):  0.7145714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.7901817   9.40315035  9.39682619 -0.13398966  2.71734802]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.69316761589748
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.333845252363982
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.77625
#
# DM estimator under NUC:  23.240623175143188
# MIS estimator under NUC:  28.336266879495334
# DRL estimator under NUC:  23.186776881408058
# pa model performance (accuracy):  0.77625
#
# pz model performance (accuracy):  0.741625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.71725365  9.25626647  9.2277594  -0.13232502  2.75855834]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.404209703788787
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9476730685836368
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7587777777777778
#
# DM estimator under NUC:  22.6322310037291
# MIS estimator under NUC:  27.36236978719381
# DRL estimator under NUC:  22.61187279648859
# pa model performance (accuracy):  0.7587777777777778
#
# pz model performance (accuracy):  0.7191111111111111
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.65866592  9.35703981  9.34256226 -0.13576408  2.74383743]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.784390988653687
# DM estimator calculation finished.
#
# Start calculating augmentation terms:

# %%
import numpy as np
REP=100
mean_IVRL_DR=(np.sum(est_IVRL_DR,0)/REP)
mean_IVRL_DM=(np.sum(est_IVRL_DM,0)/REP)
mean_DM=(np.sum(est_DM,0)/REP)
mean_MIS=(np.sum(est_MIS,0)/REP)
mean_DRL=(np.sum(est_DRL,0)/REP)

Var_IVRL_DR=np.sum((est_IVRL_DR-mean_IVRL_DR)**2,0)/REP
Var_IVRL_DM=np.sum((est_IVRL_DM-mean_IVRL_DM)**2,0)/REP
Var_DM=np.sum((est_DM-mean_DM)**2,0)/REP
Var_MIS=np.sum((est_MIS-mean_MIS)**2,0)/REP
Var_DRL=np.sum((est_DRL-mean_DRL)**2,0)/REP

# %%
MSE_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true)**2,0)/REP
MSE_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true)**2,0)/REP
MSE_DM=np.sum((est_DM-eta_pi_true)**2,0)/REP
MSE_MIS=np.sum((est_MIS-eta_pi_true)**2,0)/REP
MSE_DRL=np.sum((est_DRL-eta_pi_true)**2,0)/REP

Bias_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true),0)/REP
Bias_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true),0)/REP
Bias_DM=np.sum((est_DM-eta_pi_true),0)/REP
Bias_MIS=np.sum((est_MIS-eta_pi_true),0)/REP
Bias_DRL=np.sum((est_DRL-eta_pi_true),0)/REP

# %%
import matplotlib.pyplot as plt
 
trajectory = [200,300,400,500,600,700,800,900,1000]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

#pyl.xlim(0, 20)
#pyl.ylim(0.25, 2)

ax1.plot(trajectory, np.log(MSE_IVRL_DR/eta_pi_true**2)[1:11] ,marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax1.plot(trajectory, np.log(MSE_DM/eta_pi_true**2)[1:11] ,marker='+', linestyle='--', mec='r', mfc='r', label='DM')
ax1.plot(trajectory, np.log(MSE_MIS/eta_pi_true**2)[1:11] ,marker='v', linestyle='-.', mec='r', mfc='r', label='MIS')
ax1.plot(trajectory, np.log(MSE_DRL/eta_pi_true**2)[1:11] ,marker='x', linestyle=':', mec='r', mfc='r', label='DRL')
ax1.set_xlabel("number of trajectories")
ax1.set_title('log (Relative MSE)')

ax2.plot(trajectory, np.log(abs(Bias_IVRL_DR)/abs(eta_pi_true))[1:11],marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax2.plot(trajectory, np.log(abs(Bias_DM)/abs(eta_pi_true))[1:11],marker='+', linestyle='--', mec='r', mfc='r', label='NUC-DM')
ax2.plot(trajectory, np.log(abs(Bias_MIS)/abs(eta_pi_true))[1:11],marker='v', linestyle='-.', mec='r', mfc='r', label='NUC-MIS')
ax2.plot(trajectory, np.log(abs(Bias_DRL)/abs(eta_pi_true))[1:11],marker='x', linestyle=':', mec='r', mfc='r', label='NUC-DRL')
ax2.set_xlabel("number of trajectories")
ax2.set_title('log (Relative Absolute Bias)')
#plt.legend(loc=(1.05,0.4))
plt.legend(loc="best")
plt.text(0, -4.7, "Medium Strength Confounder", ha='center')
#plt.xlim(399, 1001)
plt.show()
