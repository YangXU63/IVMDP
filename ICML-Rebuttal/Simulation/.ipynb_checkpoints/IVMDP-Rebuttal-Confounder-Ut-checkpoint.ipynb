# %% [markdown]
# ## Generate simulation data

# %%
import joblib
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from numpy.ma.core import exp
from scipy.special import expit

# %%
# define some functions to generate the simulation data

def generate_S0(n0):
    S01=np.random.normal(size=n0)
    S02=np.random.normal(size=n0)
    return np.vstack((S01,S02)).T

def generate_Ut(n0):
    return np.random.binomial(size=n0, n=1, p=0.5) - 0.5

def generate_Zt(St,n0):
    p=expit(St[:,0]+St[:,1])
    return np.random.binomial(1,p,size=n0)

def generate_At(St,Zt,Ut,n0):
    p=expit(St[:,0]+St[:,1]+Zt+1*Ut)
    return np.random.binomial(1,p,size=n0)

# 5Ut -> Ut
def generate_Rt(St,At,Ut,n0):
    return (St[:,0]+St[:,1]+2*At+Ut)

def generate_Stplus1(St,At,Ut,n0):
    Stplus11 = St[:,0] + Ut + (At - 0.5)
    Stplus12 = St[:,1] - Ut - (At - 0.5)
    Stplus = np.vstack((Stplus11,Stplus12)).T
    return Stplus

# %%
# generate simulation dataset
# the number of samples
n=10**3
# the number of stages
T=120
p=2


np.random.seed(525)
S0=generate_S0(n)
MDP = np.copy(S0)
St=S0
for i in range(T):
    Ut=generate_Ut(n)
    Zt=generate_Zt(St,n)
    At=generate_At(St,Zt,Ut,n)
    Rt=generate_Rt(St,At,Ut,n)
    Stplus1=generate_Stplus1(St,At,Ut,n)
    MDP = np.hstack((MDP, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
    St=Stplus1


MDP=MDP[:,(20*(p+3)):(120*(p+3)+p)]
print(np.shape(MDP))
# Out:
# (1000, 502)

# %%
pd.DataFrame(MDP)
# Out:
#            0          1    2    3         4          5          6    7    8    \
# 0    -7.665318   5.507090  0.0  0.0 -1.658228  -7.665318   5.507090  1.0  0.0
# 1     9.381374  -7.349269  1.0  1.0  3.532105   9.381374  -7.349269  1.0  1.0
# 2     7.314472  -6.954949  0.0  0.0 -0.140477   6.314472  -5.954949  1.0  1.0
# 3    13.226179 -11.576353  1.0  1.0  4.149827  14.226179 -12.576353  0.0  1.0
# 4     0.545412  -1.115731  0.0  1.0  0.929681   0.545412  -1.115731  1.0  0.0
# ..         ...        ...  ...  ...       ...        ...        ...  ...  ...
# 995   1.640969  -0.121767  1.0  1.0  4.019202   2.640969  -1.121767  0.0  1.0
# 996   7.410351  -7.092512  0.0  1.0  2.817839   8.410351  -8.092512  0.0  0.0
# 997  -0.795136  -0.038623  1.0  0.0 -1.333758  -1.795136   0.961377  0.0  0.0
# 998   8.153053  -7.755844  0.0  0.0 -0.102792   7.153053  -6.755844  1.0  1.0
# 999  -5.126541   3.867136  0.0  0.0 -1.759405  -6.126541   4.867136  0.0  1.0
#
#           9    ...  492  493       494        495        496  497  498  \
# 0   -2.658228  ...  0.0  0.0 -1.658228 -40.665318  38.507090  0.0  0.0
# 1    3.532105  ...  1.0  1.0  4.532105  53.381374 -51.349269  1.0  0.0
# 2    1.859523  ...  0.0  0.0 -0.140477  26.314472 -25.954949  1.0  1.0
# 3    3.149827  ...  1.0  1.0  3.149827  44.226179 -42.576353  0.0  1.0
# 4   -0.070319  ...  1.0  1.0  0.929681  -2.454588   1.884269  0.0  1.0
# ..        ...  ...  ...  ...       ...        ...        ...  ...  ...
# 995  3.019202  ...  1.0  1.0  4.019202  44.640969 -43.121767  0.0  1.0
# 996  0.817839  ...  0.0  0.0 -0.182161  30.410351 -30.092512  1.0  1.0
# 997 -1.333758  ...  0.0  1.0  1.666242 -19.795136  18.961377  0.0  1.0
# 998  1.897208  ...  1.0  1.0  1.897208  12.153053 -11.755844  1.0  1.0
# 999  1.240595  ...  0.0  0.0 -1.759405 -24.126541  22.867136  0.0  0.0
#
#           499        500        501
# 0   -2.658228 -41.665318  39.507090
# 1    1.532105  52.381374 -50.349269
# 2    2.859523  27.314472 -26.954949
# 3    4.149827  45.226179 -43.576353
# 4    1.929681  -1.454588   0.884269
# ..        ...        ...        ...
# 995  3.019202  44.640969 -43.121767
# 996  2.817839  31.410351 -31.092512
# 997  1.666242 -18.795136  17.961377
# 998  1.897208  12.153053 -11.755844
# 999 -0.759405 -24.126541  22.867136
#
# [1000 rows x 502 columns]

# %%
p=2
#Pi=1
gamma=0.9
domain_At=np.array([0,1])
domain_Zt=np.array([0,1])
max_iter=1000
epsilon=5e-4
T=100

# %%
def Pi(St):
    if len(St.shape) == 0:
        raise ValueError("St should be 1d/2d array")

    if len(St.shape) == 1:
        return 1
        #p = expit(St[0]+St[1]+1.5*expit(St[0]+St[1]))
    else:
        return np.ones(np.shape(St)[0])
        #p = expit(St[:,0]+St[:,1]+1.5*expit(St[:,0]+St[:,1]))

# %% [markdown]
# ## true value

# %%
# approximate the true value of eta_pi by MC method
# the first step is to generate a dataset that follows target policy Pi.
# in this case, we specify At=np.ones(n0)*Pi where Pi can be 0 or 1.

np.random.seed(525)
n0=10**5 # the number of trajectories in MC approximation. The larger the better.
T_burn=20
p=2
T=100 # the number of stages
gamma=0.9

eta_pi_true=0
for repp in range(100):

    S0=generate_S0(n0)
    MDP_burn = np.copy(S0)
    St=S0
    for i in range(T_burn):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=generate_At(St,Zt,Ut,n0)
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP_burn = np.hstack((MDP_burn, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

  #print(np.shape(MDP_burn))


    S0=MDP_burn[:,T_burn*(p+3):(T_burn*(p+3)+2)]

    MDP0 = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=np.random.binomial(n=1, p=Pi(St), size=n0) # generate Ai following Pi
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP0 = np.hstack((MDP0, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1
  #MDP0=MDP0[:,(20*(p+3)):(120*(p+3)+p)]
  #print(np.shape(MDP0))

  # true value of $\eta_{\pi}$ can be estimated by MC method:

    for t in range(T):
        eta_pi_true=eta_pi_true+(gamma**(t))*sum(MDP0[:,(p+2)+(p+3)*t])/n0

        
eta_pi_true=eta_pi_true/100
print(eta_pi_true)
# Out:
# 19.995276055376863

# %%
np.shape(Zt)
# Out:
# (100000,)

# %%
pd.DataFrame(MDP0)
# Out:
#              0          1    2    3         4          5          6    7    \
# 0       6.014786  -5.354693  1.0  1.0  2.160093   6.014786  -5.354693  0.0
# 1      13.275657 -10.343086  1.0  1.0  4.432571  13.275657 -10.343086  1.0
# 2      11.096759 -10.223350  1.0  1.0  3.373409  12.096759 -11.223350  1.0
# 3      11.620527  -9.817214  1.0  1.0  4.303313  12.620527 -10.817214  1.0
# 4       8.270191  -7.059221  0.0  1.0  3.710971   9.270191  -8.059221  1.0
# ...          ...        ...  ...  ...       ...        ...        ...  ...
# 99995  -2.687823   1.920101  0.0  1.0  0.732277  -2.687823   1.920101  0.0
# 99996   3.978756  -4.450690  0.0  1.0  2.028066   4.978756  -5.450690  0.0
# 99997  12.216641 -10.047447  1.0  1.0  3.669194  12.216641 -10.047447  1.0
# 99998  -1.366799  -0.603489  0.0  1.0  0.529713  -0.366799  -1.603489  0.0
# 99999   1.335805  -1.943831  0.0  1.0  0.891974   1.335805  -1.943831  0.0
#
#        8         9    ...  492  493       494        495        496  497  498  \
# 0      1.0  2.160093  ...  1.0  1.0  3.160093  51.014786 -50.354693  1.0  1.0
# 1      1.0  5.432571  ...  1.0  1.0  5.432571  64.275657 -61.343086  1.0  1.0
# 2      1.0  2.373409  ...  0.0  1.0  3.373409  55.096759 -54.223350  0.0  1.0
# 3      1.0  4.303313  ...  1.0  1.0  4.303313  59.620527 -57.817214  1.0  1.0
# 4      1.0  3.710971  ...  0.0  1.0  3.710971  53.270191 -52.059221  1.0  1.0
# ...    ...       ...  ...  ...  ...       ...        ...        ...  ...  ...
# 99995  1.0  0.732277  ...  1.0  1.0  1.732277  55.312177 -56.079899  1.0  1.0
# 99996  1.0  1.028066  ...  1.0  1.0  2.028066  50.978756 -51.450690  1.0  1.0
# 99997  1.0  3.669194  ...  1.0  1.0  4.669194  56.216641 -54.047447  1.0  1.0
# 99998  1.0 -0.470287  ...  0.0  1.0 -0.470287  41.633201 -43.603489  0.0  1.0
# 99999  1.0  0.891974  ...  1.0  1.0  1.891974  55.335805 -55.943831  1.0  1.0
#
#             499        500        501
# 0      2.160093  51.014786 -50.354693
# 1      4.432571  64.275657 -61.343086
# 2      3.373409  56.096759 -55.223350
# 3      4.303313  60.620527 -58.817214
# 4      2.710971  53.270191 -52.059221
# ...         ...        ...        ...
# 99995  1.732277  56.312177 -57.079899
# 99996  2.028066  51.978756 -52.450690
# 99997  3.669194  56.216641 -54.047447
# 99998 -0.470287  41.633201 -43.603489
# 99999  0.891974  55.335805 -55.943831
#
# [100000 rows x 502 columns]

# %% [markdown]
# ## comparison

# %% [markdown]
# #### IVRL

# %%
def IVRL_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # IV+MDP. Off policy evaluation: estimate the averaged treatment effect in infinite-horizon MDP settings
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler
    from numpy.linalg import inv, eigvals

    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T

    index_Z=np.linspace(0,T-1,T)*(p+3)+p
    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2
    index_SZ=np.concatenate((index_S,index_Z))

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_SZ=MDP[:,index_SZ.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Zvec=MDP[:,index_Z.astype(int)].T.reshape(-1,1)
    SZvec=np.hstack((Svec,Zvec))
    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s,z) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(SZvec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(SZvec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")
    def Pa(St,Zt,n,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St,Zt]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(np.concatenate((St,np.array([Zt]))).reshape(1, -1))[0]
      else:
        return A_model.predict_proba(np.hstack((St,Zt)))


    ## (2) estimate P11 := p_a(At=1|Zt=1,St)
    def P11(St,n,A_model):
      if (n==1):
        return Pa(St,1,n,A_model)[1]
      else:
        return Pa(St,np.ones(n).reshape(-1,1),n,A_model)[:,1]

    ## (3) estimate P10 := p_a(At=1|Zt=0,St)
    def P10(St,n,A_model):
      if (n==1):
        return Pa(St,0,n,A_model)[1]
      else:
        return Pa(St,np.zeros(n).reshape(-1,1),n,A_model)[:,1]

    ## (4) estimate c(Zt|St)
    def c(Zt,St,n,Pi,A_model):
      #ratio = np.clip(ratio, a_min=-100, a_max=100)
      if (n==1):
        c=Zt*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c
        return np.clip(c, a_min=-50, a_max=50)
      else:
        c=Zt.T*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt.T)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c[0]
        return np.clip(c[0], a_min=-50, a_max=50)

    ## (5) estimate pz(Zt|St)
    Z_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #Z_model = LogisticRegression()
    Z_model.fit(Svec[range(int(n*T*0.9))], Zvec[range(int(n*T*0.9))].reshape(1,-1)[0])
    print("pz model performance (accuracy): ", Z_model.score(Svec[range(int(n*T*0.9),n*T)], Zvec[range(int(n*T*0.9),n*T)], sample_weight=None),"\n")

    def Pz(Zt,St,n,Z_model):
      if ((n==1) and (p==1)):
        return Z_model.predict_proba(np.array([St]).reshape(1, -1))[0][int(Zt)]
      elif ((n==1) and (p!=1)):
        return Z_model.predict_proba(St.reshape(1, -1))[0][int(Zt)]
      else:
        return Z_model.predict_proba(St)[:,1]*Zt.T[0] + Z_model.predict_proba(St)[:,0]*(1-Zt.T[0])




    ## (6) estimate $\rho(Z_t,S_t)$
    def rho(St,Zt,n,Pi,A_model):
      return c(Zt,St,n,Pi,A_model)/Pz(Zt,St,n,Z_model)

    print("Start estimating omega_pi(St):")
    ## (7) estimate $\omega^{\pi}(s)$: should change if St continuous, and here we only specify linear function class for xi
    class RatioLinearLearner:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, time_difference=None, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=True, rho=rho, A_model=A_model, truncate=100, domain_Zt=np.array([0,1]), domain_At=np.array([0,1])):
            self.use_IV = use_IV

            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])
            if use_IV:
                self.IV = np.copy(dataset['IV']).reshape(-1, 1)
            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)

            self.Pi = Pi

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                ratio = rho(self.state,self.IV,len(self.action),self.Pi,A_model)
            #else:
                  #estimate_pa = self.PALearner.get_pa_prediction(self.state, self.action)
                  #target_pa = self.target_policy_pa(self.policy, self.state, self.action)
                  #pa_ratio = target_pa / estimate_pa
                  #ratio = pa_ratio

            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)

    state_all=Svec
    IV=Zvec.T[0]
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, IV, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action, 'IV': IV,
            'reward': reward, 
            "next_state": next_state_all}

    
    rlearner = RatioLinearLearner(dataset, Pi, ndim = ndim, use_IV= True, rho=rho, A_model=A_model)
    rlearner.fit()
    omega_all=rlearner.get_ratio_prediction(state_all)

    print("omega_pi(St) estimation finished.\n")


    print("Start estimating Q function and Value function (fitted Q evaluation):")
    ## (8) estimate Q function: we only specify Q as a linear function of (St,Zt,At). Can be generalized later.
    # Q function: a linear function of (St,Zt,At). Can be modified later.
    def Q(beta,n,St,Zt,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,Zt,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([Zt]),np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,Zt,At)),beta)################################3

    ## (9) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta, domain_Zt, domain_At, A_model):
      len_Zt=len(domain_Zt)
      len_At=len(domain_At)
      if (n==1):
        V_St=0
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q(beta,n,St,domain_Zt[i],domain_At[j])
            #V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q_model.predict(np.concatenate((St,np.array([domain_Zt[i]]),np.array([domain_At[j]]))))
      else:
        V_St=np.zeros(n)
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i]*np.ones(n).reshape(-1,1),St,n,Pi,A_model)*Pa(St,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]*Q(beta,n,St,domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1))
            #V_St=V_St+c(np.ones(n)*domain_Zt[i].reshape(-1,1),St,n,Pi,A_model)*Pa(St,np.ones(n)*domain_Zt[i].reshape(-1,1),n,A_model)[:,j]*Q_model.predict(np.hstack((St,np.ones(n)*domain_Zt[i].reshape(-1,1),np.ones(n)*domain_At[j].reshape(-1,1))))

      return V_St

    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+2
    nall=n*T
    len_Zt=len(domain_Zt)
    len_At=len(domain_At)
    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p+2)]),axis=1)

      f_tplus1_Q=np.zeros((n,nfeatures+1))
      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      for i in range(len_Zt):
        for j in range(len_At):
          xi_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)],domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1)),axis=1)
          coef_Q=c(domain_Zt[i]*np.ones(n).reshape(-1,1),Stplus1,n,Pi,A_model)*Pa(Stplus1,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]
          f_tplus1_Q=f_tplus1_Q+xi_tplus1_Q* coef_Q[:, np.newaxis]

      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q=np.linalg.solve(part1_Q,part2_Q)

    print("Estimated beta_Q is: ", beta_Q)
    print("Q function and Value function estimation finished.\n")


    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q):
      
      phi_result=0
      #phi_result_part1=0
      #phi_result_part2=0

      for t in range(T):
        if (p==1):
          Pa_At=Pa(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=MDP[i,4*t+1],At=a)

          phi_3=MDP[:,4*t+2]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          #delta_a=np.clip(delta_a, a_min=-50, a_max=50)
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,4*t],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega) !!!!!!!!!!!!!!!
          rho_StZt=rho(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        else:
          Pa_At=Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=MDP[i,(p+3)*t+p],At=a)

          phi_3=MDP[:,(p+3)*t+p+1]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          rho_StZt=rho(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        
        
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2+phi_3))

        #phi_result_part1=phi_result_part1+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2))
        #phi_result_part2=phi_result_part2+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*phi_3)

      phi_result=phi_result/n/(T)
      #phi_result_part1=phi_result_part1/n/(T)
      #phi_result_part2=phi_result_part2/n/(T)

      return phi_result


    print("Start calculating DM estimator:")
    # calculate the direct estimator
    eta_pi_DM=0
    for i in range(n):
      for z in range(2):
        for a in range(2):
          eta_pi_DM=eta_pi_DM+c(Zt=z,St=MDP[i,0:p],n=1,Pi=Pi,A_model=A_model)*Pa(Zt=z,St=MDP[i,0:p],n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,0:p],Zt=z,At=a)
    eta_pi_DM=eta_pi_DM/n
    print("DM estimator: eta_pi_DM=", eta_pi_DM)
    print("DM estimator calculation finished.\n")

    print("Start calculating augmentation terms:")
    # calculate the augmentation terms by function phi_aug
    eta_pi_aug=phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q)
    print("Augmentation term: eta_pi_aug=", eta_pi_aug)
    print("Augmentation terms calculation finished.\n")

    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_DR=eta_pi_DM+eta_pi_aug
    
    return eta_pi_DM, eta_pi_DR

# %% [markdown]
# #### Other methods: NUC

# %%
def DRL_NUC_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # Double reinforcement learning with NO unmeasured confounders. 
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv, eigvals



    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T


    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(Svec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(Svec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")


    def Pa(St,n,p,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(St.reshape(1, -1))[0]
      else:
        return A_model.predict_proba(St)

    #from scipy.interpolate import BSpline


    ## (9) estimate Q function: we only specify Q as a linear function of (St,At). Can be generalized later.
    # Q function: a linear function of (St,At). Can be modified later.
    def Q(beta,n,St,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,At)),beta)################################3

    ## (10) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta):
      # deterministic policy Pi: here we just test Pi=1. The whole function can be generalized to random policy later.
      if (n==1):
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=1)[0])
      else:
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=n).reshape(-1,1))

      return V_St


    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+1
    nall=n*T

    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,((p+3)*t+p+1)].reshape(-1,1)),axis=1)

      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      f_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),Stplus1,np.random.binomial(n=1, p=Pi(MDP[:,(p+3)*t:((p+3)*t+p)]), size=n).reshape(-1,1)),axis=1)


      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q_NUC=np.linalg.solve(part1_Q,part2_Q)

    # DM estimator:
    eta_pi_est_DM_NUC=0
    for i in range(n):
      eta_pi_est_DM_NUC=eta_pi_est_DM_NUC+V(MDP[i,0:p],1,Pi,beta_Q_NUC) # corre
    eta_pi_est_DM_NUC=eta_pi_est_DM_NUC/n

    print("DM estimator under NUC: ",eta_pi_est_DM_NUC) 


    ## (7) estimate beta_pi
    def beta_pi(St,At,p,n,Pi,A_model):
      if (n==1):
        return (Pi(St)*At+(1-Pi(St))*(1-At))/(Pa(St,1,2,A_model)[int(At)])
      else:
        return (Pi(St)*At.T[0]+(1-Pi(St))*(1-At.T[0]))/(At.T[0]*Pa(St,n,2,A_model)[:,1]+(1-At.T[0])*Pa(St,n,2,A_model)[:,0])


    ## (8) estimate $\omega^{\pi}(s)$: here we only specify linear function class for xi
    # -*- coding: utf-8 -*-

    import numpy as np
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler

    class RatioLinearLearner_NUC:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=False, truncate=100):
            self.use_IV=use_IV
            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])

            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)
            self.beta_pi=beta_pi
            self.Pi = Pi
            self.A_model = A_model

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                rho(self.state,self.IV.reshape(-1,1),len(self.action),self.Pi,A_model)
            else:
                ratio = beta_pi(self.state, self.action,p,n,self.Pi,self.A_model)

            # print(np.mean(ratio)) # close to 1 if behaviour and target are the same
            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            # design_matrix = np.zeros((psi.shape[1], psi.shape[1]))
            # for i in range(self.state.shape[0]):
            #     design_matrix += np.matmul(psi[i].reshape(-1, 1), psi_minus_psi_next[i].reshape(1, -1))
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))  
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)


    state_all=Svec
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action,
            'reward': reward, 
            "next_state": next_state_all}

    #dataset, policy, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=100,
    rlearner_NUC = RatioLinearLearner_NUC(dataset, Pi, beta_pi, ndim = ndim, use_IV= False, A_model=A_model)
    rlearner_NUC.fit()
    omega_all_NUC=rlearner_NUC.get_ratio_prediction(state_all)



    '''
    # MIS estimator:
    eta_pi_est_MIS_NUC=0

    for t in range(T):
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)*beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,((p+3)*t+p+1)].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)* MDP[:,((p+3)*t+p+2)]

    eta_pi_est_MIS_NUC=sum(eta_pi_est_MIS_NUC)/n/(T)/(1-gamma)

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    '''

    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC):
      
      phi_result=0
      eta_pi_est_MIS_NUC=0

      for t in range(T):
        if (p==1):
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,4*t].reshape(-1,1),MDP[:,4*t+2].reshape(-1,1))
          #omega_St=omega(MDP[:,4*t].reshape(-1,1),n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,4*t].reshape(-1,1),At=MDP[:,4*t+2].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        else:
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,(p+3)*t+p+1].reshape(-1,1))
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,(p+3)*t+p+1].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(phi_1-phi_2))
        eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(MDP[:,(p+3)*t+p+2]))

      phi_result=phi_result/n/(T)
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC/n/(T)

      return phi_result, eta_pi_est_MIS_NUC


    eta_pi_est_aug_NUC, eta_pi_est_MIS_NUC=phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC)  

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_est_DR_NUC=eta_pi_est_DM_NUC+eta_pi_est_aug_NUC
    print("DRL estimator under NUC: ",eta_pi_est_DR_NUC) 


    return eta_pi_est_MIS_NUC, eta_pi_est_DM_NUC, eta_pi_est_DR_NUC

# %% [markdown]
# #### Run

# %%
import joblib

REP=100
est_IVRL_DR=np.zeros((REP,10))
est_IVRL_DM=np.zeros((REP,10))
est_DM=np.zeros((REP,10))
est_MIS=np.zeros((REP,10))
est_DRL=np.zeros((REP,10))

n_all=np.array([100,200,300,400,500,600,700,800,900,1000])

for rep in range(0,REP):
  print("rep=",rep,":\n")
  for j in range(10):
    np.random.seed(rep*10+j)  
    # generate MDP
    n=n_all[j]

    # the number of stages
    T=120
    p=2

    S0=generate_S0(n)
    MDP_IVRL = np.copy(S0)
    MDP_NUC = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n)
        Zt=generate_Zt(St,n)
        At=generate_At(St,Zt,Ut,n)
        Rt=generate_Rt(St,At,Ut,n)
        Stplus1=generate_Stplus1(St,At,Ut,n)
        MDP_NUC = np.hstack((MDP_NUC, Zt.reshape(-1,1),Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        MDP_IVRL = np.hstack((MDP_IVRL, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

    T=100
    p=3
    MDP_NUC=MDP_NUC[:,(20*(p+3)):(120*(p+3)+p)]
    MDP_NUC= np.hstack((MDP_NUC, Zt.reshape(-1,1)))
    est_MIS[rep,j],est_DM[rep,j],est_DRL[rep,j]=DRL_NUC_TE_est(MDP_NUC, 3, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)

    p=2
    MDP_IVRL=MDP_IVRL[:,(20*(p+3)):(120*(p+3)+p)]
    est_IVRL_DM[rep,j], est_IVRL_DR[rep,j]=IVRL_TE_est(MDP_IVRL, 2, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)
# Out:
# rep= 87 :
#
# pa model performance (accuracy):  0.796
#
# DM estimator under NUC:  22.547916151272357
# MIS estimator under NUC:  28.485108614691622
# DRL estimator under NUC:  22.58230647679702
# pa model performance (accuracy):  0.796
#
# pz model performance (accuracy):  0.728
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [19.02827874  9.45098416  9.46594992  0.03058764  2.20170267]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.529698427297085
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.173389955755934
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7565
#
# DM estimator under NUC:  21.079529104915263
# MIS estimator under NUC:  28.38896896320668
# DRL estimator under NUC:  21.0990348336839
# pa model performance (accuracy):  0.7565
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.77248862  9.73636532  9.71772154 -0.04310695  2.29447204]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.98730527578674
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.240368935918996
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.768
#
# DM estimator under NUC:  20.977864726275524
# MIS estimator under NUC:  27.60706547616194
# DRL estimator under NUC:  20.9711834646343
# pa model performance (accuracy):  0.768
#
# pz model performance (accuracy):  0.7363333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68441545  9.70236473  9.68612119 -0.04700468  2.25141089]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.982216761638618
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.18381251619338612
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.753
#
# DM estimator under NUC:  20.534762721660535
# MIS estimator under NUC:  25.202366107883712
# DRL estimator under NUC:  20.565456947759724
# pa model performance (accuracy):  0.753
#
# pz model performance (accuracy):  0.71475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76316699  9.81396649  9.81336331 -0.05087052  2.23987652]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.404872666283012
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.529007893149122
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76
#
# DM estimator under NUC:  20.516888182265205
# MIS estimator under NUC:  25.990100562811158
# DRL estimator under NUC:  20.52226278817857
# pa model performance (accuracy):  0.76
#
# pz model performance (accuracy):  0.706
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.81342799  9.46290598  9.43782555 -0.04965631  2.28155026]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.50622051757327
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.460212885153918
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7621666666666667
#
# DM estimator under NUC:  21.716340848042837
# MIS estimator under NUC:  27.03714075454677
# DRL estimator under NUC:  21.73612686585219
# pa model performance (accuracy):  0.7621666666666667
#
# pz model performance (accuracy):  0.7313333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.0315028   9.75566377  9.75048627 -0.03813929  2.23951352]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.917728622564237
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.15564920067839766
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.753
#
# DM estimator under NUC:  21.592318972284
# MIS estimator under NUC:  26.10899189519733
# DRL estimator under NUC:  21.594720620092176
# pa model performance (accuracy):  0.753
#
# pz model performance (accuracy):  0.7151428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84260959  9.7658664   9.7589366  -0.04840504  2.25276314]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.596330959005535
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7273529154977736
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76325
#
# DM estimator under NUC:  21.280052190724923
# MIS estimator under NUC:  27.60084104947009
# DRL estimator under NUC:  21.284019665610035
# pa model performance (accuracy):  0.76325
#
# pz model performance (accuracy):  0.727375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.78694806  9.76561791  9.7529626  -0.05092144  2.25321185]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.218817458485344
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.35157181867811216
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7511111111111111
#
# DM estimator under NUC:  21.198041967092916
# MIS estimator under NUC:  26.202546528622
# DRL estimator under NUC:  21.20491582491561
# pa model performance (accuracy):  0.7511111111111111
#
# pz model performance (accuracy):  0.7165555555555555
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.91411536  9.79391321  9.79350298 -0.0440499   2.24269126]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.274487153940544
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6069296995846183
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7572
#
# DM estimator under NUC:  21.19386875899331
# MIS estimator under NUC:  26.21754951016843
# DRL estimator under NUC:  21.20329051084107
# pa model performance (accuracy):  0.7572
#
# pz model performance (accuracy):  0.7192
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87230022  9.76689172  9.76243969 -0.04788795  2.24381705]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.218204561868856
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.652246333088346
# Augmentation terms calculation finished.
#
# rep= 88 :
#
# pa model performance (accuracy):  0.739
#
# DM estimator under NUC:  20.579767486270836
# MIS estimator under NUC:  26.03944158270055
# DRL estimator under NUC:  20.616472812602886
# pa model performance (accuracy):  0.739
#
# pz model performance (accuracy):  0.726
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.16609305 10.0017294   9.9816627  -0.10135878  2.29542889]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.6366241415149
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -5.68303931162633
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  21.46865144131243
# MIS estimator under NUC:  26.248489523243894
# DRL estimator under NUC:  21.478011937732578
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7195
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73738684  9.73473451  9.71877081 -0.05391549  2.27175522]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.316219383588585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.2045256274357083
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  20.588742948100563
# MIS estimator under NUC:  25.8720497890676
# DRL estimator under NUC:  20.601622141195257
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.95675216  9.7527684   9.74427861 -0.04006321  2.24997086]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.700065919104514
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.10906519682489031
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76325
#
# DM estimator under NUC:  22.110335346036695
# MIS estimator under NUC:  27.412746640820327
# DRL estimator under NUC:  22.101844640403893
# pa model performance (accuracy):  0.76325
#
# pz model performance (accuracy):  0.71975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80233501  9.72807371  9.71719871 -0.04909848  2.25102508]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.098254859948565
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3700565045202982
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7606
#
# DM estimator under NUC:  20.88403217965379
# MIS estimator under NUC:  26.16226233696972
# DRL estimator under NUC:  20.89822443955379
# pa model performance (accuracy):  0.7606
#
# pz model performance (accuracy):  0.7172
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.29199039  9.03226103  8.99857604 -0.02944382  2.28917858]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.462156299924963
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.9707231144715962
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7628333333333334
#
# DM estimator under NUC:  21.228625674674106
# MIS estimator under NUC:  27.312210167992074
# DRL estimator under NUC:  21.235760003432414
# pa model performance (accuracy):  0.7628333333333334
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.70310874  9.55625123  9.52798049 -0.05271997  2.27838106]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.099352690275822
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.48886841277029885
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7485714285714286
#
# DM estimator under NUC:  21.14907721960117
# MIS estimator under NUC:  26.123618547855152
# DRL estimator under NUC:  21.155296536374323
# pa model performance (accuracy):  0.7485714285714286
#
# pz model performance (accuracy):  0.7075714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.69106413  9.76658602  9.75286204 -0.05537333  2.26277421]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.972487277988915
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3391780578319898
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.755125
#
# DM estimator under NUC:  20.96656839610661
# MIS estimator under NUC:  26.933342365319234
# DRL estimator under NUC:  20.97068888435679
# pa model performance (accuracy):  0.755125
#
# pz model performance (accuracy):  0.719125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74980487  9.81815748  9.81178808 -0.0522856   2.25146338]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.826800625670664
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.01869438374651999
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7573333333333333
#
# DM estimator under NUC:  21.296813572798577
# MIS estimator under NUC:  26.70612288252416
# DRL estimator under NUC:  21.307858861388628
# pa model performance (accuracy):  0.7573333333333333
#
# pz model performance (accuracy):  0.7136666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.99039974  9.72353884  9.71854241 -0.04251833  2.25014049]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.446340620785158
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.06367906711528334
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7529
#
# DM estimator under NUC:  21.342931762586343
# MIS estimator under NUC:  26.99019882674258
# DRL estimator under NUC:  21.335071522763837
# pa model performance (accuracy):  0.7529
#
# pz model performance (accuracy):  0.7131
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80908657  9.75706579  9.74322923 -0.04794753  2.25500017]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.298494221051737
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6856359931585483
# Augmentation terms calculation finished.
#
# rep= 89 :
#
# pa model performance (accuracy):  0.755
#
# DM estimator under NUC:  21.020058583923674
# MIS estimator under NUC:  26.62925709561769
# DRL estimator under NUC:  21.042326756296674
# pa model performance (accuracy):  0.755
#
# pz model performance (accuracy):  0.731
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.46637145 10.070444   10.06415874 -0.06051158  2.26601691]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.590436386435872
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.839713972012506
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.723
#
# DM estimator under NUC:  20.47936120220538
# MIS estimator under NUC:  25.1722341792809
# DRL estimator under NUC:  20.490584407138304
# pa model performance (accuracy):  0.723
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.89292659  9.70506437  9.69480089 -0.04218756  2.25570067]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.459712512424737
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.37364735149429235
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.756
#
# DM estimator under NUC:  21.166638068667908
# MIS estimator under NUC:  25.974989076515676
# DRL estimator under NUC:  21.16047481228572
# pa model performance (accuracy):  0.756
#
# pz model performance (accuracy):  0.7073333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.82576146  9.76584284  9.75663257 -0.04197332  2.24634578]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.164265938719357
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.363716648589587
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  20.52221260914102
# MIS estimator under NUC:  25.691249057801475
# DRL estimator under NUC:  20.52451682150693
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.71125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84887624  9.79902931  9.79487575 -0.04895027  2.24859026]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.492373049946064
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3102531969016357
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  21.07627989241115
# MIS estimator under NUC:  25.791442929576306
# DRL estimator under NUC:  21.081756387173737
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.78460592  9.79704229  9.78556182 -0.05138356  2.25751574]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.00228206505447
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.11881843511367879
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7595
#
# DM estimator under NUC:  21.450244809085845
# MIS estimator under NUC:  27.453301914325163
# DRL estimator under NUC:  21.440819369191594
# pa model performance (accuracy):  0.7595
#
# pz model performance (accuracy):  0.7163333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80215417  9.75931543  9.74658284 -0.04723323  2.25278449]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.445286166286266
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8892492123907823
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7565714285714286
#
# DM estimator under NUC:  20.964198874320175
# MIS estimator under NUC:  25.70271791405956
# DRL estimator under NUC:  20.976872476545218
# pa model performance (accuracy):  0.7565714285714286
#
# pz model performance (accuracy):  0.7177142857142857
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68799903  9.73043225  9.70938394 -0.05392653  2.27388641]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.803406318743875
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6598735976879004
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751375
#
# DM estimator under NUC:  21.98746920603295
# MIS estimator under NUC:  26.24464145787397
# DRL estimator under NUC:  21.99513879461357
# pa model performance (accuracy):  0.751375
#
# pz model performance (accuracy):  0.713375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.89489111  9.7914361   9.7880545  -0.04666765  2.24576715]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.055460458594833
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3115765238475527
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  21.567481923565627
# MIS estimator under NUC:  27.32082797796097
# DRL estimator under NUC:  21.57424248921016
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7247777777777777
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.66100744  9.79743861  9.78430757 -0.05617748  2.25627947]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.381909234035906
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.28686776873810155
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7544
#
# DM estimator under NUC:  21.01122308560155
# MIS estimator under NUC:  26.337640801678504
# DRL estimator under NUC:  21.021647345194395
# pa model performance (accuracy):  0.7544
#
# pz model performance (accuracy):  0.7158
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.81794525  9.82936808  9.82459614 -0.04532073  2.24363478]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.02604456531375
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2976770919215204
# Augmentation terms calculation finished.
#
# rep= 90 :
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  19.069350723261643
# MIS estimator under NUC:  24.971251144682117
# DRL estimator under NUC:  19.06907283994259
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.737
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.39211831  9.65964414  9.63463749 -0.05640861  2.25971463]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.601878870533852
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.24524018577817253
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7425
#
# DM estimator under NUC:  21.165427775585684
# MIS estimator under NUC:  26.24936757962733
# DRL estimator under NUC:  21.169654792829913
# pa model performance (accuracy):  0.7425
#
# pz model performance (accuracy):  0.704
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68295057  9.65718086  9.63826142 -0.05170267  2.25751201]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.056022951482245
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.15671442612133743
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  21.173518526877107
# MIS estimator under NUC:  26.180256837871084
# DRL estimator under NUC:  21.214608229096207
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7043333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.94056464  9.65082642  9.6344622  -0.03606699  2.26569635]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.283675493615657
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.5323593368638391
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7625
#
# DM estimator under NUC:  21.30020265262572
# MIS estimator under NUC:  25.589304447429203
# DRL estimator under NUC:  21.34425969520178
# pa model performance (accuracy):  0.7625
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.94895021  9.68418796  9.67374795 -0.04303278  2.24898494]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.31540439065688
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2555882008974582
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7704
#
# DM estimator under NUC:  21.13512816227616
# MIS estimator under NUC:  26.707545383470755
# DRL estimator under NUC:  21.138919814577893
# pa model performance (accuracy):  0.7704
#
# pz model performance (accuracy):  0.7278
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.91429592  9.7937962   9.78873994 -0.04758109  2.25711791]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.144728091752437
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.38113174638581954
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7528333333333334
#
# DM estimator under NUC:  20.453203510241323
# MIS estimator under NUC:  25.80633683008908
# DRL estimator under NUC:  20.450269510597728
# pa model performance (accuracy):  0.7528333333333334
#
# pz model performance (accuracy):  0.718
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87589648  9.7747995   9.76783413 -0.04611844  2.24934743]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.456907414545586
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9065612872823638
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7644285714285715
#
# DM estimator under NUC:  21.62902408891805
# MIS estimator under NUC:  27.19505008105124
# DRL estimator under NUC:  21.627219603753126
# pa model performance (accuracy):  0.7644285714285715
#
# pz model performance (accuracy):  0.7175714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87604205  9.73456168  9.72482724 -0.04354381  2.24887689]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.640689584336332
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5656373626335561
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  20.586052308056292
# MIS estimator under NUC:  25.519705726671322
# DRL estimator under NUC:  20.589994515290623
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.7165
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.9617517   9.58316209  9.56828177 -0.04194713  2.26500026]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.716170322775213
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.47304040739299524
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532222222222222
#
# DM estimator under NUC:  20.918573964257817
# MIS estimator under NUC:  26.33762859078537
# DRL estimator under NUC:  20.93512581754556
# pa model performance (accuracy):  0.7532222222222222
#
# pz model performance (accuracy):  0.7192222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.93642031  9.794248    9.79216914 -0.04417691  2.24031003]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.001575769079597
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3071645961464482
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7509
#
# DM estimator under NUC:  21.5476281201707
# MIS estimator under NUC:  26.76856532209354
# DRL estimator under NUC:  21.553735373043317
# pa model performance (accuracy):  0.7509
#
# pz model performance (accuracy):  0.7166
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.83049077  9.72659702  9.71271118 -0.04679989  2.26089482]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.524224310085664
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5631026783713979
# Augmentation terms calculation finished.
#
# rep= 91 :
#
# pa model performance (accuracy):  0.747
#
# DM estimator under NUC:  22.652918183531245
# MIS estimator under NUC:  27.382144403477284
# DRL estimator under NUC:  22.690949786574
# pa model performance (accuracy):  0.747
#
# pz model performance (accuracy):  0.702
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.771269    9.83667824  9.83911227 -0.04170339  2.23132556]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.63760397708666
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.6131045845606491
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7415
#
# DM estimator under NUC:  20.30500509956651
# MIS estimator under NUC:  25.191065210668445
# DRL estimator under NUC:  20.362614516757798
# pa model performance (accuracy):  0.7415
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74751154  9.84322404  9.84094122 -0.04884981  2.24608075]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.234931306228
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.10609046323081812
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  20.655529977263964
# MIS estimator under NUC:  26.390359241845857
# DRL estimator under NUC:  20.718948979760047
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7183333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.81300795  9.76861178  9.76811814 -0.04853981  2.24090159]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.604550839580465
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.14603745039080981
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7435
#
# DM estimator under NUC:  20.358554798115804
# MIS estimator under NUC:  26.68354043019905
# DRL estimator under NUC:  20.365897492297915
# pa model performance (accuracy):  0.7435
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.70649415  9.7704749   9.76222064 -0.05344566  2.25540486]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.17025686726802
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2151578602868252
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532
#
# DM estimator under NUC:  20.57979736559112
# MIS estimator under NUC:  25.88481300128954
# DRL estimator under NUC:  20.58837905114369
# pa model performance (accuracy):  0.7532
#
# pz model performance (accuracy):  0.7236
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.92331072  9.76446152  9.75811526 -0.04155993  2.2461424 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.626855654194483
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7853295048945945
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7576666666666667
#
# DM estimator under NUC:  20.623343982668192
# MIS estimator under NUC:  26.25323522369495
# DRL estimator under NUC:  20.64800687469369
# pa model performance (accuracy):  0.7576666666666667
#
# pz model performance (accuracy):  0.7215
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.78402384  9.75842963  9.74688459 -0.05137279  2.25549732]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.53898154276827
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1096469983094928
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  20.49094342892551
# MIS estimator under NUC:  26.623649596661267
# DRL estimator under NUC:  20.485382629613706
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.7178571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.98388708  9.72301095  9.71362534 -0.04557894  2.25170959]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.546247959438826
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.01684555459553335
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75575
#
# DM estimator under NUC:  20.756522622916965
# MIS estimator under NUC:  25.652240345724408
# DRL estimator under NUC:  20.746956997671248
# pa model performance (accuracy):  0.75575
#
# pz model performance (accuracy):  0.712625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84470937  9.7751726   9.76567361 -0.04447429  2.25350099]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.772180822305337
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2712446600558175
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7442222222222222
#
# DM estimator under NUC:  20.3297997330329
# MIS estimator under NUC:  25.5337594894367
# DRL estimator under NUC:  20.35052469103699
# pa model performance (accuracy):  0.7442222222222222
#
# pz model performance (accuracy):  0.713
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.51943328  9.73627846  9.71039302 -0.05720978  2.27711626]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.976420439513273
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.927457156363013
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75
#
# DM estimator under NUC:  20.698875331039922
# MIS estimator under NUC:  25.786931904976722
# DRL estimator under NUC:  20.7062451333437
# pa model performance (accuracy):  0.75
#
# pz model performance (accuracy):  0.7186
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74508816  9.77261696  9.75641817 -0.04900484  2.25883463]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.590784822210434
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7229516652805983
# Augmentation terms calculation finished.
#
# rep= 92 :
#
# pa model performance (accuracy):  0.758
#
# DM estimator under NUC:  19.366034604140182
# MIS estimator under NUC:  26.084552128790506
# DRL estimator under NUC:  19.305760610276298
# pa model performance (accuracy):  0.758
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.83256396  9.50126758  9.48041561 -0.04588811  2.30214965]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.120871858922687
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.8821630923671286
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.724
#
# DM estimator under NUC:  20.724259293103906
# MIS estimator under NUC:  25.372084824966702
# DRL estimator under NUC:  20.712497236910544
# pa model performance (accuracy):  0.724
#
# pz model performance (accuracy):  0.701
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.96459685  9.8261084   9.82635024 -0.03946547  2.24466861]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.797965595859946
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.24236851368916426
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7536666666666667
#
# DM estimator under NUC:  20.742226587408418
# MIS estimator under NUC:  26.422692290179256
# DRL estimator under NUC:  20.761819765361636
# pa model performance (accuracy):  0.7536666666666667
#
# pz model performance (accuracy):  0.7206666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.81157388  9.74157212  9.73138055 -0.04835315  2.25583434]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.767897561453804
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7704280571862432
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.765
#
# DM estimator under NUC:  20.368981794680803
# MIS estimator under NUC:  26.011526679568934
# DRL estimator under NUC:  20.395760649158035
# pa model performance (accuracy):  0.765
#
# pz model performance (accuracy):  0.73075
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.92349914  9.74547898  9.73775005 -0.04340351  2.25073231]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.386375961835462
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.0489354940228048
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7752
#
# DM estimator under NUC:  21.11981790865005
# MIS estimator under NUC:  26.780289004809255
# DRL estimator under NUC:  21.122527025454833
# pa model performance (accuracy):  0.7752
#
# pz model performance (accuracy):  0.7154
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.72452657  9.86297725  9.85879834 -0.05404995  2.24135738]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.06209785498046
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.1429175271052031
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7518333333333334
#
# DM estimator under NUC:  21.00039361291515
# MIS estimator under NUC:  26.506657170116064
# DRL estimator under NUC:  21.000652342768007
# pa model performance (accuracy):  0.7518333333333334
#
# pz model performance (accuracy):  0.7108333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.780297    9.77340128  9.76350012 -0.04942517  2.24683666]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.924870876188482
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.15873095417903577
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7505714285714286
#
# DM estimator under NUC:  21.20114887471971
# MIS estimator under NUC:  26.590160375660158
# DRL estimator under NUC:  21.201777653446143
# pa model performance (accuracy):  0.7505714285714286
#
# pz model performance (accuracy):  0.7121428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76567082  9.780448    9.77217531 -0.04897643  2.25063695]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.15883608000394
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.28504101654794695
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74325
#
# DM estimator under NUC:  20.646966423729715
# MIS estimator under NUC:  25.929962867989573
# DRL estimator under NUC:  20.650132332935843
# pa model performance (accuracy):  0.74325
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73565895  9.73032854  9.71187877 -0.04848407  2.26278552]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.554928253395683
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7533959558437676
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7615555555555555
#
# DM estimator under NUC:  20.954771620589145
# MIS estimator under NUC:  26.878936373319267
# DRL estimator under NUC:  20.96257084056848
# pa model performance (accuracy):  0.7615555555555555
#
# pz model performance (accuracy):  0.7298888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.92550183  9.78372283  9.7780974  -0.04239698  2.24047832]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.050509404770953
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6639758355170958
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7543
#
# DM estimator under NUC:  20.377559975477546
# MIS estimator under NUC:  26.195349504735375
# DRL estimator under NUC:  20.3620534711959
# pa model performance (accuracy):  0.7543
#
# pz model performance (accuracy):  0.7137
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.77853814  9.80117821  9.7934521  -0.05109891  2.24898234]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.308479713492506
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5942482961888673
# Augmentation terms calculation finished.
#
# rep= 93 :
#
# pa model performance (accuracy):  0.759
#
# DM estimator under NUC:  22.64731164967438
# MIS estimator under NUC:  28.97675947454323
# DRL estimator under NUC:  22.66462538540773
# pa model performance (accuracy):  0.759
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.81590614  9.69880384  9.68896151 -0.05201984  2.24715868]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.62654269257939
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2028590268223502
# ...
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.662701678329552
# Augmentation terms calculation finished.
#
# rep= 98 :
#
# pa model performance (accuracy):  0.759
#
# DM estimator under NUC:  21.395737932951405
# MIS estimator under NUC:  26.972143979108218
# DRL estimator under NUC:  21.303879531075765
# pa model performance (accuracy):  0.759
#
# pz model performance (accuracy):  0.712
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.77775089  9.46768379  9.38505899 -0.07128431  2.30478209]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.46805817233094
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.34066335130422976
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.77
#
# DM estimator under NUC:  18.973829073308618
# MIS estimator under NUC:  26.08114789901703
# DRL estimator under NUC:  18.951031533043203
# pa model performance (accuracy):  0.77
#
# pz model performance (accuracy):  0.7235
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.45745396  9.7399436   9.72251266 -0.0491153   2.2531244 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.61518678911547
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.432202903306035
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7706666666666667
#
# DM estimator under NUC:  21.867749312177004
# MIS estimator under NUC:  27.67164180758315
# DRL estimator under NUC:  21.892754042107306
# pa model performance (accuracy):  0.7706666666666667
#
# pz model performance (accuracy):  0.7226666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84942158  9.93783723  9.94575686 -0.04619303  2.23336405]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.801022838061446
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.13176227395858522
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76
#
# DM estimator under NUC:  22.603166385557998
# MIS estimator under NUC:  28.06810014816113
# DRL estimator under NUC:  22.636710862175768
# pa model performance (accuracy):  0.76
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.88362829  9.79479373  9.78778984 -0.0389812   2.24305822]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.574988669651948
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.14822079127061882
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.762
#
# DM estimator under NUC:  20.994413155869466
# MIS estimator under NUC:  26.747716511316693
# DRL estimator under NUC:  21.02164168050783
# pa model performance (accuracy):  0.762
#
# pz model performance (accuracy):  0.7258
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.64057257  9.75140937  9.73708456 -0.05737798  2.2619083 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.752943606982893
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.4256865388602723
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7536666666666667
#
# DM estimator under NUC:  21.11089852926064
# MIS estimator under NUC:  26.89747955803463
# DRL estimator under NUC:  21.099285135022637
# pa model performance (accuracy):  0.7536666666666667
#
# pz model performance (accuracy):  0.7208333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.82862706  9.74567354  9.73623523 -0.04999931  2.25340053]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.0519286508657
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5163937818727107
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7571428571428571
#
# DM estimator under NUC:  22.21619830365269
# MIS estimator under NUC:  27.30016641670562
# DRL estimator under NUC:  22.21706525265233
# pa model performance (accuracy):  0.7571428571428571
#
# pz model performance (accuracy):  0.7108571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.02506658  9.77482916  9.77004346 -0.04190352  2.25482274]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.375191907951038
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.21238882954145594
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7655
#
# DM estimator under NUC:  20.322977324252847
# MIS estimator under NUC:  25.946901454513828
# DRL estimator under NUC:  20.345944940697755
# pa model performance (accuracy):  0.7655
#
# pz model performance (accuracy):  0.721375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.82018324  9.74478189  9.73338186 -0.05080139  2.25763648]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.257644800124748
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.48823554946104963
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7557777777777778
#
# DM estimator under NUC:  20.70258355604534
# MIS estimator under NUC:  26.41193601359691
# DRL estimator under NUC:  20.71456236931652
# pa model performance (accuracy):  0.7557777777777778
#
# pz model performance (accuracy):  0.7234444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.86087324  9.80299127  9.8010576  -0.04916873  2.25442887]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.67671440857746
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.45156125253925267
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7498
#
# DM estimator under NUC:  21.255943380035667
# MIS estimator under NUC:  26.371022365257403
# DRL estimator under NUC:  21.25589099289573
# pa model performance (accuracy):  0.7498
#
# pz model performance (accuracy):  0.7155
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.72577868  9.83514999  9.83108671 -0.05709177  2.24449083]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.107284672916396
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.37142276198528523
# Augmentation terms calculation finished.
#
# rep= 99 :
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  18.392838964611084
# MIS estimator under NUC:  26.121718740224246
# DRL estimator under NUC:  18.365193342359976
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.99433068  9.7738076   9.77249488 -0.03726608  2.2528778 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.046119831464686
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.0784954638078257
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74
#
# DM estimator under NUC:  20.58344614668014
# MIS estimator under NUC:  26.183969258715898
# DRL estimator under NUC:  20.620600205619876
# pa model performance (accuracy):  0.74
#
# pz model performance (accuracy):  0.7125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.36571652  9.70161656  9.67457532 -0.07070372  2.27840027]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.008978192128822
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5140445456234414
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7266666666666667
#
# DM estimator under NUC:  21.676396082331014
# MIS estimator under NUC:  26.824562670153597
# DRL estimator under NUC:  21.684738395285386
# pa model performance (accuracy):  0.7266666666666667
#
# pz model performance (accuracy):  0.6963333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.66293475  9.50846662  9.48411016 -0.04992129  2.28263108]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.515396580091682
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.994032270014996
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7395
#
# DM estimator under NUC:  19.889224085924926
# MIS estimator under NUC:  25.564759999973802
# DRL estimator under NUC:  19.900932565718993
# pa model performance (accuracy):  0.7395
#
# pz model performance (accuracy):  0.72475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.48069767  9.78234754  9.75729351 -0.05530876  2.27755702]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.491113914932836
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8259149362541183
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7656
#
# DM estimator under NUC:  21.745666284258558
# MIS estimator under NUC:  27.162885979759036
# DRL estimator under NUC:  21.742856487946174
# pa model performance (accuracy):  0.7656
#
# pz model performance (accuracy):  0.715
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80004369  9.79617333  9.7891154  -0.05061197  2.26410179]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.6279481885309
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3281985966802001
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7578333333333334
#
# DM estimator under NUC:  21.273044251950395
# MIS estimator under NUC:  26.68758268781529
# DRL estimator under NUC:  21.29100995945848
# pa model performance (accuracy):  0.7578333333333334
#
# pz model performance (accuracy):  0.7193333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.82524408  9.7123223   9.69803663 -0.05198777  2.26157604]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.227844549070422
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.35541416197657477
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7697142857142857
#
# DM estimator under NUC:  21.367954713550667
# MIS estimator under NUC:  27.091568414210027
# DRL estimator under NUC:  21.37708584859624
# pa model performance (accuracy):  0.7697142857142857
#
# pz model performance (accuracy):  0.7205714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.83709961  9.8077642   9.80218003 -0.04606739  2.24636892]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.35269431170395
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3215649934538037
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74475
#
# DM estimator under NUC:  21.169357439403125
# MIS estimator under NUC:  25.9784903805037
# DRL estimator under NUC:  21.191560955226215
# pa model performance (accuracy):  0.74475
#
# pz model performance (accuracy):  0.696875
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87071493  9.74422296  9.73517847 -0.04346607  2.24731641]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.250554580888892
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.35122213670376623
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7552222222222222
#
# DM estimator under NUC:  21.228228434699194
# MIS estimator under NUC:  26.202730150074732
# DRL estimator under NUC:  21.221199056239858
# pa model performance (accuracy):  0.7552222222222222
#
# pz model performance (accuracy):  0.7058888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.86038959  9.71508142  9.70245304 -0.0459089   2.25270746]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.273393171502867
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.392483521220243
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  20.82634135837188
# MIS estimator under NUC:  26.601519282717387
# DRL estimator under NUC:  20.81479242321743
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7257
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.99735841  9.75713254  9.7533727  -0.04171741  2.24921758]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.96477659717272
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.39041850440682146
# Augmentation terms calculation finished.

# %%
eta_pi_true = 19.995276055376863

# %%
import numpy as np
REP=100
mean_IVRL_DR=(np.sum(est_IVRL_DR,0)/REP)
mean_IVRL_DM=(np.sum(est_IVRL_DM,0)/REP)
mean_DM=(np.sum(est_DM,0)/REP)
mean_MIS=(np.sum(est_MIS,0)/REP)
mean_DRL=(np.sum(est_DRL,0)/REP)

Var_IVRL_DR=np.sum((est_IVRL_DR-mean_IVRL_DR)**2,0)/REP
Var_IVRL_DM=np.sum((est_IVRL_DM-mean_IVRL_DM)**2,0)/REP
Var_DM=np.sum((est_DM-mean_DM)**2,0)/REP
Var_MIS=np.sum((est_MIS-mean_MIS)**2,0)/REP
Var_DRL=np.sum((est_DRL-mean_DRL)**2,0)/REP

# %%
MSE_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true)**2,0)/REP
MSE_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true)**2,0)/REP
MSE_DM=np.sum((est_DM-eta_pi_true)**2,0)/REP
MSE_MIS=np.sum((est_MIS-eta_pi_true)**2,0)/REP
MSE_DRL=np.sum((est_DRL-eta_pi_true)**2,0)/REP

Bias_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true),0)/REP
Bias_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true),0)/REP
Bias_DM=np.sum((est_DM-eta_pi_true),0)/REP
Bias_MIS=np.sum((est_MIS-eta_pi_true),0)/REP
Bias_DRL=np.sum((est_DRL-eta_pi_true),0)/REP

# %%
import matplotlib.pyplot as plt
 
trajectory = [200,300,400,500,600,700,800,900,1000]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

#pyl.xlim(0, 20)
#pyl.ylim(0.25, 2)

ax1.plot(trajectory, np.log(MSE_IVRL_DR/eta_pi_true**2)[1:11] ,marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax1.plot(trajectory, np.log(MSE_DM/eta_pi_true**2)[1:11] ,marker='+', linestyle='--', mec='r', mfc='r', label='DM')
ax1.plot(trajectory, np.log(MSE_MIS/eta_pi_true**2)[1:11] ,marker='v', linestyle='-.', mec='r', mfc='r', label='MIS')
ax1.plot(trajectory, np.log(MSE_DRL/eta_pi_true**2)[1:11] ,marker='x', linestyle=':', mec='r', mfc='r', label='DRL')
ax1.set_xlabel("number of trajectories")
ax1.set_title('log (Relative MSE)')

ax2.plot(trajectory, (abs(Bias_IVRL_DR)/abs(eta_pi_true))[1:11],marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax2.plot(trajectory, (abs(Bias_DM)/abs(eta_pi_true))[1:11],marker='+', linestyle='--', mec='r', mfc='r', label='NUC-DM')
ax2.plot(trajectory, (abs(Bias_MIS)/abs(eta_pi_true))[1:11],marker='v', linestyle='-.', mec='r', mfc='r', label='NUC-MIS')
ax2.plot(trajectory, (abs(Bias_DRL)/abs(eta_pi_true))[1:11],marker='x', linestyle=':', mec='r', mfc='r', label='NUC-DRL')
ax2.set_xlabel("number of trajectories")
ax2.set_title('Relative Absolute Bias')
#plt.legend(loc=(1.05,0.4))
plt.legend(loc="best")
#plt.text(0, -0.08, "Weak Confounder", ha='center')
#plt.xlim(399, 1001)
plt.show()
