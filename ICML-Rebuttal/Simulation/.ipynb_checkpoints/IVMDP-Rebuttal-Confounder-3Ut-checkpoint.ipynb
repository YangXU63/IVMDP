# %% [markdown]
# ## Generate simulation data

# %%
import joblib
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from numpy.ma.core import exp
from scipy.special import expit

# %%
# define some functions to generate the simulation data

def generate_S0(n0):
    S01=np.random.normal(size=n0)
    S02=np.random.normal(size=n0)
    return np.vstack((S01,S02)).T

def generate_Ut(n0):
    return np.random.binomial(size=n0, n=1, p=0.5) - 0.5

def generate_Zt(St,n0):
    p=expit(St[:,0]+St[:,1])
    return np.random.binomial(1,p,size=n0)

def generate_At(St,Zt,Ut,n0):
    p=expit(St[:,0]+St[:,1]+Zt+1*Ut)
    return np.random.binomial(1,p,size=n0)

# 5Ut -> 3Ut
def generate_Rt(St,At,Ut,n0):
    return (St[:,0]+St[:,1]+2*At+3*Ut)

def generate_Stplus1(St,At,Ut,n0):
    Stplus11 = St[:,0] + Ut + (At - 0.5)
    Stplus12 = St[:,1] - Ut - (At - 0.5)
    Stplus = np.vstack((Stplus11,Stplus12)).T
    return Stplus

# %%
# generate simulation dataset
# the number of samples
n=10**3
# the number of stages
T=120
p=2


np.random.seed(525)
S0=generate_S0(n)
MDP = np.copy(S0)
St=S0
for i in range(T):
    Ut=generate_Ut(n)
    Zt=generate_Zt(St,n)
    At=generate_At(St,Zt,Ut,n)
    Rt=generate_Rt(St,At,Ut,n)
    Stplus1=generate_Stplus1(St,At,Ut,n)
    MDP = np.hstack((MDP, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
    St=Stplus1


MDP=MDP[:,(20*(p+3)):(120*(p+3)+p)]
print(np.shape(MDP))
# Out:
# (1000, 502)

# %%
pd.DataFrame(MDP)
# Out:
#            0          1    2    3         4          5          6    7    8    \
# 0    -7.665318   5.507090  0.0  0.0 -0.658228  -7.665318   5.507090  1.0  0.0
# 1     9.381374  -7.349269  1.0  1.0  2.532105   9.381374  -7.349269  1.0  1.0
# 2     7.314472  -6.954949  0.0  0.0 -1.140477   6.314472  -5.954949  1.0  1.0
# 3    13.226179 -11.576353  1.0  1.0  5.149827  14.226179 -12.576353  0.0  1.0
# 4     0.545412  -1.115731  0.0  1.0 -0.070319   0.545412  -1.115731  1.0  0.0
# ..         ...        ...  ...  ...       ...        ...        ...  ...  ...
# 995   1.640969  -0.121767  1.0  1.0  5.019202   2.640969  -1.121767  0.0  1.0
# 996   7.410351  -7.092512  0.0  1.0  3.817839   8.410351  -8.092512  0.0  0.0
# 997  -0.795136  -0.038623  1.0  0.0 -2.333758  -1.795136   0.961377  0.0  0.0
# 998   8.153053  -7.755844  0.0  0.0 -1.102792   7.153053  -6.755844  1.0  1.0
# 999  -5.126541   3.867136  0.0  0.0 -2.759405  -6.126541   4.867136  0.0  1.0
#
#           9    ...  492  493       494        495        496  497  498  \
# 0   -3.658228  ...  0.0  0.0 -0.658228 -40.665318  38.507090  0.0  0.0
# 1    2.532105  ...  1.0  1.0  5.532105  53.381374 -51.349269  1.0  0.0
# 2    0.859523  ...  0.0  0.0 -1.140477  26.314472 -25.954949  1.0  1.0
# 3    2.149827  ...  1.0  1.0  2.149827  44.226179 -42.576353  0.0  1.0
# 4    0.929681  ...  1.0  1.0 -0.070319  -2.454588   1.884269  0.0  1.0
# ..        ...  ...  ...  ...       ...        ...        ...  ...  ...
# 995  2.019202  ...  1.0  1.0  5.019202  44.640969 -43.121767  0.0  1.0
# 996  1.817839  ...  0.0  0.0 -1.182161  30.410351 -30.092512  1.0  1.0
# 997 -2.333758  ...  0.0  1.0  2.666242 -19.795136  18.961377  0.0  1.0
# 998  0.897208  ...  1.0  1.0  0.897208  12.153053 -11.755844  1.0  1.0
# 999  2.240595  ...  0.0  0.0 -2.759405 -24.126541  22.867136  0.0  0.0
#
#           499        500        501
# 0   -3.658228 -41.665318  39.507090
# 1    0.532105  52.381374 -50.349269
# 2    3.859523  27.314472 -26.954949
# 3    5.149827  45.226179 -43.576353
# 4    2.929681  -1.454588   0.884269
# ..        ...        ...        ...
# 995  2.019202  44.640969 -43.121767
# 996  3.817839  31.410351 -31.092512
# 997  2.666242 -18.795136  17.961377
# 998  0.897208  12.153053 -11.755844
# 999  0.240595 -24.126541  22.867136
#
# [1000 rows x 502 columns]

# %%
p=2
#Pi=1
gamma=0.9
domain_At=np.array([0,1])
domain_Zt=np.array([0,1])
max_iter=1000
epsilon=5e-4
T=100

# %%
def Pi(St):
    if len(St.shape) == 0:
        raise ValueError("St should be 1d/2d array")

    if len(St.shape) == 1:
        return 1
        #p = expit(St[0]+St[1]+1.5*expit(St[0]+St[1]))
    else:
        return np.ones(np.shape(St)[0])
        #p = expit(St[:,0]+St[:,1]+1.5*expit(St[:,0]+St[:,1]))

# %% [markdown]
# ## true value

# %%
# approximate the true value of eta_pi by MC method
# the first step is to generate a dataset that follows target policy Pi.
# in this case, we specify At=np.ones(n0)*Pi where Pi can be 0 or 1.

np.random.seed(525)
n0=10**5 # the number of trajectories in MC approximation. The larger the better.
T_burn=20
p=2
T=100 # the number of stages
gamma=0.9

eta_pi_true=0
for repp in range(100):

    S0=generate_S0(n0)
    MDP_burn = np.copy(S0)
    St=S0
    for i in range(T_burn):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=generate_At(St,Zt,Ut,n0)
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP_burn = np.hstack((MDP_burn, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

  #print(np.shape(MDP_burn))


    S0=MDP_burn[:,T_burn*(p+3):(T_burn*(p+3)+2)]

    MDP0 = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=np.random.binomial(n=1, p=Pi(St), size=n0) # generate Ai following Pi
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP0 = np.hstack((MDP0, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1
  #MDP0=MDP0[:,(20*(p+3)):(120*(p+3)+p)]
  #print(np.shape(MDP0))

  # true value of $\eta_{\pi}$ can be estimated by MC method:

    for t in range(T):
        eta_pi_true=eta_pi_true+(gamma**(t))*sum(MDP0[:,(p+2)+(p+3)*t])/n0

        
eta_pi_true=eta_pi_true/100
print(eta_pi_true)
# Out:
# 19.99604133247016

# %%
np.shape(Zt)
# Out:
# (100000,)

# %%
pd.DataFrame(MDP0)
# Out:
#              0          1    2    3         4          5          6    7    \
# 0       6.014786  -5.354693  1.0  1.0  1.160093   6.014786  -5.354693  0.0
# 1      13.275657 -10.343086  1.0  1.0  3.432571  13.275657 -10.343086  1.0
# 2      11.096759 -10.223350  1.0  1.0  4.373409  12.096759 -11.223350  1.0
# 3      11.620527  -9.817214  1.0  1.0  5.303313  12.620527 -10.817214  1.0
# 4       8.270191  -7.059221  0.0  1.0  4.710971   9.270191  -8.059221  1.0
# ...          ...        ...  ...  ...       ...        ...        ...  ...
# 99995  -2.687823   1.920101  0.0  1.0 -0.267723  -2.687823   1.920101  0.0
# 99996   3.978756  -4.450690  0.0  1.0  3.028066   4.978756  -5.450690  0.0
# 99997  12.216641 -10.047447  1.0  1.0  2.669194  12.216641 -10.047447  1.0
# 99998  -1.366799  -0.603489  0.0  1.0  1.529713  -0.366799  -1.603489  0.0
# 99999   1.335805  -1.943831  0.0  1.0 -0.108026   1.335805  -1.943831  0.0
#
#        8         9    ...  492  493       494        495        496  497  498  \
# 0      1.0  1.160093  ...  1.0  1.0  4.160093  51.014786 -50.354693  1.0  1.0
# 1      1.0  6.432571  ...  1.0  1.0  6.432571  64.275657 -61.343086  1.0  1.0
# 2      1.0  1.373409  ...  0.0  1.0  4.373409  55.096759 -54.223350  0.0  1.0
# 3      1.0  5.303313  ...  1.0  1.0  5.303313  59.620527 -57.817214  1.0  1.0
# 4      1.0  4.710971  ...  0.0  1.0  4.710971  53.270191 -52.059221  1.0  1.0
# ...    ...       ...  ...  ...  ...       ...        ...        ...  ...  ...
# 99995  1.0 -0.267723  ...  1.0  1.0  2.732277  55.312177 -56.079899  1.0  1.0
# 99996  1.0  0.028066  ...  1.0  1.0  3.028066  50.978756 -51.450690  1.0  1.0
# 99997  1.0  2.669194  ...  1.0  1.0  5.669194  56.216641 -54.047447  1.0  1.0
# 99998  1.0 -1.470287  ...  0.0  1.0 -1.470287  41.633201 -43.603489  0.0  1.0
# 99999  1.0 -0.108026  ...  1.0  1.0  2.891974  55.335805 -55.943831  1.0  1.0
#
#             499        500        501
# 0      1.160093  51.014786 -50.354693
# 1      3.432571  64.275657 -61.343086
# 2      4.373409  56.096759 -55.223350
# 3      5.303313  60.620527 -58.817214
# 4      1.710971  53.270191 -52.059221
# ...         ...        ...        ...
# 99995  2.732277  56.312177 -57.079899
# 99996  3.028066  51.978756 -52.450690
# 99997  2.669194  56.216641 -54.047447
# 99998 -1.470287  41.633201 -43.603489
# 99999 -0.108026  55.335805 -55.943831
#
# [100000 rows x 502 columns]

# %% [markdown]
# ## comparison

# %% [markdown]
# #### IVRL

# %%
def IVRL_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # IV+MDP. Off policy evaluation: estimate the averaged treatment effect in infinite-horizon MDP settings
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler
    from numpy.linalg import inv, eigvals

    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T

    index_Z=np.linspace(0,T-1,T)*(p+3)+p
    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2
    index_SZ=np.concatenate((index_S,index_Z))

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_SZ=MDP[:,index_SZ.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Zvec=MDP[:,index_Z.astype(int)].T.reshape(-1,1)
    SZvec=np.hstack((Svec,Zvec))
    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s,z) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(SZvec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(SZvec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")
    def Pa(St,Zt,n,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St,Zt]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(np.concatenate((St,np.array([Zt]))).reshape(1, -1))[0]
      else:
        return A_model.predict_proba(np.hstack((St,Zt)))


    ## (2) estimate P11 := p_a(At=1|Zt=1,St)
    def P11(St,n,A_model):
      if (n==1):
        return Pa(St,1,n,A_model)[1]
      else:
        return Pa(St,np.ones(n).reshape(-1,1),n,A_model)[:,1]

    ## (3) estimate P10 := p_a(At=1|Zt=0,St)
    def P10(St,n,A_model):
      if (n==1):
        return Pa(St,0,n,A_model)[1]
      else:
        return Pa(St,np.zeros(n).reshape(-1,1),n,A_model)[:,1]

    ## (4) estimate c(Zt|St)
    def c(Zt,St,n,Pi,A_model):
      #ratio = np.clip(ratio, a_min=-100, a_max=100)
      if (n==1):
        c=Zt*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c
        return np.clip(c, a_min=-50, a_max=50)
      else:
        c=Zt.T*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt.T)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c[0]
        return np.clip(c[0], a_min=-50, a_max=50)

    ## (5) estimate pz(Zt|St)
    Z_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #Z_model = LogisticRegression()
    Z_model.fit(Svec[range(int(n*T*0.9))], Zvec[range(int(n*T*0.9))].reshape(1,-1)[0])
    print("pz model performance (accuracy): ", Z_model.score(Svec[range(int(n*T*0.9),n*T)], Zvec[range(int(n*T*0.9),n*T)], sample_weight=None),"\n")

    def Pz(Zt,St,n,Z_model):
      if ((n==1) and (p==1)):
        return Z_model.predict_proba(np.array([St]).reshape(1, -1))[0][int(Zt)]
      elif ((n==1) and (p!=1)):
        return Z_model.predict_proba(St.reshape(1, -1))[0][int(Zt)]
      else:
        return Z_model.predict_proba(St)[:,1]*Zt.T[0] + Z_model.predict_proba(St)[:,0]*(1-Zt.T[0])




    ## (6) estimate $\rho(Z_t,S_t)$
    def rho(St,Zt,n,Pi,A_model):
      return c(Zt,St,n,Pi,A_model)/Pz(Zt,St,n,Z_model)

    print("Start estimating omega_pi(St):")
    ## (7) estimate $\omega^{\pi}(s)$: should change if St continuous, and here we only specify linear function class for xi
    class RatioLinearLearner:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, time_difference=None, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=True, rho=rho, A_model=A_model, truncate=100, domain_Zt=np.array([0,1]), domain_At=np.array([0,1])):
            self.use_IV = use_IV

            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])
            if use_IV:
                self.IV = np.copy(dataset['IV']).reshape(-1, 1)
            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)

            self.Pi = Pi

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                ratio = rho(self.state,self.IV,len(self.action),self.Pi,A_model)
            #else:
                  #estimate_pa = self.PALearner.get_pa_prediction(self.state, self.action)
                  #target_pa = self.target_policy_pa(self.policy, self.state, self.action)
                  #pa_ratio = target_pa / estimate_pa
                  #ratio = pa_ratio

            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)

    state_all=Svec
    IV=Zvec.T[0]
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, IV, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action, 'IV': IV,
            'reward': reward, 
            "next_state": next_state_all}

    
    rlearner = RatioLinearLearner(dataset, Pi, ndim = ndim, use_IV= True, rho=rho, A_model=A_model)
    rlearner.fit()
    omega_all=rlearner.get_ratio_prediction(state_all)

    print("omega_pi(St) estimation finished.\n")


    print("Start estimating Q function and Value function (fitted Q evaluation):")
    ## (8) estimate Q function: we only specify Q as a linear function of (St,Zt,At). Can be generalized later.
    # Q function: a linear function of (St,Zt,At). Can be modified later.
    def Q(beta,n,St,Zt,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,Zt,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([Zt]),np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,Zt,At)),beta)################################3

    ## (9) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta, domain_Zt, domain_At, A_model):
      len_Zt=len(domain_Zt)
      len_At=len(domain_At)
      if (n==1):
        V_St=0
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q(beta,n,St,domain_Zt[i],domain_At[j])
            #V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q_model.predict(np.concatenate((St,np.array([domain_Zt[i]]),np.array([domain_At[j]]))))
      else:
        V_St=np.zeros(n)
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i]*np.ones(n).reshape(-1,1),St,n,Pi,A_model)*Pa(St,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]*Q(beta,n,St,domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1))
            #V_St=V_St+c(np.ones(n)*domain_Zt[i].reshape(-1,1),St,n,Pi,A_model)*Pa(St,np.ones(n)*domain_Zt[i].reshape(-1,1),n,A_model)[:,j]*Q_model.predict(np.hstack((St,np.ones(n)*domain_Zt[i].reshape(-1,1),np.ones(n)*domain_At[j].reshape(-1,1))))

      return V_St

    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+2
    nall=n*T
    len_Zt=len(domain_Zt)
    len_At=len(domain_At)
    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p+2)]),axis=1)

      f_tplus1_Q=np.zeros((n,nfeatures+1))
      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      for i in range(len_Zt):
        for j in range(len_At):
          xi_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)],domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1)),axis=1)
          coef_Q=c(domain_Zt[i]*np.ones(n).reshape(-1,1),Stplus1,n,Pi,A_model)*Pa(Stplus1,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]
          f_tplus1_Q=f_tplus1_Q+xi_tplus1_Q* coef_Q[:, np.newaxis]

      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q=np.linalg.solve(part1_Q,part2_Q)

    print("Estimated beta_Q is: ", beta_Q)
    print("Q function and Value function estimation finished.\n")


    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q):
      
      phi_result=0
      #phi_result_part1=0
      #phi_result_part2=0

      for t in range(T):
        if (p==1):
          Pa_At=Pa(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=MDP[i,4*t+1],At=a)

          phi_3=MDP[:,4*t+2]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          #delta_a=np.clip(delta_a, a_min=-50, a_max=50)
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,4*t],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega) !!!!!!!!!!!!!!!
          rho_StZt=rho(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        else:
          Pa_At=Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=MDP[i,(p+3)*t+p],At=a)

          phi_3=MDP[:,(p+3)*t+p+1]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          rho_StZt=rho(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        
        
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2+phi_3))

        #phi_result_part1=phi_result_part1+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2))
        #phi_result_part2=phi_result_part2+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*phi_3)

      phi_result=phi_result/n/(T)
      #phi_result_part1=phi_result_part1/n/(T)
      #phi_result_part2=phi_result_part2/n/(T)

      return phi_result


    print("Start calculating DM estimator:")
    # calculate the direct estimator
    eta_pi_DM=0
    for i in range(n):
      for z in range(2):
        for a in range(2):
          eta_pi_DM=eta_pi_DM+c(Zt=z,St=MDP[i,0:p],n=1,Pi=Pi,A_model=A_model)*Pa(Zt=z,St=MDP[i,0:p],n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,0:p],Zt=z,At=a)
    eta_pi_DM=eta_pi_DM/n
    print("DM estimator: eta_pi_DM=", eta_pi_DM)
    print("DM estimator calculation finished.\n")

    print("Start calculating augmentation terms:")
    # calculate the augmentation terms by function phi_aug
    eta_pi_aug=phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q)
    print("Augmentation term: eta_pi_aug=", eta_pi_aug)
    print("Augmentation terms calculation finished.\n")

    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_DR=eta_pi_DM+eta_pi_aug
    
    return eta_pi_DM, eta_pi_DR

# %% [markdown]
# #### Other methods: NUC

# %%
def DRL_NUC_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # Double reinforcement learning with NO unmeasured confounders. 
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv, eigvals



    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T


    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(Svec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(Svec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")


    def Pa(St,n,p,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(St.reshape(1, -1))[0]
      else:
        return A_model.predict_proba(St)

    #from scipy.interpolate import BSpline


    ## (9) estimate Q function: we only specify Q as a linear function of (St,At). Can be generalized later.
    # Q function: a linear function of (St,At). Can be modified later.
    def Q(beta,n,St,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,At)),beta)################################3

    ## (10) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta):
      # deterministic policy Pi: here we just test Pi=1. The whole function can be generalized to random policy later.
      if (n==1):
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=1)[0])
      else:
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=n).reshape(-1,1))

      return V_St


    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+1
    nall=n*T

    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,((p+3)*t+p+1)].reshape(-1,1)),axis=1)

      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      f_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),Stplus1,np.random.binomial(n=1, p=Pi(MDP[:,(p+3)*t:((p+3)*t+p)]), size=n).reshape(-1,1)),axis=1)


      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q_NUC=np.linalg.solve(part1_Q,part2_Q)

    # DM estimator:
    eta_pi_est_DM_NUC=0
    for i in range(n):
      eta_pi_est_DM_NUC=eta_pi_est_DM_NUC+V(MDP[i,0:p],1,Pi,beta_Q_NUC) # corre
    eta_pi_est_DM_NUC=eta_pi_est_DM_NUC/n

    print("DM estimator under NUC: ",eta_pi_est_DM_NUC) 


    ## (7) estimate beta_pi
    def beta_pi(St,At,p,n,Pi,A_model):
      if (n==1):
        return (Pi(St)*At+(1-Pi(St))*(1-At))/(Pa(St,1,2,A_model)[int(At)])
      else:
        return (Pi(St)*At.T[0]+(1-Pi(St))*(1-At.T[0]))/(At.T[0]*Pa(St,n,2,A_model)[:,1]+(1-At.T[0])*Pa(St,n,2,A_model)[:,0])


    ## (8) estimate $\omega^{\pi}(s)$: here we only specify linear function class for xi
    # -*- coding: utf-8 -*-

    import numpy as np
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler

    class RatioLinearLearner_NUC:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=False, truncate=100):
            self.use_IV=use_IV
            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])

            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)
            self.beta_pi=beta_pi
            self.Pi = Pi
            self.A_model = A_model

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                rho(self.state,self.IV.reshape(-1,1),len(self.action),self.Pi,A_model)
            else:
                ratio = beta_pi(self.state, self.action,p,n,self.Pi,self.A_model)

            # print(np.mean(ratio)) # close to 1 if behaviour and target are the same
            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            # design_matrix = np.zeros((psi.shape[1], psi.shape[1]))
            # for i in range(self.state.shape[0]):
            #     design_matrix += np.matmul(psi[i].reshape(-1, 1), psi_minus_psi_next[i].reshape(1, -1))
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))  
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)


    state_all=Svec
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action,
            'reward': reward, 
            "next_state": next_state_all}

    #dataset, policy, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=100,
    rlearner_NUC = RatioLinearLearner_NUC(dataset, Pi, beta_pi, ndim = ndim, use_IV= False, A_model=A_model)
    rlearner_NUC.fit()
    omega_all_NUC=rlearner_NUC.get_ratio_prediction(state_all)



    '''
    # MIS estimator:
    eta_pi_est_MIS_NUC=0

    for t in range(T):
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)*beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,((p+3)*t+p+1)].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)* MDP[:,((p+3)*t+p+2)]

    eta_pi_est_MIS_NUC=sum(eta_pi_est_MIS_NUC)/n/(T)/(1-gamma)

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    '''

    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC):
      
      phi_result=0
      eta_pi_est_MIS_NUC=0

      for t in range(T):
        if (p==1):
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,4*t].reshape(-1,1),MDP[:,4*t+2].reshape(-1,1))
          #omega_St=omega(MDP[:,4*t].reshape(-1,1),n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,4*t].reshape(-1,1),At=MDP[:,4*t+2].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        else:
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,(p+3)*t+p+1].reshape(-1,1))
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,(p+3)*t+p+1].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(phi_1-phi_2))
        eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(MDP[:,(p+3)*t+p+2]))

      phi_result=phi_result/n/(T)
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC/n/(T)

      return phi_result, eta_pi_est_MIS_NUC


    eta_pi_est_aug_NUC, eta_pi_est_MIS_NUC=phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC)  

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_est_DR_NUC=eta_pi_est_DM_NUC+eta_pi_est_aug_NUC
    print("DRL estimator under NUC: ",eta_pi_est_DR_NUC) 


    return eta_pi_est_MIS_NUC, eta_pi_est_DM_NUC, eta_pi_est_DR_NUC

# %% [markdown]
# #### Run

# %%
import joblib

REP=100
est_IVRL_DR=np.zeros((REP,10))
est_IVRL_DM=np.zeros((REP,10))
est_DM=np.zeros((REP,10))
est_MIS=np.zeros((REP,10))
est_DRL=np.zeros((REP,10))


n_all=np.array([100,200,300,400,500,600,700,800,900,1000])

for rep in range(0,REP):
  print("rep=",rep,":\n")
  for j in range(10):
    np.random.seed(rep*10+j)  
    # generate MDP
    n=n_all[j]

    # the number of stages
    T=120
    p=2

    S0=generate_S0(n)
    MDP_IVRL = np.copy(S0)
    MDP_NUC = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n)
        Zt=generate_Zt(St,n)
        At=generate_At(St,Zt,Ut,n)
        Rt=generate_Rt(St,At,Ut,n)
        Stplus1=generate_Stplus1(St,At,Ut,n)
        MDP_NUC = np.hstack((MDP_NUC, Zt.reshape(-1,1),Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        MDP_IVRL = np.hstack((MDP_IVRL, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

    T=100
    p=3
    MDP_NUC=MDP_NUC[:,(20*(p+3)):(120*(p+3)+p)]
    MDP_NUC= np.hstack((MDP_NUC, Zt.reshape(-1,1)))
    est_MIS[rep,j],est_DM[rep,j],est_DRL[rep,j]=DRL_NUC_TE_est(MDP_NUC, 3, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)

    p=2
    MDP_IVRL=MDP_IVRL[:,(20*(p+3)):(120*(p+3)+p)]
    est_IVRL_DM[rep,j], est_IVRL_DR[rep,j]=IVRL_TE_est(MDP_IVRL, 2, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)
# Out:
# rep= 86 :
#
# pa model performance (accuracy):  0.739
#
# DM estimator under NUC:  21.904974172047158
# MIS estimator under NUC:  25.598087294956777
# DRL estimator under NUC:  21.948512275855464
# pa model performance (accuracy):  0.739
#
# pz model performance (accuracy):  0.678
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.693058    9.7586346   9.74154298 -0.15966134  2.75594579]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.43571723953621
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 22.430778461159033
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7545
#
# DM estimator under NUC:  21.974190692156217
# MIS estimator under NUC:  26.794204734793023
# DRL estimator under NUC:  21.99649771054773
# pa model performance (accuracy):  0.7545
#
# pz model performance (accuracy):  0.7055
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.46976884  9.06564054  9.01967518 -0.12455983  2.75953109]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.144097018363514
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.5677923983162692
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7616666666666667
#
# DM estimator under NUC:  22.78860548575705
# MIS estimator under NUC:  27.180479387022498
# DRL estimator under NUC:  22.9037132294888
# pa model performance (accuracy):  0.7616666666666667
#
# pz model performance (accuracy):  0.724
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.52596478  9.32677115  9.32320147 -0.14006063  2.7438095 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.810461112954638
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.8501218301545306
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76125
#
# DM estimator under NUC:  23.694021095308305
# MIS estimator under NUC:  28.002640874261377
# DRL estimator under NUC:  23.763075905247728
# pa model performance (accuracy):  0.76125
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74319841  9.3760806   9.36787526 -0.13184272  2.74641964]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.99361338239364
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5929050459291425
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7432
#
# DM estimator under NUC:  22.958651677631245
# MIS estimator under NUC:  27.805482630385796
# DRL estimator under NUC:  22.984106001193172
# pa model performance (accuracy):  0.7432
#
# pz model performance (accuracy):  0.7096
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.44176902  9.15230435  9.11748782 -0.14838673  2.77203301]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.83243045641758
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1806363324070206
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7583333333333333
#
# DM estimator under NUC:  22.96656320428582
# MIS estimator under NUC:  27.751419041880823
# DRL estimator under NUC:  23.032113951343348
# pa model performance (accuracy):  0.7583333333333333
#
# pz model performance (accuracy):  0.7221666666666666
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.58519953  9.47773178  9.46829889 -0.14811469  2.74724872]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.80247384674359
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1171646888000186
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7542857142857143
#
# DM estimator under NUC:  23.602826528649786
# MIS estimator under NUC:  28.210078474864805
# DRL estimator under NUC:  23.57229557172703
# pa model performance (accuracy):  0.7542857142857143
#
# pz model performance (accuracy):  0.716
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.79222857  9.30847655  9.29983208 -0.12811374  2.75569708]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.871284435657017
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4718243804739628
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751875
#
# DM estimator under NUC:  22.125697343972583
# MIS estimator under NUC:  26.823121686196032
# DRL estimator under NUC:  22.138804848216072
# pa model performance (accuracy):  0.751875
#
# pz model performance (accuracy):  0.71025
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.64220803  9.50618046  9.49899109 -0.13740837  2.73841496]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.116761685509413
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1218278212941848
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7502222222222222
#
# DM estimator under NUC:  22.811534776333875
# MIS estimator under NUC:  27.520876922769702
# DRL estimator under NUC:  22.828886934904702
# pa model performance (accuracy):  0.7502222222222222
#
# pz model performance (accuracy):  0.7116666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.32614993  9.35517243  9.32866526 -0.15929869  2.74674418]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.573157099108418
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1595649641928403
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7554
#
# DM estimator under NUC:  22.68935212797353
# MIS estimator under NUC:  27.394564303293876
# DRL estimator under NUC:  22.70786355634501
# pa model performance (accuracy):  0.7554
#
# pz model performance (accuracy):  0.7207
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.49784948  9.30469402  9.2846368  -0.14805657  2.75993284]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.569713661962084
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.0122897926619185
# Augmentation terms calculation finished.
#
# rep= 87 :
#
# pa model performance (accuracy):  0.796
#
# DM estimator under NUC:  24.36382082398709
# MIS estimator under NUC:  29.66749009510681
# DRL estimator under NUC:  24.466991800561395
# pa model performance (accuracy):  0.796
#
# pz model performance (accuracy):  0.728
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.23658111  8.75727889  8.68689659 -0.08715548  2.80844294]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.47009421435002
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.77819501219412
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7565
#
# DM estimator under NUC:  23.204561851060912
# MIS estimator under NUC:  29.944143505208604
# DRL estimator under NUC:  23.263079037366527
# pa model performance (accuracy):  0.7565
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.39050799  9.46653303  9.42981321 -0.13164378  2.81699921]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.899146468367288
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -6.762096497885692
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.768
#
# DM estimator under NUC:  22.74549494038302
# MIS estimator under NUC:  28.71938387519677
# DRL estimator under NUC:  22.725451155459112
# pa model performance (accuracy):  0.768
#
# pz model performance (accuracy):  0.7363333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.85302382  9.41741097  9.38034303 -0.14785254  2.73611585]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.398508680673828
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.5524746883381144
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.753
#
# DM estimator under NUC:  22.47836791556598
# MIS estimator under NUC:  26.732120289226813
# DRL estimator under NUC:  22.570450593863505
# pa model performance (accuracy):  0.753
#
# pz model performance (accuracy):  0.71475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.2965916   9.37786032  9.37157955 -0.15739156  2.72180654]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.14797294701818
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5199176994302344
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76
#
# DM estimator under NUC:  22.570167401280653
# MIS estimator under NUC:  27.52002374981364
# DRL estimator under NUC:  22.58629121902065
# pa model performance (accuracy):  0.76
#
# pz model performance (accuracy):  0.706
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.0773885   9.06570676  9.01432294 -0.16001414  2.81743306]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.036725816716363
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.5216831868249068
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7621666666666667
#
# DM estimator under NUC:  23.638732236708748
# MIS estimator under NUC:  28.49137393186475
# DRL estimator under NUC:  23.698090290136463
# pa model performance (accuracy):  0.7621666666666667
#
# pz model performance (accuracy):  0.7313333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.09450839  9.26699131  9.25145882 -0.11441787  2.71854055]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.242895560274356
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.4669476020343739
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.753
#
# DM estimator under NUC:  23.5230338463809
# MIS estimator under NUC:  27.561899379341245
# DRL estimator under NUC:  23.53023878980565
# pa model performance (accuracy):  0.753
#
# pz model performance (accuracy):  0.7151428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.52782876  9.29759921  9.2768098  -0.14521512  2.75828943]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.53506980654585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.1820587464938903
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76325
#
# DM estimator under NUC:  23.241966198484775
# MIS estimator under NUC:  28.93688650509314
# DRL estimator under NUC:  23.25386862314049
# pa model performance (accuracy):  0.76325
#
# pz model performance (accuracy):  0.727375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.36084417  9.29685372  9.2588878  -0.15276431  2.75963556]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.058262001755324
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.0547154560288605
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7511111111111111
#
# DM estimator under NUC:  23.117126426938487
# MIS estimator under NUC:  27.62895643967792
# DRL estimator under NUC:  23.137748000406496
# pa model performance (accuracy):  0.7511111111111111
#
# pz model performance (accuracy):  0.7165555555555555
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74234608  9.38173963  9.38050894 -0.1321497   2.72807378]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.346461987481614
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8207890987523256
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7572
#
# DM estimator under NUC:  23.124892930374124
# MIS estimator under NUC:  27.669750567054834
# DRL estimator under NUC:  23.153158185916666
# pa model performance (accuracy):  0.7572
#
# pz model performance (accuracy):  0.7192
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.61690066  9.30067516  9.28731907 -0.14366385  2.73145114]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.1979003389869
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9567389992548667
# Augmentation terms calculation finished.
#
# rep= 88 :
#
# pa model performance (accuracy):  0.739
#
# DM estimator under NUC:  22.810076223037402
# MIS estimator under NUC:  27.819274812531372
# DRL estimator under NUC:  22.920192202033657
# pa model performance (accuracy):  0.739
#
# pz model performance (accuracy):  0.726
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.10116171  9.8740617   9.84453312 -0.21910712  2.81019234]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.743618095964585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -8.43880246653749
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  23.540931298999585
# MIS estimator under NUC:  27.797618911311424
# DRL estimator under NUC:  23.569012788259858
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7195
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.21216053  9.20420354  9.15631243 -0.16174647  2.81526566]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.083635125831403
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.6135768823027923
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  22.60745609790659
# MIS estimator under NUC:  27.441020872106336
# DRL estimator under NUC:  22.646093677190414
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.87025648  9.25830521  9.23283583 -0.12018962  2.74991259]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.941425010924345
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3271955904738644
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76325
#
# DM estimator under NUC:  23.98532569435411
# MIS estimator under NUC:  28.68704038720408
# DRL estimator under NUC:  23.959853577455977
# pa model performance (accuracy):  0.76325
#
# pz model performance (accuracy):  0.71975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.38866666  9.20972903  9.17752567 -0.14764679  2.75279746]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.931805330808334
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1084958968624274
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7606
#
# DM estimator under NUC:  22.873320169889194
# MIS estimator under NUC:  27.666140107208456
# DRL estimator under NUC:  22.915896949589253
# pa model performance (accuracy):  0.7606
#
# pz model performance (accuracy):  0.7172
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.19540049  8.71088311  8.67510933 -0.11614524  2.76932914]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.610929464351397
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.556151277181972
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7628333333333334
#
# DM estimator under NUC:  23.25894028113722
# MIS estimator under NUC:  28.76338530355003
# DRL estimator under NUC:  23.280343267412682
# pa model performance (accuracy):  0.7628333333333334
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.94727126  9.16821154  9.10580443 -0.16460679  2.80964444]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.576167602072886
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.2276171233736148
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7485714285714286
#
# DM estimator under NUC:  23.1544641574894
# MIS estimator under NUC:  27.614811537362254
# DRL estimator under NUC:  23.173122107809654
# pa model performance (accuracy):  0.7485714285714286
#
# pz model performance (accuracy):  0.7075714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.03463923  9.37550989  9.33708764 -0.16734672  2.78482842]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.576569639823074
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1060368194232857
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.755125
#
# DM estimator under NUC:  22.978856647374997
# MIS estimator under NUC:  28.357957323137907
# DRL estimator under NUC:  22.99121811212585
# pa model performance (accuracy):  0.755125
#
# pz model performance (accuracy):  0.719125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.24773545  9.50115618  9.48467222 -0.15653149  2.75244124]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.51846219286059
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.3429385943559062
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7573333333333333
#
# DM estimator under NUC:  23.27148355394082
# MIS estimator under NUC:  28.140640189268638
# DRL estimator under NUC:  23.304619419711205
# pa model performance (accuracy):  0.7573333333333333
#
# pz model performance (accuracy):  0.7136666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.97119923  9.17061653  9.15562722 -0.12755499  2.75042148]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.72006469789387
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.19103720134889393
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7529
#
# DM estimator under NUC:  23.33470312205329
# MIS estimator under NUC:  28.417021221802724
# DRL estimator under NUC:  23.311122402585823
# pa model performance (accuracy):  0.7529
#
# pz model performance (accuracy):  0.7131
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.4272597   9.27119736  9.22968768 -0.14384258  2.76500051]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.20139049743524
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.0569079794790466
# Augmentation terms calculation finished.
#
# rep= 89 :
#
# pa model performance (accuracy):  0.755
#
# DM estimator under NUC:  23.07946688244276
# MIS estimator under NUC:  28.190820250605526
# DRL estimator under NUC:  23.1462713995618
# pa model performance (accuracy):  0.755
#
# pz model performance (accuracy):  0.731
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.60460143 10.09162456 10.07148853 -0.17574758  2.7879935 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.001644333209974
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -7.091537275215294
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.723
#
# DM estimator under NUC:  22.637158458798307
# MIS estimator under NUC:  26.851531598723913
# DRL estimator under NUC:  22.67082807359733
# pa model performance (accuracy):  0.723
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76120562  9.16897113  9.14425451 -0.13215199  2.76974428]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.636330963223585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.1031796570889154
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.756
#
# DM estimator under NUC:  23.08156861880567
# MIS estimator under NUC:  27.36851609018453
# DRL estimator under NUC:  23.063078849658996
# pa model performance (accuracy):  0.756
#
# pz model performance (accuracy):  0.7073333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.28613101  9.23381318  9.19541738 -0.14042815  2.75796114]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.863605985329162
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.040674225872181
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  22.54192886865454
# MIS estimator under NUC:  27.155685745158983
# DRL estimator under NUC:  22.54884150575253
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.71125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.56850634  9.35691536  9.3424928  -0.14661782  2.74432466]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.478241586830396
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.643866691479221
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  23.079764554962694
# MIS estimator under NUC:  27.341198342692678
# DRL estimator under NUC:  23.09619403925042
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.35381775  9.39112688  9.35668547 -0.15415068  2.77254722]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.857771072889783
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.35645530534030906
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7595
#
# DM estimator under NUC:  23.339149828458822
# MIS estimator under NUC:  28.76693726531213
# DRL estimator under NUC:  23.310873508776517
# pa model performance (accuracy):  0.7595
#
# pz model performance (accuracy):  0.7163333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.40646251  9.2779463   9.23974852 -0.1416997   2.75835347]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.324273900060636
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.6677476371737567
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7565714285714286
#
# DM estimator under NUC:  22.99140419327005
# MIS estimator under NUC:  27.28029345011988
# DRL estimator under NUC:  23.029424999945917
# pa model performance (accuracy):  0.7565714285714286
#
# pz model performance (accuracy):  0.7177142857142857
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.06399708  9.19129674  9.12815181 -0.16177959  2.82165923]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.509026526542087
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9796207930621015
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751375
#
# DM estimator under NUC:  23.866164826901827
# MIS estimator under NUC:  27.66612205104557
# DRL estimator under NUC:  23.889173592643697
# pa model performance (accuracy):  0.751375
#
# pz model performance (accuracy):  0.713375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68467333  9.37430831  9.3641635  -0.14000296  2.73730146]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.07013858457278
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9347295715362496
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  23.48262881271524
# MIS estimator under NUC:  28.68488183747538
# DRL estimator under NUC:  23.502910509648952
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7247777777777777
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.98302232  9.39231584  9.35292271 -0.16853243  2.76883842]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.925910744128682
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8606033062124362
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7544
#
# DM estimator under NUC:  22.87006601765211
# MIS estimator under NUC:  27.73411760180064
# DRL estimator under NUC:  22.9013387964309
# pa model performance (accuracy):  0.7544
#
# pz model performance (accuracy):  0.7158
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.45383574  9.48810425  9.47378843 -0.13596218  2.73090433]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.914530456793
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8930312757648544
# Augmentation terms calculation finished.
#
# rep= 90 :
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  21.145424514622718
# MIS estimator under NUC:  26.4880857086724
# DRL estimator under NUC:  21.14459086466424
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.737
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.59206614  9.13675005  9.07215399 -0.16774632  2.77151248]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.11992736137822
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.3758124004716081
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7425
#
# DM estimator under NUC:  23.053426314642053
# MIS estimator under NUC:  27.599332663252262
# DRL estimator under NUC:  23.0661073663743
# pa model performance (accuracy):  0.7425
#
# pz model performance (accuracy):  0.704
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.04495881  8.97840494  8.92235691 -0.15717809  2.76888977]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.711391856481104
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.4614746486738666
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  23.208825459785164
# MIS estimator under NUC:  27.73313198630167
# DRL estimator under NUC:  23.332094566442876
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7043333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74823376  8.96878946  8.91957327 -0.11820124  2.80791294]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.44960584553875
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.3590729475843184
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7625
#
# DM estimator under NUC:  23.323620808676978
# MIS estimator under NUC:  27.18828739792682
# DRL estimator under NUC:  23.455791936405696
# pa model performance (accuracy):  0.7625
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.83989005  9.013927    8.97995463 -0.13248304  2.75690252]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.477691477462805
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8255868106685995
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7704
#
# DM estimator under NUC:  23.228656899180706
# MIS estimator under NUC:  28.264328493933498
# DRL estimator under NUC:  23.240031856086024
# pa model performance (accuracy):  0.7704
#
# pz model performance (accuracy):  0.7278
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.74288775  9.38138859  9.36621981 -0.14274326  2.77135372]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.257456687618316
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1433952391616005
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7528333333333334
#
# DM estimator under NUC:  22.496545091935793
# MIS estimator under NUC:  27.31421559817053
# DRL estimator under NUC:  22.48774309300441
# pa model performance (accuracy):  0.7528333333333334
#
# pz model performance (accuracy):  0.718
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.62768944  9.32439849  9.30350239 -0.13835531  2.74804229]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.507656804853095
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.719683861852792
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7644285714285715
#
# DM estimator under NUC:  23.496990293536342
# MIS estimator under NUC:  28.515275203081284
# DRL estimator under NUC:  23.491576838041023
# pa model performance (accuracy):  0.7644285714285715
#
# pz model performance (accuracy):  0.7175714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.69120904  9.29679404  9.27387599 -0.1289126   2.73984939]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.71202341632063
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4946933466368595
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  22.642085442008852
# MIS estimator under NUC:  27.075390982687637
# DRL estimator under NUC:  22.65391206371192
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.7165
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.86908117  9.03909363  9.00827485 -0.12567256  2.77240174]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.96051861478415
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4345831986663538
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532222222222222
#
# DM estimator under NUC:  22.883524328306574
# MIS estimator under NUC:  27.82577348661745
# DRL estimator under NUC:  22.933179888170006
# pa model performance (accuracy):  0.7532222222222222
#
# pz model performance (accuracy):  0.7192222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80926093  9.382744    9.37650743 -0.13253073  2.72093008]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.13252974276452
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9214937884402193
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7509
#
# DM estimator under NUC:  23.533760979801787
# MIS estimator under NUC:  28.222572196878833
# DRL estimator under NUC:  23.55208273842004
# pa model performance (accuracy):  0.7509
#
# pz model performance (accuracy):  0.7166
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.4914723   9.17979107  9.13813354 -0.14039967  2.78268446]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.463549549543632
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.6893080351171446
# Augmentation terms calculation finished.
#
# rep= 91 :
#
# pa model performance (accuracy):  0.747
#
# DM estimator under NUC:  24.423402067025492
# MIS estimator under NUC:  28.67181758758635
# DRL estimator under NUC:  24.537496876153664
# pa model performance (accuracy):  0.747
#
# pz model performance (accuracy):  0.702
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.53071866  9.34730835  9.3481053  -0.12490362  2.70604308]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.589765609555695
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.9928581815292543
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7415
#
# DM estimator under NUC:  22.167625904829478
# MIS estimator under NUC:  26.685475064559622
# DRL estimator under NUC:  22.340454156403904
# pa model performance (accuracy):  0.7415
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.20350327  9.60335466  9.59948973 -0.14810751  2.73750768]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.852572979524634
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.2559265873474336
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  22.615444500926728
# MIS estimator under NUC:  27.88966675512057
# DRL estimator under NUC:  22.80570150841497
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7183333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.43902385  9.30583535  9.30435442 -0.14561942  2.72270478]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.46250708787406
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.4381123511713227
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7435
#
# DM estimator under NUC:  22.41085505915774
# MIS estimator under NUC:  28.104006046682166
# DRL estimator under NUC:  22.432883141703943
# pa model performance (accuracy):  0.7435
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.13035412  9.29504966  9.26946571 -0.16009616  2.76697522]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.860369170879345
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.34769054712524644
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532
#
# DM estimator under NUC:  22.60753195337557
# MIS estimator under NUC:  27.402817154412045
# DRL estimator under NUC:  22.63327701003363
# pa model performance (accuracy):  0.7532
#
# pz model performance (accuracy):  0.7236
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76993215  9.29338455  9.27434578 -0.1246798   2.7384272 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.748706819189948
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.3559885146850066
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7576666666666667
#
# DM estimator under NUC:  22.642296096029547
# MIS estimator under NUC:  27.771254863564184
# DRL estimator under NUC:  22.71628477210626
# pa model performance (accuracy):  0.7576666666666667
#
# pz model performance (accuracy):  0.7215
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.35207151  9.27528888  9.24065376 -0.15411836  2.76649196]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.389208776330726
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.3289409949284177
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  22.654895829931263
# MIS estimator under NUC:  28.189888664492585
# DRL estimator under NUC:  22.638213431995872
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.7178571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.98785435  9.20168717  9.17601392 -0.13556196  2.75282566]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.85296123373276
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.10713945318576781
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75575
#
# DM estimator under NUC:  22.70812918938116
# MIS estimator under NUC:  27.079580877199568
# DRL estimator under NUC:  22.679432313643684
# pa model performance (accuracy):  0.75575
#
# pz model performance (accuracy):  0.712625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.5341281   9.32551779  9.29702082 -0.13342286  2.76050298]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.755103787549405
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8137339801691854
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7442222222222222
#
# DM estimator under NUC:  22.416092198523526
# MIS estimator under NUC:  27.100413829990366
# DRL estimator under NUC:  22.47826707253585
# pa model performance (accuracy):  0.7442222222222222
#
# pz model performance (accuracy):  0.713
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.55829984  9.20883537  9.13117907 -0.17162933  2.83134878]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.355954317956666
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.782371469099842
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75
#
# DM estimator under NUC:  22.725572883244798
# MIS estimator under NUC:  27.347376124247088
# DRL estimator under NUC:  22.747682290155808
# pa model performance (accuracy):  0.75
#
# pz model performance (accuracy):  0.7186
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.23526449  9.31785088  9.26925451 -0.14701452  2.77650389]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.401301356747737
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.1688549958466408
# Augmentation terms calculation finished.
#
# rep= 92 :
#
# pa model performance (accuracy):  0.758
#
# DM estimator under NUC:  22.125816201817802
# MIS estimator under NUC:  28.014207953535493
# DRL estimator under NUC:  21.94499422022714
# pa model performance (accuracy):  0.758
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.24253453  8.58944118  8.52486205 -0.15408317  2.92388109]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.09319298796361
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.1863386238389937
# Augmentation terms calculation finished.
#
# ...
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9881050349898655
# Augmentation terms calculation finished.
#
# rep= 98 :
#
# pa model performance (accuracy):  0.759
#
# DM estimator under NUC:  23.21341088286099
# MIS estimator under NUC:  28.095039716410987
# DRL estimator under NUC:  22.937835677234215
# pa model performance (accuracy):  0.759
#
# pz model performance (accuracy):  0.712
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [13.85908506  8.60064084  8.34020518 -0.22685409  2.92293698]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.95609895427951
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.1194772220383635
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.77
#
# DM estimator under NUC:  21.017522737641503
# MIS estimator under NUC:  27.481004566222065
# DRL estimator under NUC:  20.94913011684433
# pa model performance (accuracy):  0.77
#
# pz model performance (accuracy):  0.7235
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.93680466  9.26301899  9.20457719 -0.1335427   2.75936008]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.451962253090077
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.496479532565048
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7706666666666667
#
# DM estimator under NUC:  23.86711298711696
# MIS estimator under NUC:  29.11765326322315
# DRL estimator under NUC:  23.942127176907857
# pa model performance (accuracy):  0.7706666666666667
#
# pz model performance (accuracy):  0.7226666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.55419928  9.56900659  9.56535245 -0.148379    2.74093882]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.719376338048967
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.3448145016860241
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76
#
# DM estimator under NUC:  24.49610415250913
# MIS estimator under NUC:  29.46815171514335
# DRL estimator under NUC:  24.59673758236205
# pa model performance (accuracy):  0.76
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.61765839  9.43110844  9.41094606 -0.1282278   2.74666541]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.571065978405997
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.5990844992230381
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.762
#
# DM estimator under NUC:  23.02251615293658
# MIS estimator under NUC:  28.206914467358875
# DRL estimator under NUC:  23.104201726852153
# pa model performance (accuracy):  0.762
#
# pz model performance (accuracy):  0.7258
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.92171771  9.25422811  9.21125367 -0.17213394  2.78572489]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.298107506282527
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.2770596165822798
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7536666666666667
#
# DM estimator under NUC:  23.149966365056326
# MIS estimator under NUC:  28.324850105924106
# DRL estimator under NUC:  23.11512618234221
# pa model performance (accuracy):  0.7536666666666667
#
# pz model performance (accuracy):  0.7208333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.48588119  9.23702061  9.20870568 -0.14999794  2.76020158]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.973056729862556
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5158887248183672
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7571428571428571
#
# DM estimator under NUC:  24.205583265827425
# MIS estimator under NUC:  28.749737833849633
# DRL estimator under NUC:  24.208184112825954
# pa model performance (accuracy):  0.7571428571428571
#
# pz model performance (accuracy):  0.7108571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.08110161  9.31989547  9.30541533 -0.12545778  2.76448867]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.68881064902825
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8378412993879613
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7655
#
# DM estimator under NUC:  22.398540416684668
# MIS estimator under NUC:  27.50651173845459
# DRL estimator under NUC:  22.467443266019306
# pa model performance (accuracy):  0.7655
#
# pz model performance (accuracy):  0.721375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.46054973  9.23434567  9.20014558 -0.15240418  2.77290943]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.202542844291585
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4647066483830022
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7557777777777778
#
# DM estimator under NUC:  22.742538049619455
# MIS estimator under NUC:  27.902475424630865
# DRL estimator under NUC:  22.778474489433442
# pa model performance (accuracy):  0.7557777777777778
#
# pz model performance (accuracy):  0.7234444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.58261972  9.4089738   9.4031728  -0.14750618  2.76328661]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.664930607215553
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3546837576197044
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7498
#
# DM estimator under NUC:  23.197244734577122
# MIS estimator under NUC:  27.794933724262346
# DRL estimator under NUC:  23.19708757315761
# pa model performance (accuracy):  0.7498
#
# pz model performance (accuracy):  0.7155
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.17733603  9.50544997  9.49326013 -0.17127531  2.7334725 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.751268613215657
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1142682859577224
# Augmentation terms calculation finished.
#
# rep= 99 :
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  20.96042865802099
# MIS estimator under NUC:  28.04603112484719
# DRL estimator under NUC:  20.877491791269662
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.82721479  9.20450979  9.19653255 -0.0875744   2.75014944]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.34618914238742
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 7.1608816243915046
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74
#
# DM estimator under NUC:  22.70772155734775
# MIS estimator under NUC:  27.73976933034703
# DRL estimator under NUC:  22.819183734166927
# pa model performance (accuracy):  0.74
#
# pz model performance (accuracy):  0.7125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.09714955  9.10484969  9.02372595 -0.21211115  2.83520082]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.984317693684158
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5421336368726306
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7266666666666667
#
# DM estimator under NUC:  23.61944000321022
# MIS estimator under NUC:  28.23741246764411
# DRL estimator under NUC:  23.64446694207333
# pa model performance (accuracy):  0.7266666666666667
#
# pz model performance (accuracy):  0.6963333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.62234637  9.15390599  9.12879994 -0.12733522  2.76662503]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.71456410074277
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.790474356216582
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7395
#
# DM estimator under NUC:  22.007916422995642
# MIS estimator under NUC:  27.138469097091686
# DRL estimator under NUC:  22.04304186237766
# pa model performance (accuracy):  0.7395
#
# pz model performance (accuracy):  0.72475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.442093    9.34704262  9.27188052 -0.16592629  2.83267106]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.81358591001299
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.4777448087641045
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7656
#
# DM estimator under NUC:  23.80238245423475
# MIS estimator under NUC:  28.60767500041497
# DRL estimator under NUC:  23.793953065297128
# pa model performance (accuracy):  0.7656
#
# pz model performance (accuracy):  0.715
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.43318701  9.34941138  9.32662148 -0.15133177  2.79461283]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.53948686868252
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.465153482686554
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7578333333333334
#
# DM estimator under NUC:  23.35684363562737
# MIS estimator under NUC:  28.242811341169
# DRL estimator under NUC:  23.41074075815143
# pa model performance (accuracy):  0.7578333333333334
#
# pz model performance (accuracy):  0.7193333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.44419497  9.23363196  9.19528925 -0.15693702  2.77941484]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.117973461048198
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3255340353335159
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7697142857142857
#
# DM estimator under NUC:  23.305518439171756
# MIS estimator under NUC:  28.47578682573942
# DRL estimator under NUC:  23.332911844308672
# pa model performance (accuracy):  0.7697142857142857
#
# pz model performance (accuracy):  0.7205714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.51129884  9.42329259  9.40654009 -0.13820217  2.73910677]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.25973723365141
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.9646949803609577
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74475
#
# DM estimator under NUC:  23.03831961106443
# MIS estimator under NUC:  27.412975416214657
# DRL estimator under NUC:  23.104930158534227
# pa model performance (accuracy):  0.74475
#
# pz model performance (accuracy):  0.696875
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.60491102  9.25145053  9.22511367 -0.13066847  2.74087182]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.24981944462801
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.7164844365159104
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7552222222222222
#
# DM estimator under NUC:  23.16294905635492
# MIS estimator under NUC:  27.611333813376824
# DRL estimator under NUC:  23.141860920976494
# pa model performance (accuracy):  0.7552222222222222
#
# pz model performance (accuracy):  0.7058888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.58116876  9.14524425  9.10735911 -0.13772671  2.75812237]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.298443266769763
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.1774505636575299
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  22.88743696402921
# MIS estimator under NUC:  28.08621911008255
# DRL estimator under NUC:  22.852790158565476
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7257
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.99117461  9.27854149  9.26764251 -0.12514505  2.74731342]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.24887212553379
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.202759556698736
# Augmentation terms calculation finished.

# %%
eta_pi_true = 19.99604133247016

# %%
import numpy as np
REP=100
mean_IVRL_DR=(np.sum(est_IVRL_DR,0)/REP)
mean_IVRL_DM=(np.sum(est_IVRL_DM,0)/REP)
mean_DM=(np.sum(est_DM,0)/REP)
mean_MIS=(np.sum(est_MIS,0)/REP)
mean_DRL=(np.sum(est_DRL,0)/REP)

Var_IVRL_DR=np.sum((est_IVRL_DR-mean_IVRL_DR)**2,0)/REP
Var_IVRL_DM=np.sum((est_IVRL_DM-mean_IVRL_DM)**2,0)/REP
Var_DM=np.sum((est_DM-mean_DM)**2,0)/REP
Var_MIS=np.sum((est_MIS-mean_MIS)**2,0)/REP
Var_DRL=np.sum((est_DRL-mean_DRL)**2,0)/REP

# %%
MSE_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true)**2,0)/REP
MSE_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true)**2,0)/REP
MSE_DM=np.sum((est_DM-eta_pi_true)**2,0)/REP
MSE_MIS=np.sum((est_MIS-eta_pi_true)**2,0)/REP
MSE_DRL=np.sum((est_DRL-eta_pi_true)**2,0)/REP

Bias_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true),0)/REP
Bias_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true),0)/REP
Bias_DM=np.sum((est_DM-eta_pi_true),0)/REP
Bias_MIS=np.sum((est_MIS-eta_pi_true),0)/REP
Bias_DRL=np.sum((est_DRL-eta_pi_true),0)/REP

# %%
import matplotlib.pyplot as plt
 
trajectory = [200,300,400,500,600,700,800,900,1000]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

#pyl.xlim(0, 20)
#pyl.ylim(0.25, 2)

ax1.plot(trajectory, np.log(MSE_IVRL_DR/eta_pi_true**2)[1:11] ,marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax1.plot(trajectory, np.log(MSE_DM/eta_pi_true**2)[1:11] ,marker='+', linestyle='--', mec='r', mfc='r', label='DM')
ax1.plot(trajectory, np.log(MSE_MIS/eta_pi_true**2)[1:11] ,marker='v', linestyle='-.', mec='r', mfc='r', label='MIS')
ax1.plot(trajectory, np.log(MSE_DRL/eta_pi_true**2)[1:11] ,marker='x', linestyle=':', mec='r', mfc='r', label='DRL')
ax1.set_xlabel("number of trajectories")
ax1.set_title('log (Relative MSE)')

ax2.plot(trajectory, np.log(abs(Bias_IVRL_DR)/abs(eta_pi_true))[1:11],marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax2.plot(trajectory, np.log(abs(Bias_DM)/abs(eta_pi_true))[1:11],marker='+', linestyle='--', mec='r', mfc='r', label='NUC-DM')
ax2.plot(trajectory, np.log(abs(Bias_MIS)/abs(eta_pi_true))[1:11],marker='v', linestyle='-.', mec='r', mfc='r', label='NUC-MIS')
ax2.plot(trajectory, np.log(abs(Bias_DRL)/abs(eta_pi_true))[1:11],marker='x', linestyle=':', mec='r', mfc='r', label='NUC-DRL')
ax2.set_xlabel("number of trajectories")
ax2.set_title('log (Relative Absolute Bias)')
#plt.legend(loc=(1.05,0.4))
plt.legend(loc="best")
#plt.text(0, -9.4, "Medium Strength Confounder", ha='center')
#plt.xlim(399, 1001)
plt.show()
