# %% [markdown]
# ## Generate simulation data

# %%
import joblib
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from numpy.ma.core import exp
from scipy.special import expit

# %%
# define some functions to generate the simulation data

def generate_S0(n0):
    S01=np.random.normal(size=n0)
    S02=np.random.normal(size=n0)
    return np.vstack((S01,S02)).T

def generate_Ut(n0):
    return np.random.binomial(size=n0, n=1, p=0.5) - 0.5

def generate_Zt(St,n0):
    p=expit(St[:,0]+St[:,1])
    return np.random.binomial(1,p,size=n0)

# 2Zt -> Zt
def generate_At(St,Zt,Ut,n0):
    p=expit(St[:,0]+St[:,1]+Zt+1*Ut)
    return np.random.binomial(1,p,size=n0)

def generate_Rt(St,At,Ut,n0):
    return (St[:,0]+St[:,1]+2*At+5*Ut)

def generate_Stplus1(St,At,Ut,n0):
    Stplus11 = St[:,0] + Ut + (At - 0.5)
    Stplus12 = St[:,1] - Ut - (At - 0.5)
    Stplus = np.vstack((Stplus11,Stplus12)).T
    return Stplus

# %%
# generate simulation dataset
# the number of samples
n=10**3
# the number of stages
T=120
p=2


np.random.seed(525)
S0=generate_S0(n)
MDP = np.copy(S0)
St=S0
for i in range(T):
    Ut=generate_Ut(n)
    Zt=generate_Zt(St,n)
    At=generate_At(St,Zt,Ut,n)
    Rt=generate_Rt(St,At,Ut,n)
    Stplus1=generate_Stplus1(St,At,Ut,n)
    MDP = np.hstack((MDP, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
    St=Stplus1


MDP=MDP[:,(20*(p+3)):(120*(p+3)+p)]
print(np.shape(MDP))
# Out:
# (1000, 502)

# %%
pd.DataFrame(MDP)
# Out:
#            0          1    2    3         4          5          6    7    8    \
# 0    -7.665318   5.507090  0.0  0.0  0.341772  -7.665318   5.507090  1.0  0.0
# 1     9.381374  -7.349269  1.0  1.0  1.532105   9.381374  -7.349269  1.0  1.0
# 2     7.314472  -6.954949  0.0  0.0 -2.140477   6.314472  -5.954949  1.0  1.0
# 3    13.226179 -11.576353  1.0  1.0  6.149827  14.226179 -12.576353  0.0  1.0
# 4     0.545412  -1.115731  0.0  1.0 -1.070319   0.545412  -1.115731  1.0  0.0
# ..         ...        ...  ...  ...       ...        ...        ...  ...  ...
# 995   1.640969  -0.121767  1.0  1.0  6.019202   2.640969  -1.121767  0.0  1.0
# 996   7.410351  -7.092512  0.0  1.0  4.817839   8.410351  -8.092512  0.0  0.0
# 997  -0.795136  -0.038623  1.0  0.0 -3.333758  -1.795136   0.961377  0.0  0.0
# 998   8.153053  -7.755844  0.0  0.0 -2.102792   7.153053  -6.755844  1.0  1.0
# 999  -5.126541   3.867136  0.0  0.0 -3.759405  -6.126541   4.867136  0.0  1.0
#
#           9    ...  492  493       494        495        496  497  498  \
# 0   -4.658228  ...  0.0  0.0  0.341772 -40.665318  38.507090  0.0  0.0
# 1    1.532105  ...  1.0  1.0  6.532105  53.381374 -51.349269  1.0  0.0
# 2   -0.140477  ...  0.0  0.0 -2.140477  26.314472 -25.954949  1.0  1.0
# 3    1.149827  ...  1.0  1.0  1.149827  44.226179 -42.576353  0.0  1.0
# 4    1.929681  ...  1.0  1.0 -1.070319  -2.454588   1.884269  0.0  1.0
# ..        ...  ...  ...  ...       ...        ...        ...  ...  ...
# 995  1.019202  ...  1.0  1.0  6.019202  44.640969 -43.121767  0.0  1.0
# 996  2.817839  ...  0.0  0.0 -2.182161  30.410351 -30.092512  1.0  1.0
# 997 -3.333758  ...  0.0  1.0  3.666242 -19.795136  18.961377  0.0  1.0
# 998 -0.102792  ...  1.0  1.0 -0.102792  12.153053 -11.755844  1.0  1.0
# 999  3.240595  ...  0.0  0.0 -3.759405 -24.126541  22.867136  0.0  0.0
#
#           499        500        501
# 0   -4.658228 -41.665318  39.507090
# 1   -0.467895  52.381374 -50.349269
# 2    4.859523  27.314472 -26.954949
# 3    6.149827  45.226179 -43.576353
# 4    3.929681  -1.454588   0.884269
# ..        ...        ...        ...
# 995  1.019202  44.640969 -43.121767
# 996  4.817839  31.410351 -31.092512
# 997  3.666242 -18.795136  17.961377
# 998 -0.102792  12.153053 -11.755844
# 999  1.240595 -24.126541  22.867136
#
# [1000 rows x 502 columns]

# %%
p=2
#Pi=1
gamma=0.9
domain_At=np.array([0,1])
domain_Zt=np.array([0,1])
max_iter=1000
epsilon=5e-4
T=100

# %%
def Pi(St):
    if len(St.shape) == 0:
        raise ValueError("St should be 1d/2d array")

    if len(St.shape) == 1:
        return 1
        #p = expit(St[0]+St[1]+1.5*expit(St[0]+St[1]))
    else:
        return np.ones(np.shape(St)[0])
        #p = expit(St[:,0]+St[:,1]+1.5*expit(St[:,0]+St[:,1]))

# %% [markdown]
# ## true value

# %%
# approximate the true value of eta_pi by MC method
# the first step is to generate a dataset that follows target policy Pi.
# in this case, we specify At=np.ones(n0)*Pi where Pi can be 0 or 1.

np.random.seed(123)
n0=10**5 # the number of trajectories in MC approximation. The larger the better.
T_burn=20
p=2
T=100 # the number of stages
gamma=0.9

eta_pi_true=0
for repp in range(100):

    S0=generate_S0(n0)
    MDP_burn = np.copy(S0)
    St=S0
    for i in range(T_burn):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=generate_At(St,Zt,Ut,n0)
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP_burn = np.hstack((MDP_burn, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

  #print(np.shape(MDP_burn))


    S0=MDP_burn[:,T_burn*(p+3):(T_burn*(p+3)+2)]

    MDP0 = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=np.random.binomial(n=1, p=Pi(St), size=n0) # generate Ai following Pi
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP0 = np.hstack((MDP0, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1
  #MDP0=MDP0[:,(20*(p+3)):(120*(p+3)+p)]
  #print(np.shape(MDP0))

  # true value of $\eta_{\pi}$ can be estimated by MC method:

    for t in range(T):
        eta_pi_true=eta_pi_true+(gamma**(t))*sum(MDP0[:,(p+2)+(p+3)*t])/n0

        
eta_pi_true=eta_pi_true/100
print(eta_pi_true)
# Out:
# 19.996806609563592

# %%
np.shape(Zt)
# Out:
# (100000,)

# %%
pd.DataFrame(MDP0)
# Out:
#              0          1    2    3         4          5          6    7    \
# 0       6.014786  -5.354693  1.0  1.0  0.160093   6.014786  -5.354693  0.0
# 1      13.275657 -10.343086  1.0  1.0  2.432571  13.275657 -10.343086  1.0
# 2      11.096759 -10.223350  1.0  1.0  5.373409  12.096759 -11.223350  1.0
# 3      11.620527  -9.817214  1.0  1.0  6.303313  12.620527 -10.817214  1.0
# 4       8.270191  -7.059221  0.0  1.0  5.710971   9.270191  -8.059221  1.0
# ...          ...        ...  ...  ...       ...        ...        ...  ...
# 99995  -2.687823   1.920101  0.0  1.0 -1.267723  -2.687823   1.920101  0.0
# 99996   3.978756  -4.450690  0.0  1.0  4.028066   4.978756  -5.450690  0.0
# 99997  12.216641 -10.047447  1.0  1.0  1.669194  12.216641 -10.047447  1.0
# 99998  -1.366799  -0.603489  0.0  1.0  2.529713  -0.366799  -1.603489  0.0
# 99999   1.335805  -1.943831  0.0  1.0 -1.108026   1.335805  -1.943831  0.0
#
#        8         9    ...  492  493       494        495        496  497  498  \
# 0      1.0  0.160093  ...  1.0  1.0  5.160093  51.014786 -50.354693  1.0  1.0
# 1      1.0  7.432571  ...  1.0  1.0  7.432571  64.275657 -61.343086  1.0  1.0
# 2      1.0  0.373409  ...  0.0  1.0  5.373409  55.096759 -54.223350  0.0  1.0
# 3      1.0  6.303313  ...  1.0  1.0  6.303313  59.620527 -57.817214  1.0  1.0
# 4      1.0  5.710971  ...  0.0  1.0  5.710971  53.270191 -52.059221  1.0  1.0
# ...    ...       ...  ...  ...  ...       ...        ...        ...  ...  ...
# 99995  1.0 -1.267723  ...  1.0  1.0  3.732277  55.312177 -56.079899  1.0  1.0
# 99996  1.0 -0.971934  ...  1.0  1.0  4.028066  50.978756 -51.450690  1.0  1.0
# 99997  1.0  1.669194  ...  1.0  1.0  6.669194  56.216641 -54.047447  1.0  1.0
# 99998  1.0 -2.470287  ...  0.0  1.0 -2.470287  41.633201 -43.603489  0.0  1.0
# 99999  1.0 -1.108026  ...  1.0  1.0  3.891974  55.335805 -55.943831  1.0  1.0
#
#             499        500        501
# 0      0.160093  51.014786 -50.354693
# 1      2.432571  64.275657 -61.343086
# 2      5.373409  56.096759 -55.223350
# 3      6.303313  60.620527 -58.817214
# 4      0.710971  53.270191 -52.059221
# ...         ...        ...        ...
# 99995  3.732277  56.312177 -57.079899
# 99996  4.028066  51.978756 -52.450690
# 99997  1.669194  56.216641 -54.047447
# 99998 -2.470287  41.633201 -43.603489
# 99999 -1.108026  55.335805 -55.943831
#
# [100000 rows x 502 columns]

# %% [markdown]
# ## comparison

# %% [markdown]
# #### IVRL

# %%
def IVRL_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # IV+MDP. Off policy evaluation: estimate the averaged treatment effect in infinite-horizon MDP settings
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler
    from numpy.linalg import inv, eigvals

    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T

    index_Z=np.linspace(0,T-1,T)*(p+3)+p
    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2
    index_SZ=np.concatenate((index_S,index_Z))

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_SZ=MDP[:,index_SZ.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Zvec=MDP[:,index_Z.astype(int)].T.reshape(-1,1)
    SZvec=np.hstack((Svec,Zvec))
    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s,z) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(SZvec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(SZvec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")
    def Pa(St,Zt,n,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St,Zt]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(np.concatenate((St,np.array([Zt]))).reshape(1, -1))[0]
      else:
        return A_model.predict_proba(np.hstack((St,Zt)))


    ## (2) estimate P11 := p_a(At=1|Zt=1,St)
    def P11(St,n,A_model):
      if (n==1):
        return Pa(St,1,n,A_model)[1]
      else:
        return Pa(St,np.ones(n).reshape(-1,1),n,A_model)[:,1]

    ## (3) estimate P10 := p_a(At=1|Zt=0,St)
    def P10(St,n,A_model):
      if (n==1):
        return Pa(St,0,n,A_model)[1]
      else:
        return Pa(St,np.zeros(n).reshape(-1,1),n,A_model)[:,1]

    ## (4) estimate c(Zt|St)
    def c(Zt,St,n,Pi,A_model):
      #ratio = np.clip(ratio, a_min=-100, a_max=100)
      if (n==1):
        c=Zt*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c
        return np.clip(c, a_min=-50, a_max=50)
      else:
        c=Zt.T*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt.T)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c[0]
        return np.clip(c[0], a_min=-50, a_max=50)

    ## (5) estimate pz(Zt|St)
    Z_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #Z_model = LogisticRegression()
    Z_model.fit(Svec[range(int(n*T*0.9))], Zvec[range(int(n*T*0.9))].reshape(1,-1)[0])
    print("pz model performance (accuracy): ", Z_model.score(Svec[range(int(n*T*0.9),n*T)], Zvec[range(int(n*T*0.9),n*T)], sample_weight=None),"\n")

    def Pz(Zt,St,n,Z_model):
      if ((n==1) and (p==1)):
        return Z_model.predict_proba(np.array([St]).reshape(1, -1))[0][int(Zt)]
      elif ((n==1) and (p!=1)):
        return Z_model.predict_proba(St.reshape(1, -1))[0][int(Zt)]
      else:
        return Z_model.predict_proba(St)[:,1]*Zt.T[0] + Z_model.predict_proba(St)[:,0]*(1-Zt.T[0])




    ## (6) estimate $\rho(Z_t,S_t)$
    def rho(St,Zt,n,Pi,A_model):
      return c(Zt,St,n,Pi,A_model)/Pz(Zt,St,n,Z_model)

    print("Start estimating omega_pi(St):")
    ## (7) estimate $\omega^{\pi}(s)$: should change if St continuous, and here we only specify linear function class for xi
    class RatioLinearLearner:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, time_difference=None, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=True, rho=rho, A_model=A_model, truncate=100, domain_Zt=np.array([0,1]), domain_At=np.array([0,1])):
            self.use_IV = use_IV

            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])
            if use_IV:
                self.IV = np.copy(dataset['IV']).reshape(-1, 1)
            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)

            self.Pi = Pi

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                ratio = rho(self.state,self.IV,len(self.action),self.Pi,A_model)
            #else:
                  #estimate_pa = self.PALearner.get_pa_prediction(self.state, self.action)
                  #target_pa = self.target_policy_pa(self.policy, self.state, self.action)
                  #pa_ratio = target_pa / estimate_pa
                  #ratio = pa_ratio

            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)

    state_all=Svec
    IV=Zvec.T[0]
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, IV, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action, 'IV': IV,
            'reward': reward, 
            "next_state": next_state_all}

    
    rlearner = RatioLinearLearner(dataset, Pi, ndim = ndim, use_IV= True, rho=rho, A_model=A_model)
    rlearner.fit()
    omega_all=rlearner.get_ratio_prediction(state_all)

    print("omega_pi(St) estimation finished.\n")


    print("Start estimating Q function and Value function (fitted Q evaluation):")
    ## (8) estimate Q function: we only specify Q as a linear function of (St,Zt,At). Can be generalized later.
    # Q function: a linear function of (St,Zt,At). Can be modified later.
    def Q(beta,n,St,Zt,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,Zt,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([Zt]),np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,Zt,At)),beta)################################3

    ## (9) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta, domain_Zt, domain_At, A_model):
      len_Zt=len(domain_Zt)
      len_At=len(domain_At)
      if (n==1):
        V_St=0
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q(beta,n,St,domain_Zt[i],domain_At[j])
            #V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q_model.predict(np.concatenate((St,np.array([domain_Zt[i]]),np.array([domain_At[j]]))))
      else:
        V_St=np.zeros(n)
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i]*np.ones(n).reshape(-1,1),St,n,Pi,A_model)*Pa(St,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]*Q(beta,n,St,domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1))
            #V_St=V_St+c(np.ones(n)*domain_Zt[i].reshape(-1,1),St,n,Pi,A_model)*Pa(St,np.ones(n)*domain_Zt[i].reshape(-1,1),n,A_model)[:,j]*Q_model.predict(np.hstack((St,np.ones(n)*domain_Zt[i].reshape(-1,1),np.ones(n)*domain_At[j].reshape(-1,1))))

      return V_St

    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+2
    nall=n*T
    len_Zt=len(domain_Zt)
    len_At=len(domain_At)
    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p+2)]),axis=1)

      f_tplus1_Q=np.zeros((n,nfeatures+1))
      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      for i in range(len_Zt):
        for j in range(len_At):
          xi_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)],domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1)),axis=1)
          coef_Q=c(domain_Zt[i]*np.ones(n).reshape(-1,1),Stplus1,n,Pi,A_model)*Pa(Stplus1,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]
          f_tplus1_Q=f_tplus1_Q+xi_tplus1_Q* coef_Q[:, np.newaxis]

      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q=np.linalg.solve(part1_Q,part2_Q)

    print("Estimated beta_Q is: ", beta_Q)
    print("Q function and Value function estimation finished.\n")


    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q):
      
      phi_result=0
      #phi_result_part1=0
      #phi_result_part2=0

      for t in range(T):
        if (p==1):
          Pa_At=Pa(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=MDP[i,4*t+1],At=a)

          phi_3=MDP[:,4*t+2]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          #delta_a=np.clip(delta_a, a_min=-50, a_max=50)
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,4*t],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega) !!!!!!!!!!!!!!!
          rho_StZt=rho(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        else:
          Pa_At=Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=MDP[i,(p+3)*t+p],At=a)

          phi_3=MDP[:,(p+3)*t+p+1]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          rho_StZt=rho(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        
        
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2+phi_3))

        #phi_result_part1=phi_result_part1+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2))
        #phi_result_part2=phi_result_part2+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*phi_3)

      phi_result=phi_result/n/(T)
      #phi_result_part1=phi_result_part1/n/(T)
      #phi_result_part2=phi_result_part2/n/(T)

      return phi_result


    print("Start calculating DM estimator:")
    # calculate the direct estimator
    eta_pi_DM=0
    for i in range(n):
      for z in range(2):
        for a in range(2):
          eta_pi_DM=eta_pi_DM+c(Zt=z,St=MDP[i,0:p],n=1,Pi=Pi,A_model=A_model)*Pa(Zt=z,St=MDP[i,0:p],n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,0:p],Zt=z,At=a)
    eta_pi_DM=eta_pi_DM/n
    print("DM estimator: eta_pi_DM=", eta_pi_DM)
    print("DM estimator calculation finished.\n")

    print("Start calculating augmentation terms:")
    # calculate the augmentation terms by function phi_aug
    eta_pi_aug=phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q)
    print("Augmentation term: eta_pi_aug=", eta_pi_aug)
    print("Augmentation terms calculation finished.\n")

    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_DR=eta_pi_DM+eta_pi_aug
    
    return eta_pi_DM, eta_pi_DR

# %% [markdown]
# #### Other methods: NUC

# %%
def DRL_NUC_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # Double reinforcement learning with NO unmeasured confounders. 
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv, eigvals



    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T


    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(Svec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(Svec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")


    def Pa(St,n,p,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(St.reshape(1, -1))[0]
      else:
        return A_model.predict_proba(St)

    #from scipy.interpolate import BSpline


    ## (9) estimate Q function: we only specify Q as a linear function of (St,At). Can be generalized later.
    # Q function: a linear function of (St,At). Can be modified later.
    def Q(beta,n,St,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,At)),beta)################################3

    ## (10) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta):
      # deterministic policy Pi: here we just test Pi=1. The whole function can be generalized to random policy later.
      if (n==1):
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=1)[0])
      else:
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=n).reshape(-1,1))

      return V_St


    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+1
    nall=n*T

    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,((p+3)*t+p+1)].reshape(-1,1)),axis=1)

      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      f_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),Stplus1,np.random.binomial(n=1, p=Pi(MDP[:,(p+3)*t:((p+3)*t+p)]), size=n).reshape(-1,1)),axis=1)


      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q_NUC=np.linalg.solve(part1_Q,part2_Q)

    # DM estimator:
    eta_pi_est_DM_NUC=0
    for i in range(n):
      eta_pi_est_DM_NUC=eta_pi_est_DM_NUC+V(MDP[i,0:p],1,Pi,beta_Q_NUC) # corre
    eta_pi_est_DM_NUC=eta_pi_est_DM_NUC/n

    print("DM estimator under NUC: ",eta_pi_est_DM_NUC) 


    ## (7) estimate beta_pi
    def beta_pi(St,At,p,n,Pi,A_model):
      if (n==1):
        return (Pi(St)*At+(1-Pi(St))*(1-At))/(Pa(St,1,2,A_model)[int(At)])
      else:
        return (Pi(St)*At.T[0]+(1-Pi(St))*(1-At.T[0]))/(At.T[0]*Pa(St,n,2,A_model)[:,1]+(1-At.T[0])*Pa(St,n,2,A_model)[:,0])


    ## (8) estimate $\omega^{\pi}(s)$: here we only specify linear function class for xi
    # -*- coding: utf-8 -*-

    import numpy as np
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler

    class RatioLinearLearner_NUC:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=False, truncate=100):
            self.use_IV=use_IV
            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])

            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)
            self.beta_pi=beta_pi
            self.Pi = Pi
            self.A_model = A_model

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                rho(self.state,self.IV.reshape(-1,1),len(self.action),self.Pi,A_model)
            else:
                ratio = beta_pi(self.state, self.action,p,n,self.Pi,self.A_model)

            # print(np.mean(ratio)) # close to 1 if behaviour and target are the same
            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            # design_matrix = np.zeros((psi.shape[1], psi.shape[1]))
            # for i in range(self.state.shape[0]):
            #     design_matrix += np.matmul(psi[i].reshape(-1, 1), psi_minus_psi_next[i].reshape(1, -1))
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))  
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)


    state_all=Svec
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action,
            'reward': reward, 
            "next_state": next_state_all}

    #dataset, policy, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=100,
    rlearner_NUC = RatioLinearLearner_NUC(dataset, Pi, beta_pi, ndim = ndim, use_IV= False, A_model=A_model)
    rlearner_NUC.fit()
    omega_all_NUC=rlearner_NUC.get_ratio_prediction(state_all)



    '''
    # MIS estimator:
    eta_pi_est_MIS_NUC=0

    for t in range(T):
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)*beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,((p+3)*t+p+1)].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)* MDP[:,((p+3)*t+p+2)]

    eta_pi_est_MIS_NUC=sum(eta_pi_est_MIS_NUC)/n/(T)/(1-gamma)

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    '''

    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC):
      
      phi_result=0
      eta_pi_est_MIS_NUC=0

      for t in range(T):
        if (p==1):
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,4*t].reshape(-1,1),MDP[:,4*t+2].reshape(-1,1))
          #omega_St=omega(MDP[:,4*t].reshape(-1,1),n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,4*t].reshape(-1,1),At=MDP[:,4*t+2].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        else:
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,(p+3)*t+p+1].reshape(-1,1))
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,(p+3)*t+p+1].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(phi_1-phi_2))
        eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(MDP[:,(p+3)*t+p+2]))

      phi_result=phi_result/n/(T)
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC/n/(T)

      return phi_result, eta_pi_est_MIS_NUC


    eta_pi_est_aug_NUC, eta_pi_est_MIS_NUC=phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC)  

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_est_DR_NUC=eta_pi_est_DM_NUC+eta_pi_est_aug_NUC
    print("DRL estimator under NUC: ",eta_pi_est_DR_NUC) 


    return eta_pi_est_MIS_NUC, eta_pi_est_DM_NUC, eta_pi_est_DR_NUC

# %% [markdown]
# #### Run

# %%
import joblib

REP=100
est_IVRL_DR=np.zeros((REP,10))
est_IVRL_DM=np.zeros((REP,10))
est_DM=np.zeros((REP,10))
est_MIS=np.zeros((REP,10))
est_DRL=np.zeros((REP,10))


n_all=np.array([100,200,300,400,500,600,700,800,900,1000])

for rep in range(REP):
  print("rep=",rep,":\n")
  for j in range(10):
    np.random.seed(rep*10+j)
    # generate MDP
    n=n_all[j]

    # the number of stages
    T=120
    p=2

    S0=generate_S0(n)
    MDP_IVRL = np.copy(S0)
    MDP_NUC = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n)
        Zt=generate_Zt(St,n)
        At=generate_At(St,Zt,Ut,n)
        Rt=generate_Rt(St,At,Ut,n)
        Stplus1=generate_Stplus1(St,At,Ut,n)
        MDP_NUC = np.hstack((MDP_NUC, Zt.reshape(-1,1),Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        MDP_IVRL = np.hstack((MDP_IVRL, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

    T=100
    p=3
    MDP_NUC=MDP_NUC[:,(20*(p+3)):(120*(p+3)+p)]
    MDP_NUC= np.hstack((MDP_NUC, Zt.reshape(-1,1)))
    est_MIS[rep,j],est_DM[rep,j],est_DRL[rep,j]=DRL_NUC_TE_est(MDP_NUC, 3, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)

    p=2
    MDP_IVRL=MDP_IVRL[:,(20*(p+3)):(120*(p+3)+p)]
    est_IVRL_DM[rep,j], est_IVRL_DR[rep,j]=IVRL_TE_est(MDP_IVRL, 2, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)
# Out:
# rep= 88 :
#
# pa model performance (accuracy):  0.739
#
# DM estimator under NUC:  25.040384959804168
# MIS estimator under NUC:  29.5991080423622
# DRL estimator under NUC:  25.223911591464816
# pa model performance (accuracy):  0.739
#
# pz model performance (accuracy):  0.726
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [14.03623036  9.746394    9.70740354 -0.33685546  3.3249558 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 15.850612050416327
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -11.194565621448682
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  25.613211156686763
# MIS estimator under NUC:  29.346748299378955
# DRL estimator under NUC:  25.660013638787177
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7195
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.68693422  8.67367256  8.59385405 -0.26957745  3.3587761 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.851050868074257
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.02262813716944
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.745
#
# DM estimator under NUC:  24.62616924771246
# MIS estimator under NUC:  29.00999195514507
# DRL estimator under NUC:  24.690565213185533
# pa model performance (accuracy):  0.745
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.78376079  8.76384201  8.72139305 -0.20031604  3.24985431]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.182784102744634
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.5453259841227794
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76325
#
# DM estimator under NUC:  25.86031604267138
# MIS estimator under NUC:  29.96133413358778
# DRL estimator under NUC:  25.817862514507972
# pa model performance (accuracy):  0.76325
#
# pz model performance (accuracy):  0.71975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.9749983   8.69138435  8.63785263 -0.24619511  3.25456985]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.765355801667457
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8469352892049966
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7606
#
# DM estimator under NUC:  24.862608160124704
# MIS estimator under NUC:  29.170017877447208
# DRL estimator under NUC:  24.933569459624852
# pa model performance (accuracy):  0.7606
#
# pz model performance (accuracy):  0.7172
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.09881058  8.3895052   8.35164261 -0.20284666  3.24947969]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.75970262877882
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.14157943989438
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7628333333333334
#
# DM estimator under NUC:  25.28925488760079
# MIS estimator under NUC:  30.21456043910799
# DRL estimator under NUC:  25.324926531393313
# pa model performance (accuracy):  0.7628333333333334
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.19143379  8.78017185  8.68362838 -0.2764936   3.34090783]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.052982513871342
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9663658339767929
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7485714285714286
#
# DM estimator under NUC:  25.159851095377995
# MIS estimator under NUC:  29.10600452686936
# DRL estimator under NUC:  25.1909476792451
# pa model performance (accuracy):  0.7485714285714286
#
# pz model performance (accuracy):  0.7075714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.37821432  8.98443377  8.92131324 -0.2793201   3.30688262]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.180652001657347
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8728955810144228
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.755125
#
# DM estimator under NUC:  24.991144898643277
# MIS estimator under NUC:  29.782572280956543
# DRL estimator under NUC:  25.011747339894768
# pa model performance (accuracy):  0.755125
#
# pz model performance (accuracy):  0.719125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.74566603  9.18415488  9.15755636 -0.26077738  3.2534191 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.21012376005017
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6671828049653636
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7573333333333333
#
# DM estimator under NUC:  25.246153535083437
# MIS estimator under NUC:  29.575157496013126
# DRL estimator under NUC:  25.301379978034056
# pa model performance (accuracy):  0.7573333333333333
#
# pz model performance (accuracy):  0.7136666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.95199872  8.61769421  8.59271203 -0.21259164  3.25070246]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.99378877500349
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.31839533558209665
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7529
#
# DM estimator under NUC:  25.326474481520165
# MIS estimator under NUC:  29.84384361686284
# DRL estimator under NUC:  25.287173282407878
# pa model performance (accuracy):  0.7529
#
# pz model performance (accuracy):  0.7131
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.04543284  8.78532894  8.71614614 -0.23973763  3.27500086]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.104286773818615
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.4281799657996506
# Augmentation terms calculation finished.
#
# rep= 89 :
#
# pa model performance (accuracy):  0.755
#
# DM estimator under NUC:  25.138875180961783
# MIS estimator under NUC:  29.75238340559335
# DRL estimator under NUC:  25.25021604282675
# pa model performance (accuracy):  0.755
#
# pz model performance (accuracy):  0.731
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.74283142 10.11280512 10.07881831 -0.29098358  3.3099701 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.41285227998331
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -11.343360578420336
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.723
#
# DM estimator under NUC:  24.79495571539111
# MIS estimator under NUC:  28.530829018166926
# DRL estimator under NUC:  24.851071740056323
# pa model performance (accuracy):  0.723
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.62948465  8.63287789  8.59370813 -0.22211642  3.28378788]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.8129494140224
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.832711962684107
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.756
#
# DM estimator under NUC:  24.996499168943483
# MIS estimator under NUC:  28.762043103853372
# DRL estimator under NUC:  24.965682887032223
# pa model performance (accuracy):  0.756
#
# pz model performance (accuracy):  0.7073333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.74650057  8.70178351  8.6342022  -0.23888299  3.2695765 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.562946031939116
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.7176318031543496
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  24.56164512816846
# MIS estimator under NUC:  28.620122432516485
# DRL estimator under NUC:  24.573166189998272
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.71125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.28813644  8.91480141  8.89010984 -0.24428537  3.24005907]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.464110123714832
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.977480186056836
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  25.083249217514183
# MIS estimator under NUC:  28.890953755809054
# DRL estimator under NUC:  25.110631691327022
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.92302958  8.98521147  8.92780911 -0.25691779  3.2875787 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.713260080725124
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.5940921755670598
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7595
#
# DM estimator under NUC:  25.228054847831892
# MIS estimator under NUC:  30.080572616299115
# DRL estimator under NUC:  25.18092764836144
# pa model performance (accuracy):  0.7595
#
# pz model performance (accuracy):  0.7163333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.01077085  8.79657716  8.7329142  -0.23616617  3.26392246]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.203261633835357
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.446246061956901
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7565714285714286
#
# DM estimator under NUC:  25.01860951222023
# MIS estimator under NUC:  28.85786898618018
# DRL estimator under NUC:  25.081977523346627
# pa model performance (accuracy):  0.7565714285714286
#
# pz model performance (accuracy):  0.7177142857142857
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.43999513  8.65216123  8.54691968 -0.26963264  3.36943206]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.21464673434016
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.299367988436409
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.751375
#
# DM estimator under NUC:  25.744860447770428
# MIS estimator under NUC:  29.087602644217178
# DRL estimator under NUC:  25.7832083906737
# pa model performance (accuracy):  0.751375
#
# pz model performance (accuracy):  0.713375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.47445555  8.95718052  8.94027249 -0.23333827  3.22883577]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.084816710550566
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5578826192249324
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  25.39777570186558
# MIS estimator under NUC:  30.04893569698975
# DRL estimator under NUC:  25.431578530088018
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7247777777777777
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.30503721  8.98719307  8.92153785 -0.28088738  3.28139737]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.46991225422238
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4343388436862372
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7544
#
# DM estimator under NUC:  24.72890894970275
# MIS estimator under NUC:  29.130594401922753
# DRL estimator under NUC:  24.781030247667484
# pa model performance (accuracy):  0.7544
#
# pz model performance (accuracy):  0.7158
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.08972623  9.14684041  9.12298072 -0.22660364  3.21817388]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.80301634827256
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4883854596080153
# Augmentation terms calculation finished.
#
# rep= 90 :
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  23.221498305982674
# MIS estimator under NUC:  28.004920272662687
# DRL estimator under NUC:  23.22010888938599
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.737
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.79201398  8.61385597  8.50967049 -0.27908403  3.28331033]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.637975852222315
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.506384615164808
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7425
#
# DM estimator under NUC:  24.941424853698237
# MIS estimator under NUC:  28.949297746877193
# DRL estimator under NUC:  24.96255993991856
# pa model performance (accuracy):  0.7425
#
# pz model performance (accuracy):  0.704
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.40696704  8.29962902  8.20645241 -0.2626535   3.28026754]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.366760761479604
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -6.76623487122667
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  25.24413239269316
# MIS estimator under NUC:  29.286007134732266
# DRL estimator under NUC:  25.44958090378947
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7043333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.55590287  8.2867525   8.20468434 -0.20033549  3.35012953]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.61553619746134
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.18578655830448604
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7625
#
# DM estimator under NUC:  25.347038964728437
# MIS estimator under NUC:  28.787270348424418
# DRL estimator under NUC:  25.567324177609642
# pa model performance (accuracy):  0.7625
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.73082988  8.34366605  8.28616131 -0.22193331  3.2648201 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.639978564268553
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3955854204396778
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7704
#
# DM estimator under NUC:  25.322185636085667
# MIS estimator under NUC:  29.821111604396197
# DRL estimator under NUC:  25.34114389759432
# pa model performance (accuracy):  0.7704
#
# pz model performance (accuracy):  0.7278
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.57147958  8.96898099  8.94369968 -0.23790544  3.28558953]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.370185283484886
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.905658731937742
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7528333333333334
#
# DM estimator under NUC:  24.539886673629926
# MIS estimator under NUC:  28.822094366251967
# DRL estimator under NUC:  24.52521667541088
# pa model performance (accuracy):  0.7528333333333334
#
# pz model performance (accuracy):  0.718
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.37948239  8.87399748  8.83917065 -0.23059218  3.24673714]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.55840619515973
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.532806436422061
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7644285714285715
#
# DM estimator under NUC:  25.36495649815469
# MIS estimator under NUC:  29.835500325111298
# DRL estimator under NUC:  25.355934072328967
# pa model performance (accuracy):  0.7644285714285715
#
# pz model performance (accuracy):  0.7175714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.50637603  8.8590264   8.82292474 -0.2142814   3.23082189]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.783357248304746
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.423749330640106
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  24.69811857596095
# MIS estimator under NUC:  28.631076238703912
# DRL estimator under NUC:  24.717829612132796
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.7165
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.77641064  8.49502516  8.44826793 -0.209398    3.27980322]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.20486690679104
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.396125989940095
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532222222222222
#
# DM estimator under NUC:  24.84847469235525
# MIS estimator under NUC:  29.313918382449547
# DRL estimator under NUC:  24.931233958794266
# pa model performance (accuracy):  0.7532222222222222
#
# pz model performance (accuracy):  0.7192222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.68210155  8.97124     8.96084571 -0.22088455  3.20155013]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.263483716448945
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5358229807335788
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7509
#
# DM estimator under NUC:  25.519893839432818
# MIS estimator under NUC:  29.67657907166412
# DRL estimator under NUC:  25.550430103796643
# pa model performance (accuracy):  0.7509
#
# pz model performance (accuracy):  0.7166
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.15245384  8.63298511  8.5635559  -0.23399945  3.3044741 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.402874789000737
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.8155133918628006
# Augmentation terms calculation finished.
#
# rep= 91 :
#
# pa model performance (accuracy):  0.747
#
# DM estimator under NUC:  26.19388595051976
# MIS estimator under NUC:  29.961490771695413
# DRL estimator under NUC:  26.384043965733458
# pa model performance (accuracy):  0.747
#
# pz model performance (accuracy):  0.702
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.29016831  8.85793846  8.85709833 -0.20810385  3.18076061]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.54192724202554
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.372611778497911
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7415
#
# DM estimator under NUC:  24.03024671009249
# MIS estimator under NUC:  28.17988491845079
# DRL estimator under NUC:  24.318293796049865
# pa model performance (accuracy):  0.7415
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.65949501  9.36348528  9.35803825 -0.24736521  3.22893461]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.470214652820868
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.40576271146388804
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7513333333333333
#
# DM estimator under NUC:  24.575359024589336
# MIS estimator under NUC:  29.388974268395287
# DRL estimator under NUC:  24.89245403706966
# pa model performance (accuracy):  0.7513333333333333
#
# pz model performance (accuracy):  0.7183333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.06503975  8.84305891  8.84059071 -0.24269903  3.20450796]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.320463336167244
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.7301872519518868
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7435
#
# DM estimator under NUC:  24.463155320199785
# MIS estimator under NUC:  29.524471663165286
# DRL estimator under NUC:  24.499868791110234
# pa model performance (accuracy):  0.7435
#
# pz model performance (accuracy):  0.71175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.55421408  8.81962442  8.77671079 -0.26674666  3.27854559]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.550481474491747
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.4802232339636116
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7532
#
# DM estimator under NUC:  24.63526654115995
# MIS estimator under NUC:  28.920821307534556
# DRL estimator under NUC:  24.67817496892369
# pa model performance (accuracy):  0.7532
#
# pz model performance (accuracy):  0.7236
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.61655358  8.82230759  8.79057631 -0.20779967  3.23071199]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.870557984185606
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.9266475244753827
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7576666666666667
#
# DM estimator under NUC:  24.66124820939116
# MIS estimator under NUC:  29.289274503433443
# DRL estimator under NUC:  24.78456266951884
# pa model performance (accuracy):  0.7576666666666667
#
# pz model performance (accuracy):  0.7215
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.92011918  8.79214814  8.73442293 -0.25686393  3.27748659]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.239436009893073
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.548234991547608
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.752
#
# DM estimator under NUC:  24.818848230936524
# MIS estimator under NUC:  29.756127732323886
# DRL estimator under NUC:  24.79104423437784
# pa model performance (accuracy):  0.752
#
# pz model performance (accuracy):  0.7178571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.99182162  8.68036339  8.6384025  -0.22554497  3.25394173]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.15967450802633
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.1974333517757448
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75575
#
# DM estimator under NUC:  24.659735755845528
# MIS estimator under NUC:  28.506921408674724
# DRL estimator under NUC:  24.611907629616198
# pa model performance (accuracy):  0.75575
#
# pz model performance (accuracy):  0.712625
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.22354684  8.87586299  8.82836803 -0.22237143  3.26750497]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.738026752794266
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.3562233002824085
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7442222222222222
#
# DM estimator under NUC:  24.502384664014304
# MIS estimator under NUC:  28.667068170544038
# DRL estimator under NUC:  24.606009454035032
# pa model performance (accuracy):  0.7442222222222222
#
# pz model performance (accuracy):  0.713
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.5971664   8.68139228  8.55196511 -0.28604888  3.38558129]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.73548819640148
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.637285781834924
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75
#
# DM estimator under NUC:  24.75227043544976
# MIS estimator under NUC:  28.90782034351751
# DRL estimator under NUC:  24.78911944696815
# pa model performance (accuracy):  0.75
#
# pz model performance (accuracy):  0.7186
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.72544082  8.8630848   8.78209085 -0.2450242   3.29417315]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.21181789128684
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.614758326411946
# Augmentation terms calculation finished.
#
# rep= 92 :
#
# pa model performance (accuracy):  0.758
#
# DM estimator under NUC:  24.885597799495613
# MIS estimator under NUC:  29.943863778280498
# DRL estimator under NUC:  24.584227830177806
# pa model performance (accuracy):  0.758
#
# pz model performance (accuracy):  0.707
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.65250509  7.67761479  7.5693085  -0.26227823  3.54561253]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.065514117004696
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.254840340045595
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.724
#
# DM estimator under NUC:  24.791333115849273
# MIS estimator under NUC:  28.428930790240116
# DRL estimator under NUC:  24.732522834882968
# pa model performance (accuracy):  0.724
#
# pz model performance (accuracy):  0.701
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.82298427  9.13054202  9.13175118 -0.19732733  3.22334307]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.159864629631933
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.211842568447062
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7536666666666667
#
# DM estimator under NUC:  24.622545077244002
# MIS estimator under NUC:  29.323692328024812
# DRL estimator under NUC:  24.720510967009957
# pa model performance (accuracy):  0.7536666666666667
#
# pz model performance (accuracy):  0.7206666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.86004208  9.77697331  9.77933488 -0.24057706  3.19517055]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.13690569270971
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.5091514457786293
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.765
#
# DM estimator under NUC:  24.60460684775858
# MIS estimator under NUC:  29.177132970624925
# DRL estimator under NUC:  24.738501120145376
# pa model performance (accuracy):  0.765
#
# pz model performance (accuracy):  0.73075
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.61135591  8.78557024  8.74994481 -0.21709383  3.2506067 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.672784953887795
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.23269328382916105
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7752
#
# DM estimator under NUC:  24.834353472481627
# MIS estimator under NUC:  29.420269293510163
# DRL estimator under NUC:  24.84789905650535
# pa model performance (accuracy):  0.7752
#
# pz model performance (accuracy):  0.7154
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.54673479  9.49551296  9.48297383 -0.27345875  3.19778064]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.307330638199563
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.8128256167540246
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7518333333333334
#
# DM estimator under NUC:  24.940432638636832
# MIS estimator under NUC:  29.403239158435518
# DRL estimator under NUC:  24.941726287903343
# pa model performance (accuracy):  0.7518333333333334
#
# pz model performance (accuracy):  0.7108333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.90148502  8.8670064   8.81750062 -0.24712585  3.23418329]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.56281895499879
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7936547708998027
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7505714285714286
#
# DM estimator under NUC:  24.95299145056618
# MIS estimator under NUC:  29.246830309226972
# DRL estimator under NUC:  24.956135344198245
# pa model performance (accuracy):  0.7505714285714286
#
# pz model performance (accuracy):  0.7121428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.82835409  8.90223998  8.86087653 -0.24488214  3.25318473]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.741427476987713
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4252050827362028
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74325
#
# DM estimator under NUC:  24.590626017176582
# MIS estimator under NUC:  28.910086132477502
# DRL estimator under NUC:  24.606455563207227
# pa model performance (accuracy):  0.74325
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.67829477  8.65164271  8.55939385 -0.24242037  3.31392762]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.130435165504064
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.766979779215974
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7615555555555555
#
# DM estimator under NUC:  24.803373737899637
# MIS estimator under NUC:  29.662503182563743
# DRL estimator under NUC:  24.84236983779669
# pa model performance (accuracy):  0.7615555555555555
#
# pz model performance (accuracy):  0.7298888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.62750913  8.91861413  8.89048698 -0.21198492  3.20239159]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.28206265882095
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.3198791776018846
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7543
#
# DM estimator under NUC:  24.388401648636588
# MIS estimator under NUC:  29.067416508276306
# DRL estimator under NUC:  24.310869127228628
# pa model performance (accuracy):  0.7543
#
# pz model performance (accuracy):  0.7137
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.8732084   9.11762785  9.08458657 -0.25562613  3.23969512]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.883181558783132
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.052538601718736
# Augmentation terms calculation finished.
#
# rep= 93 :
#
# pa model performance (accuracy):  0.759
#
# DM estimator under NUC:  26.333911120147913
# MIS estimator under NUC:  31.29381369535999
# DRL estimator under NUC:  26.420479798814327
# pa model performance (accuracy):  0.759
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.82480472  8.64624124  8.60309007 -0.28310856  3.23856665]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.929137846301188
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.8942017994939571
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7625
#
# DM estimator under NUC:  25.02309984924937
# MIS estimator under NUC:  28.869407608893656
# DRL estimator under NUC:  25.169250914379347
# pa model performance (accuracy):  0.7625
#
# pz model performance (accuracy):  0.7285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.6415776   8.94867823  8.89603484 -0.18559322  3.25126297]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.56817472743277
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.840565895247442
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7456666666666667
#
# DM estimator under NUC:  23.613293475519153
# MIS estimator under NUC:  28.077855376458178
# DRL estimator under NUC:  23.751788574672105
# pa model performance (accuracy):  0.7456666666666667
#
# pz model performance (accuracy):  0.731
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.42836457  8.81002884  8.77275177 -0.20402978  3.25057539]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.857479261548562
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.581841473263676
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7605
#
# DM estimator under NUC:  26.025131304942246
# MIS estimator under NUC:  29.899275255532967
# DRL estimator under NUC:  26.087357187238787
# pa model performance (accuracy):  0.7605
#
# pz model performance (accuracy):  0.7245
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.5632493   8.53219846  8.49619858 -0.24568575  3.29068592]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.034492010453256
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.045442952005929
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7456
#
# DM estimator under NUC:  24.54877612571759
# MIS estimator under NUC:  28.627724156474486
# DRL estimator under NUC:  24.564661125444687
# pa model performance (accuracy):  0.7456
#
# pz model performance (accuracy):  0.7074
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.6310085   8.78144829  8.67854255 -0.22544233  3.31164425]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.033776570623036
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.7524117601482772
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7405
#
# DM estimator under NUC:  24.85230616014169
# MIS estimator under NUC:  28.88823850774919
# DRL estimator under NUC:  25.007282040086498
# pa model performance (accuracy):  0.7405
#
# pz model performance (accuracy):  0.7026666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.91528776  8.69926809  8.64500175 -0.24766918  3.26625168]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.514073384548126
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.7047956086341607
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7661428571428571
#
# DM estimator under NUC:  24.594623000872566
# MIS estimator under NUC:  29.491940436729774
# DRL estimator under NUC:  24.71945707966149
# pa model performance (accuracy):  0.766
#
# pz model performance (accuracy):  0.7252857142857143
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.14511484  9.04275751  9.00604086 -0.23595882  3.23732454]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.378067388890038
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.7200657287030199
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7605
#
# DM estimator under NUC:  24.88697481857363
# MIS estimator under NUC:  29.380626844252745
# DRL estimator under NUC:  24.934512680282317
# pa model performance (accuracy):  0.7605
#
# pz model performance (accuracy):  0.718875
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.74390494  9.10801914  9.06112982 -0.25331357  3.27932066]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.245702497418566
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.2952997376444735
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7491111111111111
#
# DM estimator under NUC:  25.170880424992955
# MIS estimator under NUC:  28.61030491300487
# DRL estimator under NUC:  25.173735357532024
# pa model performance (accuracy):  0.7491111111111111
#
# pz model performance (accuracy):  0.7016666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.23845988  8.61148269  8.55940392 -0.25606235  3.28416856]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.973121912265984
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.5496139616889273
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7515
#
# DM estimator under NUC:  24.253473277926265
# MIS estimator under NUC:  28.20376799185507
# DRL estimator under NUC:  24.286547646739137
# pa model performance (accuracy):  0.7515
#
# pz model performance (accuracy):  0.7105
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.42181457  8.63362354  8.58468997 -0.22303061  3.25240374]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.476411639762723
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.0997785920802476
# Augmentation terms calculation finished.
#
# rep= 94 :
#
# pa model performance (accuracy):  0.727
#
# DM estimator under NUC:  22.183471872814508
# MIS estimator under NUC:  27.00185943901439
# DRL estimator under NUC:  22.11835974665856
# pa model performance (accuracy):  0.727
#
# pz model performance (accuracy):  0.708
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.43013948  8.71018994  8.719171   -0.20079183  3.14863211]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.704845766429475
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.163356389122717
# ...
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.3135083916499672
# Augmentation terms calculation finished.
#
# rep= 98 :
#
# pa model performance (accuracy):  0.759
#
# DM estimator under NUC:  25.03108383277072
# MIS estimator under NUC:  29.21793545371375
# DRL estimator under NUC:  24.571791823392587
# pa model performance (accuracy):  0.759
#
# pz model performance (accuracy):  0.712
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [10.94041924  7.73359788  7.29535138 -0.38242388  3.54109187]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 14.444139736227607
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.898291092772988
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.77
#
# DM estimator under NUC:  23.06121640197399
# MIS estimator under NUC:  28.88086123342711
# DRL estimator under NUC:  22.947228700645695
# pa model performance (accuracy):  0.77
#
# pz model performance (accuracy):  0.7235
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.41615537  8.78609438  8.68664171 -0.2179701   3.26559576]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.288737717064954
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.56075616182314
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7706666666666667
#
# DM estimator under NUC:  25.866476662056535
# MIS estimator under NUC:  30.563664718863187
# DRL estimator under NUC:  25.991500311708208
# pa model performance (accuracy):  0.7706666666666667
#
# pz model performance (accuracy):  0.7226666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.25897699  9.20017595  9.18494803 -0.25056498  3.2485136 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.637729838035987
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.5578667294137051
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.76
#
# DM estimator under NUC:  26.389041919459977
# MIS estimator under NUC:  30.86820328212559
# DRL estimator under NUC:  26.556764302548103
# pa model performance (accuracy):  0.76
#
# pz model performance (accuracy):  0.7145
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.35168848  9.06742315  9.03410228 -0.2174744   3.2502726 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.567143287159066
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.0499482071756352
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.762
#
# DM estimator under NUC:  25.050619150003968
# MIS estimator under NUC:  29.666112423401067
# DRL estimator under NUC:  25.186761773196665
# pa model performance (accuracy):  0.762
#
# pz model performance (accuracy):  0.7258
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.20286285  8.75704685  8.68542279 -0.2868899   3.30954148]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.843271405582502
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.12843269430424
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7536666666666667
#
# DM estimator under NUC:  25.189034200851992
# MIS estimator under NUC:  29.7522206538136
# DRL estimator under NUC:  25.1309672296619
# pa model performance (accuracy):  0.7536666666666667
#
# pz model performance (accuracy):  0.7208333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.14313531  8.72836768  8.68117613 -0.24999657  3.26700264]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.89418480885929
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.515383667763823
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7571428571428571
#
# DM estimator under NUC:  26.194968228002228
# MIS estimator under NUC:  30.19930925099363
# DRL estimator under NUC:  26.19930297299972
# pa model performance (accuracy):  0.7571428571428571
#
# pz model performance (accuracy):  0.7108571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.13713664  8.86496179  8.8407872  -0.20901204  3.27415461]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.002429390106172
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.4632937692343526
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7655
#
# DM estimator under NUC:  24.474103509116944
# MIS estimator under NUC:  29.066122022395376
# DRL estimator under NUC:  24.58894159134125
# pa model performance (accuracy):  0.7655
#
# pz model performance (accuracy):  0.721375
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.10091622  8.72390945  8.6669093  -0.25400696  3.28818238]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.147440888459712
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.4411777473047107
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7557777777777778
#
# DM estimator under NUC:  24.782492543193744
# MIS estimator under NUC:  29.39301483566486
# DRL estimator under NUC:  24.842386609550378
# pa model performance (accuracy):  0.7557777777777778
#
# pz model performance (accuracy):  0.7234444444444444
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.3043662   9.01495633  9.00528799 -0.24584363  3.27214434]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.653146805853655
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.257806262700351
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7498
#
# DM estimator under NUC:  25.138546089118567
# MIS estimator under NUC:  29.218845083267293
# DRL estimator under NUC:  25.138284153419367
# pa model performance (accuracy):  0.7498
#
# pz model performance (accuracy):  0.7155
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.62889338  9.17574995  9.15543356 -0.28545886  3.22245417]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.395252553514062
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8571138099301114
# Augmentation terms calculation finished.
#
# rep= 99 :
#
# pa model performance (accuracy):  0.744
#
# DM estimator under NUC:  23.528018351432184
# MIS estimator under NUC:  29.970343509470137
# DRL estimator under NUC:  23.389790240179245
# pa model performance (accuracy):  0.744
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [19.6600989   8.63521199  8.62057021 -0.13788273  3.24742108]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.64625845330812
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 11.243267784978158
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74
#
# DM estimator under NUC:  24.831996968015538
# MIS estimator under NUC:  29.29556940197816
# DRL estimator under NUC:  25.017767262714333
# pa model performance (accuracy):  0.74
#
# pz model performance (accuracy):  0.7125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [14.82858259  8.50808282  8.37287658 -0.35351858  3.39200137]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.959657195241224
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.5702227281212036
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7266666666666667
#
# DM estimator under NUC:  25.562483924089364
# MIS estimator under NUC:  29.65026226513462
# DRL estimator under NUC:  25.604195488861354
# pa model performance (accuracy):  0.7266666666666667
#
# pz model performance (accuracy):  0.6963333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.581758    8.79934535  8.77348972 -0.20474915  3.25061898]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.91373162139385
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -6.586916442419233
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7395
#
# DM estimator under NUC:  24.126608760066073
# MIS estimator under NUC:  28.71217819420958
# DRL estimator under NUC:  24.185151159036156
# pa model performance (accuracy):  0.7395
#
# pz model performance (accuracy):  0.72475
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.40348833  8.9117377   8.78646753 -0.27654381  3.3877851 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.13605790509202
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.129574681273993
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7656
#
# DM estimator under NUC:  25.85909862421067
# MIS estimator under NUC:  30.05246402107089
# DRL estimator under NUC:  25.845049642648
# pa model performance (accuracy):  0.7656
#
# pz model performance (accuracy):  0.715
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.06633032  8.90264944  8.86412756 -0.25205158  3.32512388]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.45102554883363
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.6021083686932287
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7578333333333334
#
# DM estimator under NUC:  25.440643019304158
# MIS estimator under NUC:  29.798039994522707
# DRL estimator under NUC:  25.53047155684455
# pa model performance (accuracy):  0.7578333333333334
#
# pz model performance (accuracy):  0.7193333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.06314586  8.75494163  8.69254188 -0.26188627  3.29725364]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.008102373027157
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.2956539086902645
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7697142857142857
#
# DM estimator under NUC:  25.243082164793
# MIS estimator under NUC:  29.860005237268787
# DRL estimator under NUC:  25.288737840020985
# pa model performance (accuracy):  0.7697142857142857
#
# pz model performance (accuracy):  0.7205714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.18549806  9.03882098  9.01090014 -0.23033696  3.23184462]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.166780155598445
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.6078249672681741
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74475
#
# DM estimator under NUC:  24.90728178272583
# MIS estimator under NUC:  28.847460451925595
# DRL estimator under NUC:  25.018299361842473
# pa model performance (accuracy):  0.74475
#
# pz model performance (accuracy):  0.696875
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.33910711  8.7586781   8.71504886 -0.21787087  3.23442722]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.249084308368626
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.0817467363275797
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7552222222222222
#
# DM estimator under NUC:  25.097669678010465
# MIS estimator under NUC:  29.019937476678933
# DRL estimator under NUC:  25.062522785713057
# pa model performance (accuracy):  0.7552222222222222
#
# pz model performance (accuracy):  0.7058888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.30194793  8.57540709  8.51226519 -0.22954452  3.26353729]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.323493362036686
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.9624176060944196
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.754
#
# DM estimator under NUC:  24.94853256968691
# MIS estimator under NUC:  29.570918937447704
# DRL estimator under NUC:  24.890787893913792
# pa model performance (accuracy):  0.754
#
# pz model performance (accuracy):  0.7257
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.98499082  8.79995044  8.78191232 -0.2085727   3.24540925]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.532967653894907
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.0151006089910326
# Augmentation terms calculation finished.

# %%
eta_pi_true = 19.996806609563592

# %%
import numpy as np
REP=100
mean_IVRL_DR=(np.sum(est_IVRL_DR,0)/REP)
mean_IVRL_DM=(np.sum(est_IVRL_DM,0)/REP)
mean_DM=(np.sum(est_DM,0)/REP)
mean_MIS=(np.sum(est_MIS,0)/REP)
mean_DRL=(np.sum(est_DRL,0)/REP)

Var_IVRL_DR=np.sum((est_IVRL_DR-mean_IVRL_DR)**2,0)/REP
Var_IVRL_DM=np.sum((est_IVRL_DM-mean_IVRL_DM)**2,0)/REP
Var_DM=np.sum((est_DM-mean_DM)**2,0)/REP
Var_MIS=np.sum((est_MIS-mean_MIS)**2,0)/REP
Var_DRL=np.sum((est_DRL-mean_DRL)**2,0)/REP

# %%
MSE_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true)**2,0)/REP
MSE_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true)**2,0)/REP
MSE_DM=np.sum((est_DM-eta_pi_true)**2,0)/REP
MSE_MIS=np.sum((est_MIS-eta_pi_true)**2,0)/REP
MSE_DRL=np.sum((est_DRL-eta_pi_true)**2,0)/REP

Bias_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true),0)/REP
Bias_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true),0)/REP
Bias_DM=np.sum((est_DM-eta_pi_true),0)/REP
Bias_MIS=np.sum((est_MIS-eta_pi_true),0)/REP
Bias_DRL=np.sum((est_DRL-eta_pi_true),0)/REP

# %%
import matplotlib.pyplot as plt
 
trajectory = [200,300,400,500,600,700,800,900,1000]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

#pyl.xlim(0, 20)
#pyl.ylim(0.25, 2)

ax1.plot(trajectory, np.log(MSE_IVRL_DR/eta_pi_true**2)[1:11] ,marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax1.plot(trajectory, np.log(MSE_DM/eta_pi_true**2)[1:11] ,marker='+', linestyle='--', mec='r', mfc='r', label='DM')
ax1.plot(trajectory, np.log(MSE_MIS/eta_pi_true**2)[1:11] ,marker='v', linestyle='-.', mec='r', mfc='r', label='MIS')
ax1.plot(trajectory, np.log(MSE_DRL/eta_pi_true**2)[1:11] ,marker='x', linestyle=':', mec='r', mfc='r', label='DRL')
ax1.set_xlabel("number of trajectories")
ax1.set_title('log (Relative MSE)')

ax2.plot(trajectory, np.log(abs(Bias_IVRL_DR)/abs(eta_pi_true))[1:11],marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax2.plot(trajectory, np.log(abs(Bias_DM)/abs(eta_pi_true))[1:11],marker='+', linestyle='--', mec='r', mfc='r', label='NUC-DM')
ax2.plot(trajectory, np.log(abs(Bias_MIS)/abs(eta_pi_true))[1:11],marker='v', linestyle='-.', mec='r', mfc='r', label='NUC-MIS')
ax2.plot(trajectory, np.log(abs(Bias_DRL)/abs(eta_pi_true))[1:11],marker='x', linestyle=':', mec='r', mfc='r', label='NUC-DRL')
ax2.set_xlabel("number of trajectories")
ax2.set_title('log (Relative Absolute Bias)')
#plt.legend(loc=(1.05,0.4))
plt.legend(loc="best")
#plt.xlim(399, 1001)
#plt.text(0, -6.2, "Medium Strength IV", ha='center')
plt.show()
