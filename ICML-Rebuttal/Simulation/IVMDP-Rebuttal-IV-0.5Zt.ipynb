# %% [markdown]
# ## Description
# In this notebook, we changed the IV strength to **weak** level through function 'generate_At'.

# %% [markdown]
# ## Generate simulation data

# %%
import joblib
import numpy as np
import random
import time
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from numpy.ma.core import exp
from scipy.special import expit

# %%
# define some functions to generate the simulation data

def generate_S0(n0):
    S01=np.random.normal(size=n0)
    S02=np.random.normal(size=n0)
    return np.vstack((S01,S02)).T

def generate_Ut(n0):
    return np.random.binomial(size=n0, n=1, p=0.5) - 0.5

def generate_Zt(St,n0):
    p=expit(St[:,0]+St[:,1])
    return np.random.binomial(1,p,size=n0)

# 2Zt -> 0.5Zt
def generate_At(St,Zt,Ut,n0):
    p=expit(St[:,0]+St[:,1]+0.5*Zt+1*Ut)
    return np.random.binomial(1,p,size=n0)

def generate_Rt(St,At,Ut,n0):
    return (St[:,0]+St[:,1]+2*At+5*Ut)

def generate_Stplus1(St,At,Ut,n0):
    Stplus11 = St[:,0] + Ut + (At - 0.5)
    Stplus12 = St[:,1] - Ut - (At - 0.5)
    Stplus = np.vstack((Stplus11,Stplus12)).T
    return Stplus

# %%
# generate simulation dataset
# the number of samples
n=10**3
# the number of stages
T=120
p=2


np.random.seed(525)
S0=generate_S0(n)
MDP = np.copy(S0)
St=S0
for i in range(T):
    Ut=generate_Ut(n)
    Zt=generate_Zt(St,n)
    At=generate_At(St,Zt,Ut,n)
    Rt=generate_Rt(St,At,Ut,n)
    Stplus1=generate_Stplus1(St,At,Ut,n)
    MDP = np.hstack((MDP, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
    St=Stplus1


MDP=MDP[:,(20*(p+3)):(120*(p+3)+p)]
print(np.shape(MDP))
# Out:
# (1000, 502)

# %%
pd.DataFrame(MDP)
# Out:
#            0          1    2    3         4          5          6    7    8    \
# 0    -7.665318   5.507090  0.0  0.0  0.341772  -7.665318   5.507090  1.0  0.0
# 1     8.381374  -6.349269  1.0  1.0  1.532105   8.381374  -6.349269  1.0  1.0
# 2     6.314472  -5.954949  0.0  0.0 -2.140477   5.314472  -4.954949  1.0  1.0
# 3    12.226179 -10.576353  1.0  1.0  6.149827  13.226179 -11.576353  0.0  1.0
# 4    -1.454588   0.884269  0.0  1.0 -1.070319  -1.454588   0.884269  1.0  0.0
# ..         ...        ...  ...  ...       ...        ...        ...  ...  ...
# 995   1.640969  -0.121767  1.0  1.0  6.019202   2.640969  -1.121767  0.0  1.0
# 996   7.410351  -7.092512  0.0  1.0  4.817839   8.410351  -8.092512  0.0  0.0
# 997  -1.795136   0.961377  1.0  0.0 -3.333758  -2.795136   1.961377  0.0  0.0
# 998   5.153053  -4.755844  0.0  0.0 -2.102792   4.153053  -3.755844  1.0  1.0
# 999  -5.126541   3.867136  0.0  0.0 -3.759405  -6.126541   4.867136  0.0  1.0
#
#           9    ...  492  493       494        495        496  497  498  \
# 0   -4.658228  ...  0.0  0.0  0.341772 -41.665318  39.507090  0.0  0.0
# 1    1.532105  ...  1.0  1.0  6.532105  48.381374 -46.349269  1.0  0.0
# 2   -0.140477  ...  0.0  0.0 -2.140477  24.314472 -23.954949  1.0  1.0
# 3    1.149827  ...  1.0  1.0  1.149827  39.226179 -37.576353  0.0  1.0
# 4    1.929681  ...  1.0  0.0 -3.070319 -10.454588   9.884269  0.0  1.0
# ..        ...  ...  ...  ...       ...        ...        ...  ...  ...
# 995  1.019202  ...  1.0  1.0  6.019202  42.640969 -41.121767  0.0  1.0
# 996  2.817839  ...  0.0  0.0 -2.182161  23.410351 -23.092512  1.0  1.0
# 997 -3.333758  ...  0.0  1.0  3.666242 -22.795136  21.961377  0.0  1.0
# 998 -0.102792  ...  1.0  1.0 -0.102792   6.153053  -5.755844  1.0  0.0
# 999  3.240595  ...  0.0  0.0 -3.759405 -24.126541  22.867136  0.0  0.0
#
#           499        500        501
# 0   -4.658228 -42.665318  40.507090
# 1   -0.467895  47.381374 -45.349269
# 2    4.859523  25.314472 -24.954949
# 3    6.149827  40.226179 -38.576353
# 4    3.929681  -9.454588   8.884269
# ..        ...        ...        ...
# 995  1.019202  42.640969 -41.121767
# 996  4.817839  24.410351 -24.092512
# 997  3.666242 -21.795136  20.961377
# 998 -2.102792   5.153053  -4.755844
# 999  1.240595 -24.126541  22.867136
#
# [1000 rows x 502 columns]

# %%
p=2
#Pi=1
gamma=0.9
domain_At=np.array([0,1])
domain_Zt=np.array([0,1])
max_iter=1000
epsilon=5e-4
T=100

# %%
def Pi(St):
    if len(St.shape) == 0:
        raise ValueError("St should be 1d/2d array")

    if len(St.shape) == 1:
        return 1
        #p = expit(St[0]+St[1]+1.5*expit(St[0]+St[1]))
    else:
        return np.ones(np.shape(St)[0])
        #p = expit(St[:,0]+St[:,1]+1.5*expit(St[:,0]+St[:,1]))

# %% [markdown]
# ## true value

# %%
# approximate the true value of eta_pi by MC method
# the first step is to generate a dataset that follows target policy Pi.
# in this case, we specify At=np.ones(n0)*Pi where Pi can be 0 or 1.

np.random.seed(525)
n0=10**5 # the number of trajectories in MC approximation. The larger the better.
T_burn=20
p=2
T=100 # the number of stages
gamma=0.9

eta_pi_true=0
for repp in range(100):

    S0=generate_S0(n0)
    MDP_burn = np.copy(S0)
    St=S0
    for i in range(T_burn):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=generate_At(St,Zt,Ut,n0)
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP_burn = np.hstack((MDP_burn, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

  #print(np.shape(MDP_burn))


    S0=MDP_burn[:,T_burn*(p+3):(T_burn*(p+3)+2)]

    MDP0 = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n0)
        Zt=generate_Zt(St,n0)
        At=np.random.binomial(n=1, p=Pi(St), size=n0) # generate Ai following Pi
        Rt=generate_Rt(St,At,Ut,n0)
        Stplus1=generate_Stplus1(St,At,Ut,n0)
        MDP0 = np.hstack((MDP0, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1
  #MDP0=MDP0[:,(20*(p+3)):(120*(p+3)+p)]
  #print(np.shape(MDP0))

  # true value of $\eta_{\pi}$ can be estimated by MC method:

    for t in range(T):
        eta_pi_true=eta_pi_true+(gamma**(t))*sum(MDP0[:,(p+2)+(p+3)*t])/n0

        
eta_pi_true=eta_pi_true/100
print(eta_pi_true)
# Out:
# 19.996806609563592

# %%
np.shape(Zt)
# Out:
# (100000,)

# %%
pd.DataFrame(MDP0)
# Out:
#              0          1    2    3         4          5          6    7    \
# 0       6.014786  -5.354693  1.0  1.0  0.160093   6.014786  -5.354693  0.0
# 1      13.275657 -10.343086  1.0  1.0  2.432571  13.275657 -10.343086  1.0
# 2      11.096759 -10.223350  1.0  1.0  5.373409  12.096759 -11.223350  1.0
# 3      11.620527  -9.817214  1.0  1.0  6.303313  12.620527 -10.817214  1.0
# 4       6.270191  -5.059221  0.0  1.0  5.710971   7.270191  -6.059221  1.0
# ...          ...        ...  ...  ...       ...        ...        ...  ...
# 99995  -2.687823   1.920101  0.0  1.0 -1.267723  -2.687823   1.920101  0.0
# 99996   3.978756  -4.450690  0.0  1.0  4.028066   4.978756  -5.450690  0.0
# 99997  12.216641 -10.047447  1.0  1.0  1.669194  12.216641 -10.047447  1.0
# 99998  -1.366799  -0.603489  0.0  1.0  2.529713  -0.366799  -1.603489  0.0
# 99999  -0.664195   0.056169  0.0  1.0 -1.108026  -0.664195   0.056169  0.0
#
#        8         9    ...  492  493       494        495        496  497  498  \
# 0      1.0  0.160093  ...  1.0  1.0  5.160093  51.014786 -50.354693  1.0  1.0
# 1      1.0  7.432571  ...  1.0  1.0  7.432571  64.275657 -61.343086  1.0  1.0
# 2      1.0  0.373409  ...  0.0  1.0  5.373409  55.096759 -54.223350  0.0  1.0
# 3      1.0  6.303313  ...  1.0  1.0  6.303313  59.620527 -57.817214  1.0  1.0
# 4      1.0  5.710971  ...  0.0  1.0  5.710971  51.270191 -50.059221  1.0  1.0
# ...    ...       ...  ...  ...  ...       ...        ...        ...  ...  ...
# 99995  1.0 -1.267723  ...  1.0  1.0  3.732277  55.312177 -56.079899  1.0  1.0
# 99996  1.0 -0.971934  ...  1.0  1.0  4.028066  50.978756 -51.450690  1.0  1.0
# 99997  1.0  1.669194  ...  1.0  1.0  6.669194  56.216641 -54.047447  1.0  1.0
# 99998  1.0 -2.470287  ...  0.0  1.0 -2.470287  41.633201 -43.603489  0.0  1.0
# 99999  1.0 -1.108026  ...  1.0  1.0  3.891974  53.335805 -53.943831  1.0  1.0
#
#             499        500        501
# 0      0.160093  51.014786 -50.354693
# 1      2.432571  64.275657 -61.343086
# 2      5.373409  56.096759 -55.223350
# 3      6.303313  60.620527 -58.817214
# 4      0.710971  51.270191 -50.059221
# ...         ...        ...        ...
# 99995  3.732277  56.312177 -57.079899
# 99996  4.028066  51.978756 -52.450690
# 99997  1.669194  56.216641 -54.047447
# 99998 -2.470287  41.633201 -43.603489
# 99999 -1.108026  53.335805 -53.943831
#
# [100000 rows x 502 columns]

# %% [markdown]
# ## comparison

# %% [markdown]
# #### IVRL

# %%
def IVRL_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # IV+MDP. Off policy evaluation: estimate the averaged treatment effect in infinite-horizon MDP settings
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler
    from numpy.linalg import inv, eigvals

    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T

    index_Z=np.linspace(0,T-1,T)*(p+3)+p
    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2
    index_SZ=np.concatenate((index_S,index_Z))

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_SZ=MDP[:,index_SZ.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Zvec=MDP[:,index_Z.astype(int)].T.reshape(-1,1)
    SZvec=np.hstack((Svec,Zvec))
    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s,z) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(SZvec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(SZvec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")
    def Pa(St,Zt,n,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St,Zt]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(np.concatenate((St,np.array([Zt]))).reshape(1, -1))[0]
      else:
        return A_model.predict_proba(np.hstack((St,Zt)))


    ## (2) estimate P11 := p_a(At=1|Zt=1,St)
    def P11(St,n,A_model):
      if (n==1):
        return Pa(St,1,n,A_model)[1]
      else:
        return Pa(St,np.ones(n).reshape(-1,1),n,A_model)[:,1]

    ## (3) estimate P10 := p_a(At=1|Zt=0,St)
    def P10(St,n,A_model):
      if (n==1):
        return Pa(St,0,n,A_model)[1]
      else:
        return Pa(St,np.zeros(n).reshape(-1,1),n,A_model)[:,1]

    ## (4) estimate c(Zt|St)
    def c(Zt,St,n,Pi,A_model):
      #ratio = np.clip(ratio, a_min=-100, a_max=100)
      if (n==1):
        c=Zt*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c
        return np.clip(c, a_min=-50, a_max=50)
      else:
        c=Zt.T*((Pi(St)-P10(St,n,A_model))/(P11(St,n,A_model)-P10(St,n,A_model)))+(1-Zt.T)*((P11(St,n,A_model)-Pi(St))/(P11(St,n,A_model)-P10(St,n,A_model)))
        #return c[0]
        return np.clip(c[0], a_min=-50, a_max=50)

    ## (5) estimate pz(Zt|St)
    Z_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #Z_model = LogisticRegression()
    Z_model.fit(Svec[range(int(n*T*0.9))], Zvec[range(int(n*T*0.9))].reshape(1,-1)[0])
    print("pz model performance (accuracy): ", Z_model.score(Svec[range(int(n*T*0.9),n*T)], Zvec[range(int(n*T*0.9),n*T)], sample_weight=None),"\n")

    def Pz(Zt,St,n,Z_model):
      if ((n==1) and (p==1)):
        return Z_model.predict_proba(np.array([St]).reshape(1, -1))[0][int(Zt)]
      elif ((n==1) and (p!=1)):
        return Z_model.predict_proba(St.reshape(1, -1))[0][int(Zt)]
      else:
        return Z_model.predict_proba(St)[:,1]*Zt.T[0] + Z_model.predict_proba(St)[:,0]*(1-Zt.T[0])




    ## (6) estimate $\rho(Z_t,S_t)$
    def rho(St,Zt,n,Pi,A_model):
      return c(Zt,St,n,Pi,A_model)/Pz(Zt,St,n,Z_model)

    print("Start estimating omega_pi(St):")
    ## (7) estimate $\omega^{\pi}(s)$: should change if St continuous, and here we only specify linear function class for xi
    class RatioLinearLearner:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, time_difference=None, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=True, rho=rho, A_model=A_model, truncate=100, domain_Zt=np.array([0,1]), domain_At=np.array([0,1])):
            self.use_IV = use_IV

            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])
            if use_IV:
                self.IV = np.copy(dataset['IV']).reshape(-1, 1)
            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)

            self.Pi = Pi

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                ratio = rho(self.state,self.IV,len(self.action),self.Pi,A_model)
            #else:
                  #estimate_pa = self.PALearner.get_pa_prediction(self.state, self.action)
                  #target_pa = self.target_policy_pa(self.policy, self.state, self.action)
                  #pa_ratio = target_pa / estimate_pa
                  #ratio = pa_ratio

            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)

    state_all=Svec
    IV=Zvec.T[0]
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, IV, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action, 'IV': IV,
            'reward': reward, 
            "next_state": next_state_all}

    
    rlearner = RatioLinearLearner(dataset, Pi, ndim = ndim, use_IV= True, rho=rho, A_model=A_model)
    rlearner.fit()
    omega_all=rlearner.get_ratio_prediction(state_all)

    print("omega_pi(St) estimation finished.\n")


    print("Start estimating Q function and Value function (fitted Q evaluation):")
    ## (8) estimate Q function: we only specify Q as a linear function of (St,Zt,At). Can be generalized later.
    # Q function: a linear function of (St,Zt,At). Can be modified later.
    def Q(beta,n,St,Zt,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,Zt,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([Zt]),np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,Zt,At)),beta)################################3

    ## (9) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta, domain_Zt, domain_At, A_model):
      len_Zt=len(domain_Zt)
      len_At=len(domain_At)
      if (n==1):
        V_St=0
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q(beta,n,St,domain_Zt[i],domain_At[j])
            #V_St=V_St+c(domain_Zt[i],St,n,Pi,A_model)*Pa(St,domain_Zt[i],n,A_model)[j]*Q_model.predict(np.concatenate((St,np.array([domain_Zt[i]]),np.array([domain_At[j]]))))
      else:
        V_St=np.zeros(n)
        for i in range(len_Zt):
          for j in range(len_At):
            V_St=V_St+c(domain_Zt[i]*np.ones(n).reshape(-1,1),St,n,Pi,A_model)*Pa(St,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]*Q(beta,n,St,domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1))
            #V_St=V_St+c(np.ones(n)*domain_Zt[i].reshape(-1,1),St,n,Pi,A_model)*Pa(St,np.ones(n)*domain_Zt[i].reshape(-1,1),n,A_model)[:,j]*Q_model.predict(np.hstack((St,np.ones(n)*domain_Zt[i].reshape(-1,1),np.ones(n)*domain_At[j].reshape(-1,1))))

      return V_St

    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+2
    nall=n*T
    len_Zt=len(domain_Zt)
    len_At=len(domain_At)
    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p+2)]),axis=1)

      f_tplus1_Q=np.zeros((n,nfeatures+1))
      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      for i in range(len_Zt):
        for j in range(len_At):
          xi_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)],domain_Zt[i]*np.ones(n).reshape(-1,1),domain_At[j]*np.ones(n).reshape(-1,1)),axis=1)
          coef_Q=c(domain_Zt[i]*np.ones(n).reshape(-1,1),Stplus1,n,Pi,A_model)*Pa(Stplus1,domain_Zt[i]*np.ones(n).reshape(-1,1),n,A_model)[:,j]
          f_tplus1_Q=f_tplus1_Q+xi_tplus1_Q* coef_Q[:, np.newaxis]

      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q=np.linalg.solve(part1_Q,part2_Q)

    print("Estimated beta_Q is: ", beta_Q)
    print("Q function and Value function estimation finished.\n")


    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q):
      
      phi_result=0
      #phi_result_part1=0
      #phi_result_part2=0

      for t in range(T):
        if (p==1):
          Pa_At=Pa(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=MDP[i,4*t+1],At=a)

          phi_3=MDP[:,4*t+2]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,4*t].reshape(-1,1),Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          #delta_a=np.clip(delta_a, a_min=-50, a_max=50)
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,4*t],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,4*t],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega) !!!!!!!!!!!!!!!
          rho_StZt=rho(St=MDP[:,4*t].reshape(-1,1),Zt=MDP[:,4*t+1].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        else:
          Pa_At=Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n, A_model=A_model)
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q, domain_Zt=domain_Zt, domain_At=domain_At, A_model=A_model)
          phi_2=np.zeros(n)
          for i in range(n):
            for a in domain_At:
              phi_2[i]=phi_2[i]+Pa_At[i,a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=MDP[i,(p+3)*t+p],At=a)

          phi_3=MDP[:,(p+3)*t+p+1]-Pa_At[:,1]
          phi_3_2=np.zeros(n)
          delta_a=(Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.ones(n).reshape(-1,1),n=n, A_model=A_model)-Pa(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=np.zeros(n).reshape(-1,1),n=n, A_model=A_model))[:,1]
          delta_a[np.where(abs(delta_a)<1e-2)]=np.sign(delta_a[np.where(abs(delta_a)<1e-2)])*1e-2
          for i in range(n):
            for z in domain_Zt:
              for a in domain_At:
                phi_3_2[i]=phi_3_2[i]+(-1)**z/(delta_a[i])*Pa(St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,(p+3)*t:((p+3)*t+p)],Zt=z,At=a)
          
          phi_3=phi_3*phi_3_2
          rho_StZt=rho(St=MDP[:,(p+3)*t:((p+3)*t+p)],Zt=MDP[:,(p+3)*t+p].reshape(-1,1),n=n,Pi=Pi,A_model=A_model)
        
        
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2+phi_3))

        #phi_result_part1=phi_result_part1+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*(phi_1-phi_2))
        #phi_result_part2=phi_result_part2+np.sum(1/(1-gamma)*omega_all[t*n:(t+1)*n]*rho_StZt*phi_3)

      phi_result=phi_result/n/(T)
      #phi_result_part1=phi_result_part1/n/(T)
      #phi_result_part2=phi_result_part2/n/(T)

      return phi_result


    print("Start calculating DM estimator:")
    # calculate the direct estimator
    eta_pi_DM=0
    for i in range(n):
      for z in range(2):
        for a in range(2):
          eta_pi_DM=eta_pi_DM+c(Zt=z,St=MDP[i,0:p],n=1,Pi=Pi,A_model=A_model)*Pa(Zt=z,St=MDP[i,0:p],n=1,A_model=A_model)[a]*Q(beta=beta_Q,n=1,St=MDP[i,0:p],Zt=z,At=a)
    eta_pi_DM=eta_pi_DM/n
    print("DM estimator: eta_pi_DM=", eta_pi_DM)
    print("DM estimator calculation finished.\n")

    print("Start calculating augmentation terms:")
    # calculate the augmentation terms by function phi_aug
    eta_pi_aug=phi_aug(MDP,omega_all,rho,Q,V,Pa,c,beta_Q)
    print("Augmentation term: eta_pi_aug=", eta_pi_aug)
    print("Augmentation terms calculation finished.\n")

    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_DR=eta_pi_DM+eta_pi_aug
    
    return eta_pi_DM, eta_pi_DR

# %% [markdown]
# #### Other methods: NUC

# %%
def DRL_NUC_TE_est(MDP, p, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3, ndim=100, l2penalty=1e-3):

    # =============================================================================
    # Double reinforcement learning with NO unmeasured confounders. 
    # -------------------------------------------------------------------------
    #  parameters:
    #  MDP: dataframe, which contains all observed data formalized 
    #       as (St,Zt,At,Rt) from stage 1 to T. St can be multi-dimensional.
    #  p: the dimension of state variable St
    #  n: the number of trajectories
    #  T: the number of stages
    #  Pi: the target policy we want to evaluate
    #  gamma: discount factor
    #  domain_At: the domain/support of action space
    #  domain_Zt: the domain/support of IV space
    #  max_iter: maximum number of iterations in fitted-Q evaluation
    #  epsilon: error bound in fitted-Q evaluation
    #  
    #  
    # =============================================================================


    # load packages
    import joblib
    import numpy as np
    import random
    import time
    import pandas as pd
    import matplotlib.pyplot as plt

    from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
    from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
    from sklearn.metrics import r2_score, mean_squared_error, accuracy_score, f1_score, recall_score
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import OneHotEncoder, LabelEncoder
    from sklearn.impute import SimpleImputer
    from sklearn.neural_network import MLPRegressor
    from sklearn.linear_model import LinearRegression
    from sklearn.linear_model import LogisticRegression
    from numpy.linalg import inv, eigvals



    # vectorize the data for further use
    if (p==1):
      index_S=np.linspace(0,T-1,T)*4
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S.astype(int)].T.reshape(-1,1)
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(-1,1)
    else:
      index_S=np.linspace(0,T-1,T)*(p+3)
      for i in range(1,p):
        index_S=np.concatenate((index_S,(np.linspace(0,T-1,T)*(p+3)+i))).astype(int)
      index_Splus1=index_S+(p+3)
      Svec=MDP[:,index_S].T.reshape(p,-1).T
      Splus1_vec=MDP[:,index_Splus1.astype(int)].T.reshape(p,-1).T


    index_A=np.linspace(0,T-1,T)*(p+3)+p+1
    index_R=np.linspace(0,T-1,T)*(p+3)+p+2

    MDP_S=MDP[:,index_S.astype(int)]
    MDP_A=MDP[:,index_A.astype(int)]

    Avec=MDP[:,index_A.astype(int)].T.reshape(-1,1)
    Rvec=MDP[:,index_R.astype(int)].T.reshape(-1,1)

    nall=n*T

    # estimate models:
    ## (1) estimate Action model p_a(a|s) with the first 90% samples
    A_model = GradientBoostingClassifier(n_estimators = 20, max_depth = 5)
    #A_model = LogisticRegression()
    A_model.fit(Svec[range(int(nall*0.9))], Avec[range(int(nall*0.9))].reshape(1,-1)[0])
    # print out the accuracy of the classifier for p_a(a|s,z) with the last 10% samples
    print("pa model performance (accuracy): ", A_model.score(Svec[range(int(nall*0.9),nall)], Avec[range(int(nall*0.9),nall)], sample_weight=None),"\n")


    def Pa(St,n,p,A_model):
      if ((n==1) and (p==1)):
        return A_model.predict_proba(np.array([St]).reshape(1, -1))[0]
      elif ((n==1) and (p!=1)):
        return A_model.predict_proba(St.reshape(1, -1))[0]
      else:
        return A_model.predict_proba(St)

    #from scipy.interpolate import BSpline


    ## (9) estimate Q function: we only specify Q as a linear function of (St,At). Can be generalized later.
    # Q function: a linear function of (St,At). Can be modified later.
    def Q(beta,n,St,At):
      if ((n==1) and (p==1)):
        #return np.dot(np.array([St,Zt,At]),beta)
        return np.dot(np.array([1,St,At]),beta)
      elif ((n==1) and (p!=1)):
        #return np.dot(np.concatenate((St,np.array([Zt]),np.array([At]))),beta)
        return np.dot(np.concatenate((np.array([1]),St,np.array([At]))),beta)
      else:
        #return np.dot(np.hstack((St,Zt,At)),beta)
        return np.dot(np.hstack((np.ones(n).reshape(-1,1),St,At)),beta)################################3

    ## (10) estimate Value function based on Q function estimation result 
    def V(St, n, Pi, beta):
      # deterministic policy Pi: here we just test Pi=1. The whole function can be generalized to random policy later.
      if (n==1):
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=1)[0])
      else:
        V_St=Q(beta,n,St,np.random.binomial(n=1, p=Pi(St), size=n).reshape(-1,1))

      return V_St


    # estimate the parameters beta in both Q function and Value function
    nfeatures=p+1
    nall=n*T

    part1_Q=0
    part2_Q=0
    for t in range(T):
      xi_t_Q=np.concatenate((np.ones(n).reshape(-1,1),MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,((p+3)*t+p+1)].reshape(-1,1)),axis=1)

      Stplus1=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)]
      f_tplus1_Q=np.concatenate((np.ones(n).reshape(-1,1),Stplus1,np.random.binomial(n=1, p=Pi(MDP[:,(p+3)*t:((p+3)*t+p)]), size=n).reshape(-1,1)),axis=1)


      part1_Q=part1_Q+np.matmul(xi_t_Q.T,(xi_t_Q-gamma*f_tplus1_Q))
      R_t_Q=MDP[:,((p+3)*t+p+2)]
      part2_Q=part2_Q+np.sum(xi_t_Q*R_t_Q[:, np.newaxis],axis=0)

    beta_Q_NUC=np.linalg.solve(part1_Q,part2_Q)

    # DM estimator:
    eta_pi_est_DM_NUC=0
    for i in range(n):
      eta_pi_est_DM_NUC=eta_pi_est_DM_NUC+V(MDP[i,0:p],1,Pi,beta_Q_NUC) # corre
    eta_pi_est_DM_NUC=eta_pi_est_DM_NUC/n

    print("DM estimator under NUC: ",eta_pi_est_DM_NUC) 


    ## (7) estimate beta_pi
    def beta_pi(St,At,p,n,Pi,A_model):
      if (n==1):
        return (Pi(St)*At+(1-Pi(St))*(1-At))/(Pa(St,1,2,A_model)[int(At)])
      else:
        return (Pi(St)*At.T[0]+(1-Pi(St))*(1-At.T[0]))/(At.T[0]*Pa(St,n,2,A_model)[:,1]+(1-At.T[0])*Pa(St,n,2,A_model)[:,0])


    ## (8) estimate $\omega^{\pi}(s)$: here we only specify linear function class for xi
    # -*- coding: utf-8 -*-

    import numpy as np
    from numpy.linalg import inv
    from sklearn.kernel_approximation import RBFSampler

    class RatioLinearLearner_NUC:
        '''
        Input
        --------
        cplearner is an object of rho or PALearner. 
        It gives estimators for conditional probability of behaviour policy: 
        P(action|state) (if input a PALearner), P(mediator|action, state) (if input a PMLearner).
        Examples
        --------
        '''
        def __init__(self, dataset, Pi, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=ndim, l2penalty=l2penalty, use_IV=False, truncate=100):
            self.use_IV=use_IV
            self.state = np.copy(dataset['state'])
            self.action = np.copy(dataset['action']).reshape(-1, 1)
            self.unique_action = np.unique(dataset['action'])

            self.next_state = np.copy(dataset['next_state'])
            self.s0 = np.copy(dataset['s0'])
            if time_difference is None:
                self.time_difference = np.ones(self.action.shape[0])
            else:
                self.time_difference = np.copy(time_difference)
            self.beta_pi=beta_pi
            self.Pi = Pi
            self.A_model = A_model

            self.gamma = gamma
            self.l2penalty = l2penalty
            self.beta = None
            self.rbf_feature = RBFSampler(random_state=1, n_components=ndim)
            self.rbf_feature.fit(np.vstack((self.state, self.s0)))
            self.truncate = truncate
            pass

        def feature_engineering(self, feature):
            feature_new = self.rbf_feature.transform(feature)
            feature_new = np.hstack([np.repeat(1, feature_new.shape[0]).reshape(-1, 1), feature_new])
            return feature_new


        def fit(self):
            psi = self.feature_engineering(self.state)
            psi_next = self.feature_engineering(self.next_state)
            if self.use_IV:
                rho(self.state,self.IV.reshape(-1,1),len(self.action),self.Pi,A_model)
            else:
                ratio = beta_pi(self.state, self.action,p,n,self.Pi,self.A_model)

            # print(np.mean(ratio)) # close to 1 if behaviour and target are the same
            psi_minus_psi_next = self.rbf_difference(psi, psi_next, ratio)
            # design_matrix = np.zeros((psi.shape[1], psi.shape[1]))
            # for i in range(self.state.shape[0]):
            #     design_matrix += np.matmul(psi[i].reshape(-1, 1), psi_minus_psi_next[i].reshape(1, -1))
            design_matrix = np.matmul(psi.transpose(), psi_minus_psi_next)
            design_matrix /= self.state.shape[0]
            # print(design_matrix)

            min_eigen_value = np.min(eigvals(design_matrix).real)
            if min_eigen_value >= 1e-5:
                penalty_matrix = np.diagflat(np.repeat(np.abs(min_eigen_value) * self.l2penalty + 1e-5, design_matrix.shape[0]))  
            else:
                penalty_matrix = np.diagflat(np.repeat(1e-5, design_matrix.shape[0]))
            # if psi.shape[0] <= psi.shape[1]:
            #     penalty_matrix = np.diagflat(np.repeat(self.l2penalty, design_matrix.shape[0]))
            # else:
            #     penalty_matrix = np.zeros(design_matrix.shape)
            
            penalize_design_matrix = design_matrix + penalty_matrix
            inv_design_matrix = inv(penalize_design_matrix)

            # psi_s0 = self.feature_engineering(self.s0)
            # mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            # print(mean_psi_s0)
            mean_psi_s0 = self.ratio_expectation_s0(np.copy(self.s0))

            beta = np.matmul(inv_design_matrix, mean_psi_s0.reshape(-1, 1))
            self.beta = beta
            pass
        
        def rbf_difference(self, psi, psi_next, ratio):
            # psi_next = self.gamma * (psi_next.transpose() * ratio).transpose()
            psi_next = np.multiply((psi_next.transpose() * ratio).transpose(),
                                  np.power(self.gamma, self.time_difference)[:, np.newaxis])
            psi_minus_psi_next = psi - psi_next
            return psi_minus_psi_next

        def get_ratio_prediction(self, state, normalize=True):
            '''
            Input:
            state: a numpy.array
            Output:
            A 1D numpy array. The probability ratio in certain states.
            '''
            if np.ndim(state) == 0 or np.ndim(state) == 1:
                x_state = np.reshape(state, (1, -1))
            else:
                x_state = np.copy(state)
            psi = self.feature_engineering(x_state)
            ratio = np.matmul(psi, self.beta).flatten()
            ratio_min = 1 / self.truncate
            ratio_max = self.truncate
            ratio = np.clip(ratio, a_min=ratio_min, a_max=ratio_max)
            if state.shape[0] > 1:
                if normalize:
                    ratio /= np.mean(ratio)
            return ratio
        
        def ratio_expectation_s0(self, s0):
            psi_s0 = self.feature_engineering(s0)
            mean_psi_s0 = (1 - self.gamma) * np.mean(psi_s0, axis=0)
            return mean_psi_s0

        def get_r_prediction(self, state, normalize=True):
            return self.get_ratio_prediction(state, normalize)


    state_all=Svec
    action=Avec.T[0]
    reward=Rvec.T[0]
    next_state_all=Splus1_vec

    iid_dataset = [state_all, action, reward, next_state_all]

    s0=MDP[:,0:p]
    dataset = {'s0': s0, 'state': state_all, 
            'action': action,
            'reward': reward, 
            "next_state": next_state_all}

    #dataset, policy, beta_pi, time_difference=None, A_model=A_model, gamma=0.9, ndim=100,
    rlearner_NUC = RatioLinearLearner_NUC(dataset, Pi, beta_pi, ndim = ndim, use_IV= False, A_model=A_model)
    rlearner_NUC.fit()
    omega_all_NUC=rlearner_NUC.get_ratio_prediction(state_all)



    '''
    # MIS estimator:
    eta_pi_est_MIS_NUC=0

    for t in range(T):
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)*beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,((p+3)*t+p+1)].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)* MDP[:,((p+3)*t+p+2)]

    eta_pi_est_MIS_NUC=sum(eta_pi_est_MIS_NUC)/n/(T)/(1-gamma)

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    '''

    # calculate the augmentation terms in our DR estimator by function phi_aug
    def phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC):
      
      phi_result=0
      eta_pi_est_MIS_NUC=0

      for t in range(T):
        if (p==1):
          phi_1=MDP[:,4*t+3]+gamma*V(St=MDP[:,4*t+4].reshape(-1,1), n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,4*t].reshape(-1,1),MDP[:,4*t+2].reshape(-1,1))
          #omega_St=omega(MDP[:,4*t].reshape(-1,1),n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,4*t].reshape(-1,1),At=MDP[:,4*t+2].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        else:
          phi_1=MDP[:,(p+3)*t+p+2]+gamma*V(St=MDP[:,(p+3)*(t+1):((p+3)*(t+1)+p)], n=n, Pi=Pi, beta=beta_Q_NUC)
          phi_2=Q(beta_Q_NUC,n,MDP[:,(p+3)*t:((p+3)*t+p)],MDP[:,(p+3)*t+p+1].reshape(-1,1))
          #omega_St=omega(MDP[:,(p+3)*t:((p+3)*t+p)],n,p,beta_omega_NUC)
          beta_St=beta_pi(St=MDP[:,(p+3)*t:((p+3)*t+p)],At=MDP[:,(p+3)*t+p+1].reshape(-1,1),p=p,n=n,Pi=Pi,A_model=A_model)
          beta_St=np.clip(beta_St,a_min=-100,a_max=100)
        phi_result=phi_result+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(phi_1-phi_2))
        eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC+np.sum(1/(1-gamma)*omega_all_NUC[t*n:(t+1)*n]*beta_St*(MDP[:,(p+3)*t+p+2]))

      phi_result=phi_result/n/(T)
      eta_pi_est_MIS_NUC=eta_pi_est_MIS_NUC/n/(T)

      return phi_result, eta_pi_est_MIS_NUC


    eta_pi_est_aug_NUC, eta_pi_est_MIS_NUC=phi_aug_NUC(MDP,omega_all_NUC,Q,V,Pa,beta_pi,beta_Q_NUC)  

    print("MIS estimator under NUC: ",eta_pi_est_MIS_NUC) 
    # the final estimator is the summation of DM estimator and augmentation terms, given by eta_pi_DR
    eta_pi_est_DR_NUC=eta_pi_est_DM_NUC+eta_pi_est_aug_NUC
    print("DRL estimator under NUC: ",eta_pi_est_DR_NUC) 


    return eta_pi_est_MIS_NUC, eta_pi_est_DM_NUC, eta_pi_est_DR_NUC

# %% [markdown]
# #### Run

# %%
import joblib

REP=100
est_IVRL_DR=np.zeros((REP,10))
est_IVRL_DM=np.zeros((REP,10))
est_DM=np.zeros((REP,10))
est_MIS=np.zeros((REP,10))
est_DRL=np.zeros((REP,10))

np.random.seed(526)

n_all=np.array([100,200,300,400,500,600,700,800,900,1000])

for rep in range(0,REP):
  print("rep=",rep,":\n")
  for j in range(10):
  
    # generate MDP
    n=n_all[j]

    # the number of stages
    T=120
    p=2

    S0=generate_S0(n)
    MDP_IVRL = np.copy(S0)
    MDP_NUC = np.copy(S0)
    St=S0
    for i in range(T):
        Ut=generate_Ut(n)
        Zt=generate_Zt(St,n)
        At=generate_At(St,Zt,Ut,n)
        Rt=generate_Rt(St,At,Ut,n)
        Stplus1=generate_Stplus1(St,At,Ut,n)
        MDP_NUC = np.hstack((MDP_NUC, Zt.reshape(-1,1),Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        MDP_IVRL = np.hstack((MDP_IVRL, Zt.reshape(-1,1), At.reshape(-1,1), Rt.reshape(-1,1), Stplus1))
        St=Stplus1

    T=100
    p=3
    MDP_NUC=MDP_NUC[:,(20*(p+3)):(120*(p+3)+p)]
    MDP_NUC= np.hstack((MDP_NUC, Zt.reshape(-1,1)))
    est_MIS[rep,j],est_DM[rep,j],est_DRL[rep,j]=DRL_NUC_TE_est(MDP_NUC, 3, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)

    p=2
    MDP_IVRL=MDP_IVRL[:,(20*(p+3)):(120*(p+3)+p)]
    est_IVRL_DM[rep,j], est_IVRL_DR[rep,j]=IVRL_TE_est(MDP_IVRL, 2, n, T, Pi, gamma, domain_At, domain_Zt, max_iter=1000, epsilon=1e-3)
# Out:
# rep= 85 :
#
# pa model performance (accuracy):  0.766
#
# DM estimator under NUC:  25.00189188048015
# MIS estimator under NUC:  31.000869050314737
# DRL estimator under NUC:  24.61608215154272
# pa model performance (accuracy):  0.766
#
# pz model performance (accuracy):  0.723
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [21.03172726  6.58667885  6.57157407  0.02427769  3.28219791]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 23.877348897637013
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.8832724748872054
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.733
#
# DM estimator under NUC:  26.199996391911537
# MIS estimator under NUC:  30.33057746216478
# DRL estimator under NUC:  26.5006092319136
# pa model performance (accuracy):  0.733
#
# pz model performance (accuracy):  0.7225
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.98594075  5.01774068  4.76619159 -0.08482479  3.53440425]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.990439920620634
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.810264603879823
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7193333333333334
#
# DM estimator under NUC:  24.917287225273505
# MIS estimator under NUC:  29.789671687370454
# DRL estimator under NUC:  25.224172425415812
# pa model performance (accuracy):  0.7193333333333334
#
# pz model performance (accuracy):  0.7323333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.3998412   8.10927763  8.01922623 -0.11487964  3.36786016]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.37589854747944
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.309458230497264
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74125
#
# DM estimator under NUC:  25.756472453883525
# MIS estimator under NUC:  30.77235239886313
# DRL estimator under NUC:  25.75351456857315
# pa model performance (accuracy):  0.74125
#
# pz model performance (accuracy):  0.717
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.00240533  8.52795895  8.46374179 -0.14491354  3.31518215]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.964153595490387
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -13.696824952186008
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.727
#
# DM estimator under NUC:  25.979660789490328
# MIS estimator under NUC:  31.637533787909728
# DRL estimator under NUC:  26.058262319173174
# pa model performance (accuracy):  0.727
#
# pz model performance (accuracy):  0.725
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [12.77144018  8.14350442  7.80148025 -0.19741048  3.63373073]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.329208079596285
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.0015656067563232
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7303333333333333
#
# DM estimator under NUC:  24.984300738957423
# MIS estimator under NUC:  29.73336212031833
# DRL estimator under NUC:  24.89633622005953
# pa model performance (accuracy):  0.7303333333333333
#
# pz model performance (accuracy):  0.7281666666666666
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.15799921  8.77692345  8.74957054 -0.10640359  3.20025444]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.721070797908897
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.0613122345269514
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7351428571428571
#
# DM estimator under NUC:  25.427912223983604
# MIS estimator under NUC:  29.956053846286146
# DRL estimator under NUC:  25.4662491929925
# pa model performance (accuracy):  0.7351428571428571
#
# pz model performance (accuracy):  0.7234285714285714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.96436124  8.76841782  8.6882097  -0.14142391  3.2701472 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.597974580424722
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.632562768076451
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.742625
#
# DM estimator under NUC:  24.86358899943465
# MIS estimator under NUC:  29.663548586865076
# DRL estimator under NUC:  24.909273697744137
# pa model performance (accuracy):  0.742625
#
# pz model performance (accuracy):  0.728125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.10883338  8.75449655  8.69485031 -0.13148353  3.27134588]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.4118536870168
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.4869451100760958
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7343333333333333
#
# DM estimator under NUC:  25.160203594769452
# MIS estimator under NUC:  29.93436748494352
# DRL estimator under NUC:  25.240484648288923
# pa model performance (accuracy):  0.7343333333333333
#
# pz model performance (accuracy):  0.7235555555555555
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.1384597   8.89669223  8.80562836 -0.16466294  3.36464183]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.3723296229942
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.627960171029145
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7371
#
# DM estimator under NUC:  24.732000785007255
# MIS estimator under NUC:  29.495213560592692
# DRL estimator under NUC:  24.720662074049425
# pa model performance (accuracy):  0.7371
#
# pz model performance (accuracy):  0.7152
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.48284118  8.53278133  8.46736495 -0.12661709  3.27322139]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.335514026158705
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.6477963215857734
# Augmentation terms calculation finished.
#
# rep= 86 :
#
# pa model performance (accuracy):  0.748
#
# DM estimator under NUC:  24.48005138292326
# MIS estimator under NUC:  28.527303486511936
# DRL estimator under NUC:  23.927442036107966
# pa model performance (accuracy):  0.748
#
# pz model performance (accuracy):  0.716
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.3229917   6.33528272  6.2299763  -0.09175291  3.45440053]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.095934609698535
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -15.191595615875551
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74
#
# DM estimator under NUC:  25.662000408700656
# MIS estimator under NUC:  30.182380782708165
# DRL estimator under NUC:  25.56082125390627
# pa model performance (accuracy):  0.74
#
# pz model performance (accuracy):  0.7355
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [12.4567551   8.15381822  7.91103028 -0.16178973  3.38474334]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 15.924421554074211
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.769863437884523
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7326666666666667
#
# DM estimator under NUC:  25.496761799478435
# MIS estimator under NUC:  30.182533977874623
# DRL estimator under NUC:  25.53305566239908
# pa model performance (accuracy):  0.7326666666666667
#
# pz model performance (accuracy):  0.719
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.12789674  8.20833799  8.15984745 -0.08199131  3.26412448]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.845369919089723
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.2652675450103903
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7335
#
# DM estimator under NUC:  25.698232659044915
# MIS estimator under NUC:  30.470261468568516
# DRL estimator under NUC:  25.75252788960648
# pa model performance (accuracy):  0.7335
#
# pz model performance (accuracy):  0.7225
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.84644622  9.03448206  9.00750001 -0.15635484  3.22879292]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.081699042446274
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.7038890029374748
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7316
#
# DM estimator under NUC:  25.503122069015976
# MIS estimator under NUC:  30.69614510237659
# DRL estimator under NUC:  25.598125633669436
# pa model performance (accuracy):  0.7316
#
# pz model performance (accuracy):  0.7124
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.95590566  8.79537883  8.73391628 -0.1225953   3.28442147]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.690945539070448
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.017882169853769
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7286666666666667
#
# DM estimator under NUC:  26.121430044071236
# MIS estimator under NUC:  31.069601589003028
# DRL estimator under NUC:  26.164493415561214
# pa model performance (accuracy):  0.7286666666666667
#
# pz model performance (accuracy):  0.7238333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.23213524  8.91212508  8.88619527 -0.10991827  3.26716067]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.591297747585926
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.09019375346329006
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7427142857142857
#
# DM estimator under NUC:  25.095290038107255
# MIS estimator under NUC:  29.830316790944945
# DRL estimator under NUC:  25.225482351782965
# pa model performance (accuracy):  0.7427142857142857
#
# pz model performance (accuracy):  0.7135714285714285
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.66541267  7.83406857  7.69687185 -0.13913897  3.37449871]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.00047177068566
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.5875229938629705
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.73575
#
# DM estimator under NUC:  26.03520557413035
# MIS estimator under NUC:  30.270674121435164
# DRL estimator under NUC:  26.123801517027037
# pa model performance (accuracy):  0.73575
#
# pz model performance (accuracy):  0.7175
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.53878537  8.64432373  8.62941917 -0.09847759  3.25487059]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.121579583265564
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.8690307731431206
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7321111111111112
#
# DM estimator under NUC:  24.949911649083088
# MIS estimator under NUC:  29.650039156929807
# DRL estimator under NUC:  25.000755257479675
# pa model performance (accuracy):  0.7321111111111112
#
# pz model performance (accuracy):  0.7221111111111111
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.06132319  8.83867979  8.77173285 -0.16856596  3.31185324]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.05600712829236
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 1.69160321165199
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7309
#
# DM estimator under NUC:  25.295076950930717
# MIS estimator under NUC:  29.981251396705957
# DRL estimator under NUC:  25.401043031062947
# pa model performance (accuracy):  0.7309
#
# pz model performance (accuracy):  0.7165
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.60997792  8.61162328  8.52495148 -0.15327468  3.32654602]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.04237951703452
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.753030889277194
# Augmentation terms calculation finished.
#
# rep= 87 :
#
# pa model performance (accuracy):  0.755
#
# DM estimator under NUC:  26.608173348083447
# MIS estimator under NUC:  33.72518452162936
# DRL estimator under NUC:  26.55850704771092
# pa model performance (accuracy):  0.755
#
# pz model performance (accuracy):  0.718
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [19.13840083  9.6812916  10.17369478  0.03969003  2.97068987]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 23.37674312777537
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 36.67754305417938
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7315
#
# DM estimator under NUC:  25.462226066274617
# MIS estimator under NUC:  30.272504363325396
# DRL estimator under NUC:  25.587620454643563
# pa model performance (accuracy):  0.7315
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.27280152  8.98448673  8.94442628 -0.13238203  3.34140838]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.76776844567785
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -49.986208382850755
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.717
#
# DM estimator under NUC:  25.941436982561207
# MIS estimator under NUC:  31.211595399449884
# DRL estimator under NUC:  25.790918798119872
# pa model performance (accuracy):  0.717
#
# pz model performance (accuracy):  0.7246666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.40508232  8.35074208  8.27652769 -0.07910202  3.24638371]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.27767076504047
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 8.49461889876492
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.72075
#
# DM estimator under NUC:  26.627262487196337
# MIS estimator under NUC:  30.537795094227018
# DRL estimator under NUC:  26.78405245375249
# pa model performance (accuracy):  0.72075
#
# pz model performance (accuracy):  0.70075
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.34952593  8.40136237  8.37234068 -0.11909352  3.22667567]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.282614390737898
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.415953911813434
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7384
#
# DM estimator under NUC:  25.45406904106802
# MIS estimator under NUC:  30.295792830838426
# DRL estimator under NUC:  25.575840784510305
# pa model performance (accuracy):  0.7384
#
# pz model performance (accuracy):  0.7194
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.27121164  9.0024594   9.38482992 -0.0582487   2.87329475]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.27335361624732
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 22.40852396192797
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7413333333333333
#
# DM estimator under NUC:  25.276318806974917
# MIS estimator under NUC:  29.916647136234825
# DRL estimator under NUC:  25.177657991516938
# pa model performance (accuracy):  0.7413333333333333
#
# pz model performance (accuracy):  0.7185
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.73538965  8.9608903   8.86651456 -0.16925729  3.34320594]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.186015132111493
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -6.040245238706823
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7258571428571429
#
# DM estimator under NUC:  25.92026003662275
# MIS estimator under NUC:  29.5869693240714
# DRL estimator under NUC:  25.997832740176502
# pa model performance (accuracy):  0.7258571428571429
#
# pz model performance (accuracy):  0.7101428571428572
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [19.65856271  8.30243051  8.28862581 -0.06463327  3.23855891]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 23.10388535783559
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.7081868166058305
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.728125
#
# DM estimator under NUC:  25.695700309402646
# MIS estimator under NUC:  30.193751894146473
# DRL estimator under NUC:  25.756774127182485
# pa model performance (accuracy):  0.728125
#
# pz model performance (accuracy):  0.705125
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.76076997  8.25130792  8.17822623 -0.12648668  3.30402351]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.81830532186723
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.568575119187256
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7308888888888889
#
# DM estimator under NUC:  25.96723770362279
# MIS estimator under NUC:  30.55809587382005
# DRL estimator under NUC:  26.138529210208468
# pa model performance (accuracy):  0.7308888888888889
#
# pz model performance (accuracy):  0.7238888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.84128931  8.73979651  8.62158268 -0.1512552   3.35228886]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.401282989309784
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.730912346608699
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7373
#
# DM estimator under NUC:  25.05023147277609
# MIS estimator under NUC:  30.033143118506313
# DRL estimator under NUC:  24.960543052837675
# pa model performance (accuracy):  0.7373
#
# pz model performance (accuracy):  0.713
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.60011456  8.52198978  8.46770148 -0.12404078  3.29284979]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.929155079911478
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.3551341600350053
# Augmentation terms calculation finished.
#
# rep= 88 :
#
# pa model performance (accuracy):  0.729
#
# DM estimator under NUC:  24.62109752631092
# MIS estimator under NUC:  28.777397983266102
# DRL estimator under NUC:  24.31431192280935
# pa model performance (accuracy):  0.729
#
# pz model performance (accuracy):  0.699
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.23595205  8.62373917  8.61003561 -0.15972204  3.19158843]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.37631322436709
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 24.437813585001717
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.743
#
# DM estimator under NUC:  25.07594693892913
# MIS estimator under NUC:  30.01795539829173
# DRL estimator under NUC:  25.15589090083046
# pa model performance (accuracy):  0.743
#
# pz model performance (accuracy):  0.727
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [14.81333396  5.65448922  5.33386808 -0.15768111  3.57458286]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.798267603865504
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -8.434118183140923
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7486666666666667
#
# DM estimator under NUC:  24.519533997445784
# MIS estimator under NUC:  29.49990094927871
# DRL estimator under NUC:  24.71504010859722
# pa model performance (accuracy):  0.7486666666666667
#
# pz model performance (accuracy):  0.7343333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.53982589  8.48845431  8.43466975 -0.09300426  3.22777716]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.516777296406453
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.15437825500062097
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.746
#
# DM estimator under NUC:  25.751965935961575
# MIS estimator under NUC:  30.635108852268527
# DRL estimator under NUC:  25.663301651112487
# pa model performance (accuracy):  0.746
#
# pz model performance (accuracy):  0.7345
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [20.16697952  6.73037639  6.61068785 -0.04810111  3.38702774]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 23.536836850670525
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -21.955148504057792
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7256
#
# DM estimator under NUC:  25.457581631233833
# MIS estimator under NUC:  29.784199205405816
# DRL estimator under NUC:  25.503609855193414
# pa model performance (accuracy):  0.7256
#
# pz model performance (accuracy):  0.7194
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.39296145  7.96105662  7.84160574 -0.1298915   3.36351053]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.013963952721518
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -11.714164486021
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.725
#
# DM estimator under NUC:  25.65176967199068
# MIS estimator under NUC:  30.248810527525347
# DRL estimator under NUC:  25.573950856719353
# pa model performance (accuracy):  0.725
#
# pz model performance (accuracy):  0.7275
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [13.05501198  8.58871931  8.32233779 -0.20199487  3.47762986]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.382783794759327
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 48.7247990402283
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7305714285714285
#
# DM estimator under NUC:  26.17934060664502
# MIS estimator under NUC:  30.5838584379854
# DRL estimator under NUC:  26.12419109278715
# pa model performance (accuracy):  0.7305714285714285
#
# pz model performance (accuracy):  0.7157142857142857
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.18042786  8.0118233   7.92356031 -0.14173612  3.36068966]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.638394028208964
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 46.722911716924074
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.740625
#
# DM estimator under NUC:  25.392795088728136
# MIS estimator under NUC:  30.40031297571146
# DRL estimator under NUC:  25.439161098688352
# pa model performance (accuracy):  0.740625
#
# pz model performance (accuracy):  0.717875
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.00325088  8.36665307  8.27991709 -0.12694117  3.30649871]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.722810204157835
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.9083634840406787
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7204444444444444
#
# DM estimator under NUC:  25.364633940599678
# MIS estimator under NUC:  30.166592540421338
# DRL estimator under NUC:  25.465336035390497
# pa model performance (accuracy):  0.7204444444444444
#
# pz model performance (accuracy):  0.7148888888888889
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [14.25805574  7.82260356  7.64016346 -0.18151735  3.41564463]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.44891200800094
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 12.782675874649849
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7327
#
# DM estimator under NUC:  25.078485501418623
# MIS estimator under NUC:  29.628356112118002
# DRL estimator under NUC:  25.189167346226014
# pa model performance (accuracy):  0.7327
#
# pz model performance (accuracy):  0.7289
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.07471266  8.39286256  8.30847304 -0.10029163  3.27938082]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.656795933011402
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.261815335523995
# Augmentation terms calculation finished.
#
# rep= 89 :
#
# pa model performance (accuracy):  0.725
#
# DM estimator under NUC:  23.833032641855283
# MIS estimator under NUC:  30.365378173778158
# DRL estimator under NUC:  23.853189649798352
# pa model performance (accuracy):  0.725
#
# pz model performance (accuracy):  0.708
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [12.30747957  6.59326484  6.71584398 -0.11595082  2.96350278]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 13.885247286891364
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -66.6366453392656
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.757
#
# DM estimator under NUC:  25.493373366517222
# MIS estimator under NUC:  30.967913608530015
# DRL estimator under NUC:  25.71004867675312
# pa model performance (accuracy):  0.757
#
# pz model performance (accuracy):  0.737
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.17914877  8.50814109  8.46906287 -0.10468317  3.24627031]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.50324499124261
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 7.0514141060505935
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7393333333333333
#
# DM estimator under NUC:  26.7473549473576
# MIS estimator under NUC:  32.708127751761154
# DRL estimator under NUC:  26.889842546019153
# pa model performance (accuracy):  0.7396666666666667
#
# pz model performance (accuracy):  0.7283333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.77267859  7.89582891  7.68745023 -0.12004881  3.3702964 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.7626777572006
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -24.055534478930863
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.74875
#
# DM estimator under NUC:  26.264306329008676
# MIS estimator under NUC:  31.83404040338796
# DRL estimator under NUC:  26.3341989270556
# pa model performance (accuracy):  0.74875
#
# pz model performance (accuracy):  0.73725
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.031092    8.33984708  8.19345163 -0.17465784  3.47655262]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.660297905643198
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -15.28573314546884
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7418
#
# DM estimator under NUC:  25.34623000911955
# MIS estimator under NUC:  30.897931145310203
# DRL estimator under NUC:  25.411831813343472
# pa model performance (accuracy):  0.7418
#
# pz model performance (accuracy):  0.7204
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.09918044  8.36193851  8.29224059 -0.10571272  3.30038154]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.791683767538682
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.43730639498283
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7181666666666666
#
# DM estimator under NUC:  24.79884366014581
# MIS estimator under NUC:  28.983117814791445
# DRL estimator under NUC:  24.95374409178317
# pa model performance (accuracy):  0.7181666666666666
#
# pz model performance (accuracy):  0.7148333333333333
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.19670456  8.01833113  7.88107185 -0.11137294  3.40390284]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.443157352796096
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.747709992081924
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7307142857142858
#
# DM estimator under NUC:  26.48907527241617
# MIS estimator under NUC:  30.828145536131373
# DRL estimator under NUC:  26.580285698778905
# pa model performance (accuracy):  0.7307142857142858
#
# pz model performance (accuracy):  0.7124285714285714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.58756845  8.39508361  8.34248638 -0.10022188  3.28688618]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 22.4460903028059
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.986050707660673
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7445
#
# DM estimator under NUC:  25.217899317665296
# MIS estimator under NUC:  30.312759157255076
# DRL estimator under NUC:  25.220716644733304
# pa model performance (accuracy):  0.7445
#
# pz model performance (accuracy):  0.74225
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.39966729  8.83126021  8.78077209 -0.12509524  3.2724495 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.71585759088211
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.8865134778383894
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7408888888888889
#
# DM estimator under NUC:  25.288974000964576
# MIS estimator under NUC:  30.396427212978214
# DRL estimator under NUC:  25.22327882510194
# pa model performance (accuracy):  0.7408888888888889
#
# pz model performance (accuracy):  0.7253333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.0304831   8.34528413  8.20254944 -0.13236897  3.34539235]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.67458741913965
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.679860893166932
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7354
#
# DM estimator under NUC:  25.397847597618686
# MIS estimator under NUC:  30.606013032799606
# DRL estimator under NUC:  25.441222271896766
# pa model performance (accuracy):  0.7354
#
# pz model performance (accuracy):  0.731
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.4429005   8.56810731  8.45003819 -0.14710483  3.32940307]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.134511884852216
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 8.433441428764747
# Augmentation terms calculation finished.
#
# rep= 90 :
#
# pa model performance (accuracy):  0.71
#
# DM estimator under NUC:  23.423210931078593
# MIS estimator under NUC:  27.209676158231517
# DRL estimator under NUC:  23.20839478006774
# pa model performance (accuracy):  0.71
#
# pz model performance (accuracy):  0.693
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.41152589  9.33019301  9.43038585 -0.10876563  3.20848699]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 14.91951991932663
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -62.43565195980957
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7265
#
# DM estimator under NUC:  25.075396384705822
# MIS estimator under NUC:  28.773011547902485
# DRL estimator under NUC:  24.85064194191578
# pa model performance (accuracy):  0.7265
#
# pz model performance (accuracy):  0.714
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.26750359  8.75656974  8.73479822 -0.11409035  3.27742493]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.800005557511053
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 5.132895074303296
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7353333333333333
#
# DM estimator under NUC:  26.000009014170082
# MIS estimator under NUC:  30.74404954328255
# DRL estimator under NUC:  25.940439834057422
# pa model performance (accuracy):  0.7353333333333333
#
# pz model performance (accuracy):  0.7273333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.98075795  8.68823241  8.64609199 -0.13160816  3.29139152]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.957292049721186
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -6.214306505327946
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7425
#
# DM estimator under NUC:  25.89867739118659
# MIS estimator under NUC:  31.695196989271004
# DRL estimator under NUC:  26.004527688682792
# pa model performance (accuracy):  0.7425
#
# pz model performance (accuracy):  0.734
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.80727945  8.63479777  8.56836344 -0.11147412  3.30707471]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.07898655906554
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.42855752419072196
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7288
#
# DM estimator under NUC:  24.632476881258885
# MIS estimator under NUC:  28.823243581227686
# DRL estimator under NUC:  24.67094901138565
# pa model performance (accuracy):  0.7288
#
# pz model performance (accuracy):  0.7076
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.93686991  7.984062    7.87247249 -0.11413316  3.30899361]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.140852015409525
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.123866548272369
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7303333333333333
#
# DM estimator under NUC:  25.72894512922969
# MIS estimator under NUC:  30.954407075563005
# DRL estimator under NUC:  25.848937303924597
# pa model performance (accuracy):  0.7303333333333333
#
# pz model performance (accuracy):  0.7135
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.44696989  8.79788987  8.73736816 -0.11684283  3.27444263]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.671027017298826
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.24381864521474106
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7324285714285714
#
# DM estimator under NUC:  25.758811359528003
# MIS estimator under NUC:  30.54242029892163
# DRL estimator under NUC:  25.640396683559462
# pa model performance (accuracy):  0.7324285714285714
#
# pz model performance (accuracy):  0.7292857142857143
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.81248289  8.78742295  8.72443718 -0.15035459  3.31751504]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.60873172207789
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.6711532083947755
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.736
#
# DM estimator under NUC:  25.466186546608768
# MIS estimator under NUC:  30.06753409862288
# DRL estimator under NUC:  25.55348614997748
# pa model performance (accuracy):  0.736
#
# pz model performance (accuracy):  0.7235
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.90313825  7.84397062  7.78883153 -0.10188826  3.27421538]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.86821909431347
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.47450931070763
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7322222222222222
#
# DM estimator under NUC:  25.346119422109048
# MIS estimator under NUC:  30.079550430429276
# DRL estimator under NUC:  25.440355537261766
# pa model performance (accuracy):  0.7322222222222222
#
# pz model performance (accuracy):  0.7147777777777777
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.40536785  8.63443914  8.59065711 -0.13443954  3.30446235]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.781689033611247
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.7618828196021563
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7322
#
# DM estimator under NUC:  25.137525114998436
# MIS estimator under NUC:  29.861226469650866
# DRL estimator under NUC:  25.168844188458284
# pa model performance (accuracy):  0.7322
#
# pz model performance (accuracy):  0.7151
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.55488338  8.55098983  8.45525916 -0.10831821  3.34864371]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.222565743217288
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.0854251092827942
# Augmentation terms calculation finished.
#
# rep= 91 :
#
# pa model performance (accuracy):  0.75
#
# DM estimator under NUC:  26.294868206627463
# MIS estimator under NUC:  30.862671963560885
# DRL estimator under NUC:  26.369228327143837
# pa model performance (accuracy):  0.75
#
# pz model performance (accuracy):  0.722
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.02600642  3.60700238  3.38398156 -0.06006918  3.46211784]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.63783925940169
# DM estimator calculation finished.
#
# ...
# DM estimator: eta_pi_DM= 21.374902731425895
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -2.243029512378213
# Augmentation terms calculation finished.
#
# rep= 98 :
#
# pa model performance (accuracy):  0.751
#
# DM estimator under NUC:  26.96532547482709
# MIS estimator under NUC:  31.9330746073536
# DRL estimator under NUC:  27.153344199048117
# pa model performance (accuracy):  0.751
#
# pz model performance (accuracy):  0.72
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [22.77292027  7.36502647  7.38416577  0.05696648  3.16364747]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 26.806251426831345
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -4.813975188366968
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.75
#
# DM estimator under NUC:  26.723893037743313
# MIS estimator under NUC:  31.94114873760261
# DRL estimator under NUC:  26.849797922348902
# pa model performance (accuracy):  0.75
#
# pz model performance (accuracy):  0.715
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.53542288  8.39578494  8.24424067 -0.17026532  3.41476839]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.59467952115964
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 19.770504317030387
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7446666666666667
#
# DM estimator under NUC:  25.323873891576813
# MIS estimator under NUC:  29.911991203410867
# DRL estimator under NUC:  25.349919269987065
# pa model performance (accuracy):  0.7446666666666667
#
# pz model performance (accuracy):  0.709
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.31792485  8.16484786  8.06378055 -0.10507404  3.34706418]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.991332356405632
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 18.514266070631198
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.72625
#
# DM estimator under NUC:  25.265419370555943
# MIS estimator under NUC:  29.226405161777635
# DRL estimator under NUC:  25.215014822901175
# pa model performance (accuracy):  0.72625
#
# pz model performance (accuracy):  0.727
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.5000777   8.76533316  8.76455504 -0.12751263  3.29078229]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 17.62141757269306
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -1.7752472090551716
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7186
#
# DM estimator under NUC:  25.59579311064761
# MIS estimator under NUC:  30.487537949769163
# DRL estimator under NUC:  25.73762915502232
# pa model performance (accuracy):  0.7186
#
# pz model performance (accuracy):  0.7094
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.61380989  7.91420894  7.72157507 -0.17161693  3.44069747]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.319088855357098
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.6219425740269726
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7206666666666667
#
# DM estimator under NUC:  25.388964776238616
# MIS estimator under NUC:  29.772933733528397
# DRL estimator under NUC:  25.457035498225704
# pa model performance (accuracy):  0.7206666666666667
#
# pz model performance (accuracy):  0.7081666666666667
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.31278703  8.43124867  8.40262642 -0.10020311  3.25211031]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.91802580230088
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -0.2125533839499884
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7308571428571429
#
# DM estimator under NUC:  25.22430009579397
# MIS estimator under NUC:  29.495536411405325
# DRL estimator under NUC:  25.318241598140634
# pa model performance (accuracy):  0.7308571428571429
#
# pz model performance (accuracy):  0.72
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [14.01423814  8.14352074  7.93931453 -0.17717483  3.39675155]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 16.41918207386226
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 20.264059279305073
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.741375
#
# DM estimator under NUC:  25.307622988264626
# MIS estimator under NUC:  29.84566941995789
# DRL estimator under NUC:  25.325218294704595
# pa model performance (accuracy):  0.741375
#
# pz model performance (accuracy):  0.727
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.67237434  8.69345535  8.60210558 -0.15261167  3.33995878]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.38150957935273
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 2.9981380812531473
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.733
#
# DM estimator under NUC:  25.31009054741477
# MIS estimator under NUC:  29.749765116064278
# DRL estimator under NUC:  25.348860335836584
# pa model performance (accuracy):  0.733
#
# pz model performance (accuracy):  0.7202222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.43504803  8.29854967  8.15592141 -0.14822229  3.38245127]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.052030232552045
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.531428168254589
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.735
#
# DM estimator under NUC:  25.592364972463674
# MIS estimator under NUC:  30.60128324450472
# DRL estimator under NUC:  25.659759661282926
# pa model performance (accuracy):  0.735
#
# pz model performance (accuracy):  0.7241
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.62972706  8.41840188  8.32249504 -0.15602261  3.29874594]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.627626359484132
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.859223661552244
# Augmentation terms calculation finished.
#
# rep= 99 :
#
# pa model performance (accuracy):  0.728
#
# DM estimator under NUC:  25.191585007217828
# MIS estimator under NUC:  30.129407446721743
# DRL estimator under NUC:  25.426548655529803
# pa model performance (accuracy):  0.728
#
# pz model performance (accuracy):  0.713
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.93920703  7.30129672  7.11211985 -0.08890917  3.32992783]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.758233990328574
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 24.384137006380964
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7285
#
# DM estimator under NUC:  27.22650657713139
# MIS estimator under NUC:  31.055601571770925
# DRL estimator under NUC:  27.02798215886504
# pa model performance (accuracy):  0.7285
#
# pz model performance (accuracy):  0.721
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [20.80518011  6.86098652  6.79297747 -0.04943762  3.40689392]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 25.216162321667102
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 13.768363934714468
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7196666666666667
#
# DM estimator under NUC:  24.977446997763657
# MIS estimator under NUC:  29.698154594021695
# DRL estimator under NUC:  25.023890699314173
# pa model performance (accuracy):  0.7196666666666667
#
# pz model performance (accuracy):  0.7193333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [ 5.11123504  8.08493271  7.29900813 -0.32547107  4.1706378 ]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 7.245219558441774
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -10.845015075138512
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.72575
#
# DM estimator under NUC:  24.72396519746686
# MIS estimator under NUC:  29.63585228144957
# DRL estimator under NUC:  24.891924183814684
# pa model performance (accuracy):  0.72575
#
# pz model performance (accuracy):  0.71975
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.17233667  6.56398055  6.41770581 -0.11025646  3.41808401]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.354576175434094
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -7.765811077311045
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7314
#
# DM estimator under NUC:  25.913554723816357
# MIS estimator under NUC:  30.973731886290892
# DRL estimator under NUC:  25.89611531695851
# pa model performance (accuracy):  0.7314
#
# pz model performance (accuracy):  0.7116
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [16.88975027  8.16427766  8.02387471 -0.1205922   3.35714302]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.416693902730174
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 4.311650250140033
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7403333333333333
#
# DM estimator under NUC:  25.32161527595197
# MIS estimator under NUC:  29.849142789448923
# DRL estimator under NUC:  25.313006982460863
# pa model performance (accuracy):  0.7403333333333333
#
# pz model performance (accuracy):  0.7273333333333334
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.71139954  8.02598138  7.95436799 -0.07978982  3.26085315]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.63582586842074
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 0.42065503116463226
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7321428571428571
#
# DM estimator under NUC:  25.326551866462697
# MIS estimator under NUC:  29.68039244519673
# DRL estimator under NUC:  25.33029907887057
# pa model performance (accuracy):  0.7321428571428571
#
# pz model performance (accuracy):  0.7158571428571429
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.79314665  7.90575323  7.84820491 -0.13192645  3.27928046]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 20.543027389263848
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 9.967754693458973
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.725
#
# DM estimator under NUC:  25.59186351786908
# MIS estimator under NUC:  29.72115296325282
# DRL estimator under NUC:  25.680911932753343
# pa model performance (accuracy):  0.725
#
# pz model performance (accuracy):  0.7205
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [18.60902377  8.30692122  8.26505093 -0.09680505  3.30613604]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 21.546207731822115
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 6.5563288058841644
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7353333333333333
#
# DM estimator under NUC:  24.848733205321018
# MIS estimator under NUC:  29.771817297226004
# DRL estimator under NUC:  24.877753972229566
# pa model performance (accuracy):  0.7353333333333333
#
# pz model performance (accuracy):  0.7242222222222222
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [17.84784103  8.58073776  8.50873314 -0.12376429  3.29170432]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 19.95735922844816
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= -3.3338710931963753
# Augmentation terms calculation finished.
#
# pa model performance (accuracy):  0.7297
#
# DM estimator under NUC:  25.901637674596692
# MIS estimator under NUC:  30.509063462748912
# DRL estimator under NUC:  25.995457793620243
# pa model performance (accuracy):  0.7297
#
# pz model performance (accuracy):  0.7231
#
# Start estimating omega_pi(St):
# omega_pi(St) estimation finished.
#
# Start estimating Q function and Value function (fitted Q evaluation):
# Estimated beta_Q is:  [15.63563041  8.73647493  8.62947702 -0.16817111  3.34935575]
# Q function and Value function estimation finished.
#
# Start calculating DM estimator:
# DM estimator: eta_pi_DM= 18.649885062915715
# DM estimator calculation finished.
#
# Start calculating augmentation terms:
# Augmentation term: eta_pi_aug= 3.7944615733283094
# Augmentation terms calculation finished.

# %%
import numpy as np
REP=100
mean_IVRL_DR=(np.sum(est_IVRL_DR,0)/REP)
mean_IVRL_DM=(np.sum(est_IVRL_DM,0)/REP)
mean_DM=(np.sum(est_DM,0)/REP)
mean_MIS=(np.sum(est_MIS,0)/REP)
mean_DRL=(np.sum(est_DRL,0)/REP)

Var_IVRL_DR=np.sum((est_IVRL_DR-mean_IVRL_DR)**2,0)/REP
Var_IVRL_DM=np.sum((est_IVRL_DM-mean_IVRL_DM)**2,0)/REP
Var_DM=np.sum((est_DM-mean_DM)**2,0)/REP
Var_MIS=np.sum((est_MIS-mean_MIS)**2,0)/REP
Var_DRL=np.sum((est_DRL-mean_DRL)**2,0)/REP

# %%
MSE_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true)**2,0)/REP
MSE_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true)**2,0)/REP
MSE_DM=np.sum((est_DM-eta_pi_true)**2,0)/REP
MSE_MIS=np.sum((est_MIS-eta_pi_true)**2,0)/REP
MSE_DRL=np.sum((est_DRL-eta_pi_true)**2,0)/REP

Bias_IVRL_DR=np.sum((est_IVRL_DR-eta_pi_true),0)/REP
Bias_IVRL_DM=np.sum((est_IVRL_DM-eta_pi_true),0)/REP
Bias_DM=np.sum((est_DM-eta_pi_true),0)/REP
Bias_MIS=np.sum((est_MIS-eta_pi_true),0)/REP
Bias_DRL=np.sum((est_DRL-eta_pi_true),0)/REP

# %%
import matplotlib.pyplot as plt
 
trajectory = [200,300,400,500,600,700,800,900,1000]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

#pyl.xlim(0, 20)
#pyl.ylim(0.25, 2)

ax1.plot(trajectory, np.log(MSE_IVRL_DR/eta_pi_true**2)[1:11] ,marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax1.plot(trajectory, np.log(MSE_DM/eta_pi_true**2)[1:11] ,marker='+', linestyle='--', mec='r', mfc='r', label='DM')
ax1.plot(trajectory, np.log(MSE_MIS/eta_pi_true**2)[1:11] ,marker='v', linestyle='-.', mec='r', mfc='r', label='MIS')
ax1.plot(trajectory, np.log(MSE_DRL/eta_pi_true**2)[1:11] ,marker='x', linestyle=':', mec='r', mfc='r', label='DRL')
ax1.set_xlabel("number of trajectories")
ax1.set_title('log (Relative MSE)')

ax2.plot(trajectory, np.log(abs(Bias_IVRL_DR)/abs(eta_pi_true))[1:11],marker='*', linestyle='-', mec='r', mfc='r', label='IVMDP')
ax2.plot(trajectory, np.log(abs(Bias_DM)/abs(eta_pi_true))[1:11],marker='+', linestyle='--', mec='r', mfc='r', label='NUC-DM')
ax2.plot(trajectory, np.log(abs(Bias_MIS)/abs(eta_pi_true))[1:11],marker='v', linestyle='-.', mec='r', mfc='r', label='NUC-MIS')
ax2.plot(trajectory, np.log(abs(Bias_DRL)/abs(eta_pi_true))[1:11],marker='x', linestyle=':', mec='r', mfc='r', label='NUC-DRL')
ax2.set_xlabel("number of trajectories")
ax2.set_title('log (Relative Absolute Bias)')
#plt.legend(loc=(1.05,0.4))
plt.legend(loc="best")
plt.text(0, -3.5, "Weak IV", ha='center')
#plt.xlim(399, 1001)
plt.show()
